# %%
model_name = "google/flan-t5-base"

# %%
import sys

sys.path.insert(0, '../')
from datasets import Dataset
from src.training import generator
from src.utils import sanitize_context_word, sanitize_context
from src.mlflow_utils import mlflow
from transformers import T5Tokenizer

mlflow.set_experiment(experiment_id=4)

prefix = "define: "
tokenizer = T5Tokenizer.from_pretrained(model_name)

def preprocess(examples):
    inputs = [f"{sanitize_context(doc[2])} Was ist die Definition von \"{sanitize_context_word(doc[1])}\"?" for doc in examples["input"]]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True)
    labels = tokenizer(text_target=[sanitize_context(doc) for doc in examples["gt"]], max_length=128, truncation=True)
    model_inputs["labels"] = labels["input_ids"]

    return model_inputs


dataset_train = Dataset.from_generator(lambda: generator("train", limit=1000))
dataset_val = Dataset.from_generator(lambda: generator("val"))
# dataset_test = Dataset.from_generator(lambda: generator("test", preprocess))
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Encode the input data
dataset_train = dataset_train.map(preprocess, batched=True)
# # The transformers model expects the target class column to be named "labels"
# dataset_train = dataset_train.rename_column(original_column_name="label", new_column_name="labels")
# # Transform to pytorch tensors and only output the required columns
# dataset_train.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

# Encode the input data
dataset_val = dataset_val.map(preprocess, batched=True)
# # The transformers model expects the target class column to be named "labels"
# dataset_val = dataset_val.rename_column(original_column_name="label", new_column_name="labels")
# # Transform to pytorch tensors and only output the required columns
# dataset_val.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

# %%
from adapters import AutoAdapterModel, T5AdapterModel

# %%
model = AutoAdapterModel.from_pretrained(model_name)  # type: T5AdapterModel

# %%
print(model.num_parameters(only_trainable=True))
print(model.num_parameters(only_trainable=False))
# Out:
# 247577856
# 247577856

# %%
1789056 / 249366912 * 100
# Out:
# 0.7174392086148141

# %%
adapter_name = "experiment_1"

# %%
model.add_seq2seq_lm_head(adapter_name)
model.add_adapter(adapter_name)

# %%
model.load_adapter("./example_test_2/")
# Out:
# 'test-adapter-2'

# %%
list(model.adapters_config)
# Out:
# ['experiment_1']

# %%
model.train_adapter(adapter_name)
model.set_active_adapters(adapter_name)

# %%
print(model.num_parameters(only_trainable=True))
print(model.num_parameters(only_trainable=False))
# Out:
# 26463360
# 274041216

# %%
25270272 / 2809229312 * 100
# Out:
# 0.8995446506290762

# %%
from src.ha_utils import set_sensor_state, Input, set_absolute_value
from transformers import TrainerCallback

class HassioCallback(TrainerCallback):
    def on_step_end(self, args, state, control, **kwargs):
        # Calculate the percentage of steps completed in the current epoch
        steps_per_epoch = state.max_steps / args.num_train_epochs
        current_step_percentage = (state.global_step % steps_per_epoch) / steps_per_epoch
        
        # Calculate the percentage of epochs completed
        current_epoch_percentage = state.epoch / args.num_train_epochs

        set_sensor_state(state.global_step % steps_per_epoch, steps_per_epoch, Input.SINGLE_INPUT)
        set_sensor_state(state.epoch, args.num_train_epochs, Input.TOTAL_INPUT)
        if state.log_history and 'loss' in state.log_history[-1]:
            set_absolute_value(state.log_history[-1]['loss'], Input.LOSS)
            
        return control

# %%
import numpy as np
from transformers import Seq2SeqTrainingArguments, EvalPrediction, DataCollatorForSeq2Seq
from adapters import AdapterTrainer

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model_name)

training_args = Seq2SeqTrainingArguments(
    learning_rate=1e-4,
    num_train_epochs=24,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=32,
    logging_steps=200,
    output_dir="./training_output",
    overwrite_output_dir=True,
    # The next line is important to ensure the dataset labels are properly passed to the model
    remove_unused_columns=True,
    predict_with_generate=True,
    eval_accumulation_steps=1
)

trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset_train,
    eval_dataset=dataset_val,
    # compute_metrics=compute_accuracy,
    data_collator=data_collator,
    tokenizer=tokenizer,
    callbacks=[HassioCallback]
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='3000' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3000/3000 07:02, Epoch 24/24]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>9.754000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>9.462900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>9.296800</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>9.185300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>9.117500</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>9.055200</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>9.004200</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>8.948900</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>8.911400</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>8.857000</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>8.823100</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>8.799400</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>8.774300</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>8.763900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>8.750800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3000, training_loss=9.033647298177083, metrics={'train_runtime': 423.1781, 'train_samples_per_second': 56.714, 'train_steps_per_second': 7.089, 'total_flos': 2820211392890880.0, 'train_loss': 9.033647298177083, 'epoch': 24.0})

# %%
model.save_adapter("./Adapters_Experiments/experiment-1", adapter_name)

# %%
from transformers import GenerationConfig
import torch

gen_config = GenerationConfig(max_new_tokens=128, top_k=1)
# Out:
# /home/jfeil/.pyenv/versions/3.10.12/envs/MasterThesis-NLP/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:509: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(

# %%
datapoint = dataset_val[0]
datapoint = dataset_train[10]

input_text = f"{sanitize_context(datapoint['input'][2])} Was ist die Definition von \"{sanitize_context_word(datapoint['input'][1])}\"?"
# input_ids = tokenizer(input_text, return_tensors="pt").to('cuda').input_ids
outputs = model.generate(torch.tensor([datapoint['input_ids'],]).to('cuda'), generation_config=gen_config)

print("Prompt: " + input_text)
print("\n")
print("Prediction: " + tokenizer.decode(outputs[0], skip_special_tokens=True))
print("\n")
print("Ground-Truth: " + datapoint['gt'])
# Out:
# Prompt: Danach wird in einem heute vielfach gebrauchten System die Gattung in 4 Subgenera eingeteilt, wovon das Subgenus II (Eurosa) 10 Sektionen mit zus. 126 Arten umfaßt. Was ist die Definition von "Subgenera"?
#
#
# Prediction: esst, seses, essesses, esseses, seses, sesees
#
#
# Ground-Truth: ''Biologie, fachsprachlich:'' eine Rangstufe der biologischen Systematik unterhalb des Genus, in die artenreiche Gattungen (Genera) unterteilt werden können

# %%
for dat in dataset_train:
    print(tokenizer.decode(dat["labels"], skip_special_tokens=False))
# Out:
# Taxonomie Biologische Systematik (neulateinisch) Ordnung oder fachwissenschaftlich Ordo (Zusammenfassung mehrerer eng verwandter Familien, Teil eine Klasse)</s>
# die Gestalt, das <unk> ußere, die Erscheinung</s>
# militärische Abteilung, Kriegsflotte, Heer</s>
# nächstkleinere Unterteilung der taxonomischen Regna (Reiche)</s>
# Biologie die hierarchische Gliederungsstufe der Divisio (deutsch Abteilung) im Reich der Pflanzen und der Pilze wird weiter in Subdivisiones (deutsch Unterabteilungen) differenziert</s>
# Biologie, Systematik fachwissenschaftlicher Terminus für das zoologische, hierarchisch hoch angesiedelte Taxon des Stammes, das zwischen dem Regnum (deutsch Reich) und der Classis (deutsch Klasse) steht. Im Pflanzenreich entspricht formal dem Phylum die Divisio (deutsch die Abteilung)., Seite 880&nbspf., Kapitel Systematik</s>
# Biologie, Systematik fachwissenschaftlicher Terminus für das zoologische, hierarchisch hoch angesiedelte Taxon des Stammes, das zwischen dem Regnum (deutsch Reich) und der Classis (deutsch Klasse) steht. Im Pflanzenreich entspricht formal dem Phylum die Divisio (deutsch die Abteilung)., Seite 880&nbspf., Kapitel Systematik</s>
# Biologie, fachsprachlich eine Rangstufe der biologischen Systematik unterhalb der Ordnung, in der enger verwandte Familien zusammengefasst werden</s>
# Biologie, fachsprachlich eine Rangstufe der biologischen Systematik unterhalb des Genus, in die artenreiche Gattungen (Genera) unterteilt werden können</s>
# Biologie, fachsprachlich eine Rangstufe der biologischen Systematik unterhalb des Genus, in die artenreiche Gattungen (Genera) unterteilt werden können</s>
# Biologie, fachsprachlich eine Rangstufe der biologischen Systematik unterhalb des Genus, in die artenreiche Gattungen (Genera) unterteilt werden können</s>
# Biologie, fachsprachlich eine Rangstufe der biologischen Systematik unterhalb des Genus, in die artenreiche Gattungen (Genera) unterteilt werden können</s>
# Biologie, fachsprachlich eine Rangstufe der biologischen Systematik unterhalb des Genus, in die artenreiche Gattungen (Genera) unterteilt werden können</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# zweiter, 28-tägiger (in Schaltjahren 29-tägiger) und somit kürzester Monat im Kalenderjahr</s>
# eine innige, gefühlsmäßige Zuneigung für jemanden oder etwas empfinden</s>
# eine innige, gefühlsmäßige Zuneigung für jemanden oder etwas empfinden</s>
# Geschlechtsverkehr haben</s>
# starke Zuneigung, Begierde zum Ausdruck bringen, aber ohne die Zielperson zu nennen</s>
# schlangenförmiger Süßwasser- und Meerwasserfisch aus der Ordnung der Aalartigen (Anguilliformes)</s>
# schlangenförmiger Süßwasser- und Meerwasserfisch aus der Ordnung der Aalartigen (Anguilliformes)</s>
# schlangenförmiger Süßwasser- und Meerwasserfisch aus der Ordnung der Aalartigen (Anguilliformes)</s>
# Fisch oder Wassertier von länglicher Gestalt</s>
# Torpedo</s>
# neu eingezogener, unvereidigter Soldat, Soldat ohne Dienstgrad</s>
# junge Kalmuspflanze</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# unterdurchschnittlich häufig auftretender, deutscher und niederländischer Nachname, Familienname häufigstes Vorkommen in Deutschland im Kreis Kleve in Nordrhein-Westfalen) auch mit Namenzusatz de</s>
# bedeutendste Plansprache</s>
# bedeutendste Plansprache</s>
# bedeutendste Plansprache</s>
# bedeutendste Plansprache</s>
# bedeutendste Plansprache</s>
# erster Wochentag gemäß ISO 8601Wikipedia ISO 8601 zweiter Wochentag nach jüdischer, christlicher und islamischer Zählung Tag zwischen Sonntag und Dienstag</s>
# erster Wochentag gemäß ISO 8601Wikipedia ISO 8601 zweiter Wochentag nach jüdischer, christlicher und islamischer Zählung Tag zwischen Sonntag und Dienstag</s>
# erster Wochentag gemäß ISO 8601Wikipedia ISO 8601 zweiter Wochentag nach jüdischer, christlicher und islamischer Zählung Tag zwischen Sonntag und Dienstag</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# stehendes Gewässer, das von Land umgeben ist</s>
# stehendes Gewässer, das von Land umgeben ist</s>
# stehendes Gewässer, das von Land umgeben ist</s>
# stehendes Gewässer, das von Land umgeben ist</s>
# Namensbestandteil vieler Seen1</s>
# sehr großes, zusammenhängendes Gewässer</s>
# sehr großes, zusammenhängendes Gewässer</s>
# Bewegung der Oberfläche eines Meeres oder Sees</s>
# Bewegung der Oberfläche eines Meeres oder Sees</s>
# hohe Welle</s>
# hohe Welle</s>
# hohe Welle</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# gängiger Name eines im Westen Mitteleuropas liegenden Landes und amtliche Kurzform (Staatsbezeichnung) der Bundesrepublik Deutschland</s>
# besonders in den Medien Bezeichnung für alle Angehörigen des deutschen Volkes und seiner Regierung</s>
# besonders in den Medien Bezeichnung für alle Angehörigen des deutschen Volkes und seiner Regierung</s>
# an einen Zugang montierte Schließvorrichtung</s>
# an einen Zugang montierte Schließvorrichtung</s>
# an einen Zugang montierte Schließvorrichtung</s>
# prunkvolles und repräsentatives Wohngebäude</s>
# prunkvolles und repräsentatives Wohngebäude</s>
# prunkvolles und repräsentatives Wohngebäude</s>
# Teil einer Feuerwaffe, welcher die Ladung zündet</s>
# zahnartige Vorsprünge an beiden Seiten der Schale einer Muschel</s>
# das Entstehen, Hervorkommen von etwas (im Laufe eines Prozesses)</s>
# das Entstehen, Hervorkommen von etwas (im Laufe eines Prozesses)</s>
# das Entstehen, Hervorkommen von etwas (im Laufe eines Prozesses)</s>
# Handlung oder Vorgang, etwas herzustellen, zu erschaffen oder zu formen</s>
# Handlung oder Vorgang, etwas herzustellen, zu erschaffen oder zu formen</s>
# Handlung oder Vorgang, etwas herzustellen, zu erschaffen oder zu formen</s>
# Handlung oder Vorgang, etwas herzustellen, zu erschaffen oder zu formen</s>
# Handlung oder Vorgang, etwas herzustellen, zu erschaffen oder zu formen</s>
# äußere Form, Gestalt von etwas</s>
# Wortbildung</s>
# Weiterentwicklung, Formung des menschlichen Geistes durch Erziehung</s>
# Weiterentwicklung, Formung des menschlichen Geistes durch Erziehung</s>
# Weiterentwicklung, Formung des menschlichen Geistes durch Erziehung</s>
# Weiterentwicklung, Formung des menschlichen Geistes durch Erziehung</s>
# Ergebnis dieses Prozesses Gesamtheit des erworbenen Wissens, Könnens und der inneren Einstellung</s>
# Ergebnis dieses Prozesses Gesamtheit des erworbenen Wissens, Könnens und der inneren Einstellung</s>
# Ergebnis dieses Prozesses Gesamtheit des erworbenen Wissens, Könnens und der inneren Einstellung</s>
# Ergebnis dieses Prozesses Gesamtheit des erworbenen Wissens, Könnens und der inneren Einstellung</s>
# gute Umgangsform, gutes Verhalten</s>
# aus hauptsächlich Mehl, Wasser und Salz gebackenes Nahrungsmittel</s>
# aus hauptsächlich Mehl, Wasser und Salz gebackenes Nahrungsmittel</s>
# aus hauptsächlich Mehl, Wasser und Salz gebackenes Nahrungsmittel</s>
# aus hauptsächlich Mehl, Wasser und Salz gebackenes Nahrungsmittel</s>
# aus hauptsächlich Mehl, Wasser und Salz gebackenes Nahrungsmittel</s>
# aus hauptsächlich Mehl, Wasser und Salz gebackenes Nahrungsmittel</s>
# einzelner Brotlaib</s>
# einzelner Brotlaib</s>
# abgeschnittene Scheibe eines Brotlaibes</s>
# Lebensunterhalt, Lohn, Ertrag</s>
# Lebensunterhalt, Lohn, Ertrag</s>
# allgemein als pars pro toto Nahrung, ein Essen, eine Speise, Kost</s>
# allgemein als pars pro toto Nahrung, ein Essen, eine Speise, Kost</s>
# kaputtgehen (wenn es dabei Splitter oder Brocken erzeugt)</s>
# emotional zutiefst geschädigt werden</s>
# etwas wie bei 1 kaputt machen (zerstören)</s>
# Tier, das unter Wasser lebt und durch Kiemen atmet</s>
# Tier, das unter Wasser lebt und durch Kiemen atmet</s>
# Tier, das unter Wasser lebt und durch Kiemen atmet</s>
# Tier, das unter Wasser lebt und durch Kiemen atmet</s>
# kein Plural Fleisch von 1 als Lebensmittel</s>
# kein Plural Fleisch von 1 als Lebensmittel</s>
# kein Plural Fleisch von 1 als Lebensmittel</s>
# weithin Lichtsignale ausstrahlender Turm an der Küste</s>
# weithin Lichtsignale ausstrahlender Turm an der Küste</s>
# weithin Lichtsignale ausstrahlender Turm an der Küste</s>
# weithin Lichtsignale ausstrahlender Turm an der Küste</s>
# Plural selten anregendes schwarzes Aufgussgetränk</s>
# Plural selten anregendes schwarzes Aufgussgetränk</s>
# Plural selten anregendes schwarzes Aufgussgetränk</s>
# Plural selten anregendes schwarzes Aufgussgetränk</s>
# ohne Plural der Kaffeestrauch (Rubiaceae)</s>
# ohne Plural Gattungsname (Coffea) des Kaffeestrauchs2</s>
# ohne Plural Gattungsname (Coffea) des Kaffeestrauchs2</s>
# bohnenförmiger Samen des Kaffeestrauchs2 elliptisch für Kaffeebohne</s>
# bohnenförmiger Samen des Kaffeestrauchs2 elliptisch für Kaffeebohne</s>
# elliptisch für Röstkaffee, Kaffeepulver</s>
# ohne Plural regional eine zumeist nachmittägliche Zwischenmahlzeit</s>
# veraltend für Gaststätte, in der – zumeist neben einer gewissen Auswahl an Gebäckwaren – Kaffee1 angeboten wird</s>
# dritter Monat des Jahres</s>
# Marktgemeinde in Oberösterreich</s>
# Marktgemeinde in Oberösterreich</s>
# Marktgemeinde in Oberösterreich</s>
# Marktgemeinde in Oberösterreich</s>
# jemandem etwas aufzwingen, aufdrängen</s>
# jemandem etwas aufzwingen, aufdrängen</s>
# ein Gesetz nicht verfassungsgemäß erlassen, eine Verfassung einem Volk aufzwingen</s>
# ein Gesetz nicht verfassungsgemäß erlassen, eine Verfassung einem Volk aufzwingen</s>
# verleihen</s>
# entgegengesetzt, sich widersprechend</s>
# viel und heftig diskutiert</s>
# pferdeartiges Fabeltier mit einem Horn auf der Stirn</s>
# pferdeartiges Fabeltier mit einem Horn auf der Stirn</s>
# pferdeartiges Fabeltier mit einem Horn auf der Stirn</s>
# Sternbild südlich des Himmelsäquators</s>
# etwas werfen, schleudern</s>
# etwas werfen, schleudern</s>
# etwas werfen, schleudern</s>
# etwas aufgeben, misslingen lassen</s>
# etwas spendieren, ausgeben</s>
# etwas erfolgreich durchführen</s>
# dritter Wochentag gemäß ISO 8601Wikipedia ISO 8601 vierter Wochentag nach jüdischer, christlicher und islamischer ZählungWikipedia Reihenfolge der Wochentage Tag zwischen Dienstag und Donnerstag</s>
# dritter Wochentag gemäß ISO 8601Wikipedia ISO 8601 vierter Wochentag nach jüdischer, christlicher und islamischer ZählungWikipedia Reihenfolge der Wochentage Tag zwischen Dienstag und Donnerstag</s>
# dritter Wochentag gemäß ISO 8601Wikipedia ISO 8601 vierter Wochentag nach jüdischer, christlicher und islamischer ZählungWikipedia Reihenfolge der Wochentage Tag zwischen Dienstag und Donnerstag</s>
# dritter Wochentag gemäß ISO 8601Wikipedia ISO 8601 vierter Wochentag nach jüdischer, christlicher und islamischer ZählungWikipedia Reihenfolge der Wochentage Tag zwischen Dienstag und Donnerstag</s>
# dritter Wochentag gemäß ISO 8601Wikipedia ISO 8601 vierter Wochentag nach jüdischer, christlicher und islamischer ZählungWikipedia Reihenfolge der Wochentage Tag zwischen Dienstag und Donnerstag</s>
# dritter Wochentag gemäß ISO 8601Wikipedia ISO 8601 vierter Wochentag nach jüdischer, christlicher und islamischer ZählungWikipedia Reihenfolge der Wochentage Tag zwischen Dienstag und Donnerstag</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# Luftfahrzeug, das schwerer als Luft ist und den aerodynamischen Auftrieb nutzt</s>
# Luftfahrzeug, das schwerer als Luft ist und den aerodynamischen Auftrieb nutzt</s>
# Luftfahrzeug, das schwerer als Luft ist und den aerodynamischen Auftrieb nutzt</s>
# Luftfahrzeug, das schwerer als Luft ist und den aerodynamischen Auftrieb nutzt</s>
# Luftfahrzeug, das schwerer als Luft ist und den aerodynamischen Auftrieb nutzt</s>
# Luftfahrzeug, das schwerer als Luft ist und den aerodynamischen Auftrieb nutzt</s>
# Technik- und Industriebereich, der sich mit der Fortbewegung durch die Luft befasst</s>
# Technik- und Industriebereich, der sich mit der Fortbewegung durch die Luft befasst</s>
# Technik- und Industriebereich, der sich mit der Fortbewegung durch die Luft befasst</s>
# Technik- und Industriebereich, der sich mit der Fortbewegung durch die Luft befasst</s>
# das Fliegen an sich betreffend mit Luftfahrzeugen oder der Flug selbst</s>
# die Reise durch die Luft mit einem Ballon oder Luftschiff</s>
# in den polaren und gemäßigten Breiten vorkommender Abschnitt eines Jahres nach klimatischer bzw. astronomischer Unterteilung nach der scheinbaren Bahn der Sonne am Himmel</s>
# in den polaren und gemäßigten Breiten vorkommender Abschnitt eines Jahres nach klimatischer bzw. astronomischer Unterteilung nach der scheinbaren Bahn der Sonne am Himmel</s>
# in den polaren und gemäßigten Breiten vorkommender Abschnitt eines Jahres nach klimatischer bzw. astronomischer Unterteilung nach der scheinbaren Bahn der Sonne am Himmel</s>
# in den polaren und gemäßigten Breiten vorkommender Abschnitt eines Jahres nach klimatischer bzw. astronomischer Unterteilung nach der scheinbaren Bahn der Sonne am Himmel</s>
# in den polaren und gemäßigten Breiten vorkommender Abschnitt eines Jahres nach klimatischer bzw. astronomischer Unterteilung nach der scheinbaren Bahn der Sonne am Himmel</s>
# in den polaren und gemäßigten Breiten vorkommender Abschnitt eines Jahres nach klimatischer bzw. astronomischer Unterteilung nach der scheinbaren Bahn der Sonne am Himmel</s>
# 1.000.000, eintausend mal eintausend, 106</s>
# 1.000.000, eintausend mal eintausend, 106</s>
# 1.000.000, eintausend mal eintausend, 106</s>
# 1.000.000, eintausend mal eintausend, 106</s>
# 1.000.000, eintausend mal eintausend, 106</s>
# 1.000.000, eintausend mal eintausend, 106</s>
# 1.000.000, eintausend mal eintausend, 106</s>
# eine sehr große unbestimmte Anzahl</s>
# eine sehr große unbestimmte Anzahl</s>
# eine sehr große unbestimmte Anzahl</s>
# Konsonant und vierundzwanzigster Buchstabe des Alphabets</s>
# Konsonant und vierundzwanzigster Buchstabe des Alphabets</s>
# römisches Zahlzeichen für 10 (eigentlich Unicode-Zeichen X, siehe dort)</s>
# im Plural Gruppe der Wissenschaften, die die verschiedenen Gebiete der unbelebten und belebten Natur zum Gegenstand haben</s>
# im Plural Gruppe der Wissenschaften, die die verschiedenen Gebiete der unbelebten und belebten Natur zum Gegenstand haben</s>
# im Plural Gruppe der Wissenschaften, die die verschiedenen Gebiete der unbelebten und belebten Natur zum Gegenstand haben</s>
# im Plural Gruppe der Wissenschaften, die die verschiedenen Gebiete der unbelebten und belebten Natur zum Gegenstand haben</s>
# im Plural Gruppe der Wissenschaften, die die verschiedenen Gebiete der unbelebten und belebten Natur zum Gegenstand haben</s>
# einzelne Wissenschaft, die sich mit einem bestimmten Gegenstand der Natur befasst</s>
# Wissenschaft, die selbstgeschaffene abstrakte Strukturen auf ihre Eigenschaften und Muster untersucht</s>
# Wissenschaft, die selbstgeschaffene abstrakte Strukturen auf ihre Eigenschaften und Muster untersucht</s>
# Wissenschaft, die selbstgeschaffene abstrakte Strukturen auf ihre Eigenschaften und Muster untersucht</s>
# Wissenschaft von der Entwicklung, vom Aufbau und von der Veränderung der Erde einschließlich der diese bewohnenden Lebewesen in der Erdgeschichte</s>
# Wissenschaft von der Entwicklung, vom Aufbau und von der Veränderung der Erde einschließlich der diese bewohnenden Lebewesen in der Erdgeschichte</s>
# Wissenschaft von der Entwicklung, vom Aufbau und von der Veränderung der Erde einschließlich der diese bewohnenden Lebewesen in der Erdgeschichte</s>
# die in den Bereich von 1 fallenden Eigenschaften eines Landstrichs geologischer Aufbau von Kontinenten, Ozeanen und deren Teile *VerzeichnisDeutsch/Geowissenschaften</s>
# anhaltender Redeschwall</s>
# anhaltender Redeschwall</s>
# anhaltender Redeschwall</s>
# anhaltender Redeschwall</s>
# anhaltender Redeschwall</s>
# anhaltender Redeschwall</s>
# Musik eine Strophenform, in der schnell aufeinanderfolgende Töne in einem Lauf gespielt werden</s>
# , Religion eine monotheistische Weltreligion</s>
# , Religion eine monotheistische Weltreligion</s>
# , Religion eine monotheistische Weltreligion</s>
# , Religion eine monotheistische Weltreligion</s>
# , Religion eine monotheistische Weltreligion</s>
# , Religion eine monotheistische Weltreligion</s>
# , Religion eine monotheistische Weltreligion</s>
# eine spezifische Auffassung oder Art von 1</s>
# eine spezifische Auffassung oder Art von 1</s>
# eine spezifische Auffassung oder Art von 1</s>
# eine spezifische Auffassung oder Art von 1</s>
# eine spezifische Auffassung oder Art von 1</s>
# eine spezifische Auffassung oder Art von 1</s>
# Zoologie Wolf</s>
# märkisch, berlinisch, verschliffene Floskel für die eingeschobene, rhetorische Frage Gelt es, Gilt es, Habe ich recht oder Nicht wahr, Stimmt es, um sich der (vorausgesetzten) Zustimmung zu versichern. Die Frage wird nicht oder nur mit der gleichen Floskel beantwortet.</s>
# Nominativ Singular maskulin des Relativpronomens der/die/das</s>
# Personenkraftwagen</s>
# ein Wort, das in einem bestimmten Zusammenhang die gleiche Bedeutung hat wie die eines anderen Wortes, gleichbedeutendes (neuzeitlich auch sinnverwandtes) Wort</s>
# ein Wort, das in einem bestimmten Zusammenhang die gleiche Bedeutung hat wie die eines anderen Wortes, gleichbedeutendes (neuzeitlich auch sinnverwandtes) Wort</s>
# ein Wort, das in einem bestimmten Zusammenhang die gleiche Bedeutung hat wie die eines anderen Wortes, gleichbedeutendes (neuzeitlich auch sinnverwandtes) Wort</s>
# ein Wort, das in einem bestimmten Zusammenhang die gleiche Bedeutung hat wie die eines anderen Wortes, gleichbedeutendes (neuzeitlich auch sinnverwandtes) Wort</s>
# ein Wort, das in einem bestimmten Zusammenhang die gleiche Bedeutung hat wie die eines anderen Wortes, gleichbedeutendes (neuzeitlich auch sinnverwandtes) Wort</s>
# ein Wort, das in einem bestimmten Zusammenhang die gleiche Bedeutung hat wie die eines anderen Wortes, gleichbedeutendes (neuzeitlich auch sinnverwandtes) Wort</s>
# ein Wort, das in einem bestimmten Zusammenhang die gleiche Bedeutung hat wie die eines anderen Wortes, gleichbedeutendes (neuzeitlich auch sinnverwandtes) Wort</s>
# Vertreter einer Gruppe von bestimmten kurzbeinigen Arten der Familie der Hunde (Canidae)</s>
# Vertreter einer Gruppe von bestimmten kurzbeinigen Arten der Familie der Hunde (Canidae)</s>
# männlicher Fuchs1</s>
# Pelz des Fuchses</s>
# Pferd, bei dem Fell, Mähne und Schweif braun sind</s>
# Pferd, bei dem Fell, Mähne und Schweif braun sind</s>
# Pferd, bei dem Fell, Mähne und Schweif braun sind</s>
# Tagfalter (Kleiner Fuchs, Großer Fuchs)</s>
# ein kluger Mensch (schlauer Fuchs)</s>
# ein Rekrut in der Grundausbildung</s>
# Farbe mit einem zusätzlichen Rotton</s>
# die Spielkarte Karo Ass beim Kartenspiel Doppelkopf</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# kleines zweiflügliges Stechinsekt (Diptera, Unterordnung Nematocera), besonders Stechmücke</s>
# kleines zweiflügliges Stechinsekt (Diptera, Unterordnung Nematocera), besonders Stechmücke</s>
# kleines zweiflügliges Stechinsekt (Diptera, Unterordnung Nematocera), besonders Stechmücke</s>
# kleine oder unwichtige Person</s>
# Gemeinde Mücke im Vogelbergskreis in Hessen, Deutschland</s>
# Ort, an dem nichts existiert, Raum, der leer ist</s>
# Ort, an dem nichts existiert, Raum, der leer ist</s>
# Ort, an dem nichts existiert, Raum, der leer ist</s>
# Ort, an dem nichts existiert, Raum, der leer ist</s>
# Ort, an dem nichts existiert, Raum, der leer ist</s>
# Ort, an dem nichts existiert, Raum, der leer ist</s>
# abstrakt, philosophisch Gegenteil von Sein</s>
# abstrakt, philosophisch Gegenteil von Sein</s>
# abstrakt, philosophisch Gegenteil von Sein</s>
# abstrakt, philosophisch Gegenteil von Sein</s>
# abstrakt, philosophisch Gegenteil von Sein</s>
# abwertend, von einer Person jemand ohne Rang und Ansehen</s>
# abwertend, von einer Person jemand ohne Rang und Ansehen</s>
# abwertend, von einer Person jemand ohne Rang und Ansehen</s>
# ausgelaugtes Pulver vom Bohnenkaffee, das nach der Zubereitung zurückbleibt</s>
# ausgelaugtes Pulver vom Bohnenkaffee, das nach der Zubereitung zurückbleibt</s>
# ausgelaugtes Pulver vom Bohnenkaffee, das nach der Zubereitung zurückbleibt</s>
# gehen, sich begeben, fahren, reisen, fliegen, kommen</s>
# die Sprache der Japaner, Landessprache Japans (Versuche, sie einer Sprachfamilie zuzuordnen, sind umstritten)</s>
# die Sprache der Japaner, Landessprache Japans (Versuche, sie einer Sprachfamilie zuzuordnen, sind umstritten)</s>
# die Sprache der Japaner, Landessprache Japans (Versuche, sie einer Sprachfamilie zuzuordnen, sind umstritten)</s>
# die Sprache der Japaner, Landessprache Japans (Versuche, sie einer Sprachfamilie zuzuordnen, sind umstritten)</s>
# die Sprache der Japaner, Landessprache Japans (Versuche, sie einer Sprachfamilie zuzuordnen, sind umstritten)</s>
# die Karthager oder Karthago betreffend, zur Kultur Karthagos gehörend</s>
# die Karthager oder Karthago betreffend, zur Kultur Karthagos gehörend</s>
# ein aus der Antike stammendes Rechenbrett mit Kugeln</s>
# ein aus der Antike stammendes Rechenbrett mit Kugeln</s>
# antikes Spielbrett</s>
# Architektur quadratische Platte am Kopfstück von Säulen</s>
# Kommandostab der Tempelherren</s>
# gehoben, Plural 1 edles Pferd, besonders zum Reiten</s>
# gehoben, Plural 1 edles Pferd, besonders zum Reiten</s>
# gehoben, Plural 1 edles Pferd, besonders zum Reiten</s>
# gehoben, Plural 1 edles Pferd, besonders zum Reiten</s>
# gehoben, Plural 1 edles Pferd, besonders zum Reiten</s>
# Plural 2 Pferd, Hauspferd</s>
# Springer, eine Schachfigur</s>
# Plural 2 schwachsinniger, dummer Mensch</s>
# derb, Plural 2 Mensch mit großer Widerstandskraft und massigem Körperbau</s>
# Gerät zur Beschleunigung von elektrisch geladenen Teilchen auf sehr hohe Geschwindigkeiten</s>
# Gerät zur Beschleunigung von elektrisch geladenen Teilchen auf sehr hohe Geschwindigkeiten</s>
# <unk> l aus pflanzlichen oder tierischen Quellen, das sich zum Braten eignet</s>
# <unk> l aus pflanzlichen oder tierischen Quellen, das sich zum Braten eignet</s>
# <unk> l aus pflanzlichen oder tierischen Quellen, das sich zum Braten eignet</s>
# metallische Legierung, deren Hauptbestandteil Eisen ist der Kohlenstoffgehalt liegt zwischen 0,02% und 2,06%.</s>
# metallische Legierung, deren Hauptbestandteil Eisen ist der Kohlenstoffgehalt liegt zwischen 0,02% und 2,06%.</s>
# metallische Legierung, deren Hauptbestandteil Eisen ist der Kohlenstoffgehalt liegt zwischen 0,02% und 2,06%.</s>
# metallische Legierung, deren Hauptbestandteil Eisen ist der Kohlenstoffgehalt liegt zwischen 0,02% und 2,06%.</s>
# kurze zweischneidige, blanke Stichwaffe (Dolch, Schwert, Messer oder <unk> hnliches)</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# jemandem gewidmet, zugeeignet</s>
# speziell für eine bestimmte Aufgabenstellung geschaffen (entwickelt, eingerichtet, ihr zugeordnet)</s>
# speziell für eine bestimmte Aufgabenstellung geschaffen (entwickelt, eingerichtet, ihr zugeordnet)</s>
# speziell für eine bestimmte Aufgabenstellung geschaffen (entwickelt, eingerichtet, ihr zugeordnet)</s>
# ein bei Stress ausgeschüttetes Hormon des Nebennierenmarks</s>
# ein bei Stress ausgeschüttetes Hormon des Nebennierenmarks</s>
# ein bei Stress ausgeschüttetes Hormon des Nebennierenmarks</s>
# Notfallmedikament bei der Herz-Lungen-Wiederbelebung bei Herzstillstand, dem anaphylaktischen Schock und Vasokonstriktor</s>
# sich ausstrecken, (zum Beispiel im Bett, in der Sonne, am Strand) faulenzen</s>
# sich ausstrecken, (zum Beispiel im Bett, in der Sonne, am Strand) faulenzen</s>
# Aale fangen, auf Aalfang gehen</s>
# (ein Rohr) mit einem Aal lüften und reinigen</s>
# Aalenium</s>
# Auto, dessen Verdeck geöffnet werden kann (Kurzwort für Cabriolet)</s>
# Auto, dessen Verdeck geöffnet werden kann (Kurzwort für Cabriolet)</s>
# ohne Plural eine aus dem Orient kommende Knüpftechnik zur Herstellung von Ornamenten oder Textilien</s>
# ohne Plural eine aus dem Orient kommende Knüpftechnik zur Herstellung von Ornamenten oder Textilien</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# die deutsche Sprache</s>
# ohne Artikel, kurz für Deutschunterricht</s>
# ohne Artikel, kurz für Deutschunterricht</s>
# ohne Artikel, kurz für Deutschunterricht</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# deutschsprachiger Familienname, Nachname</s>
# (Germanismus) die deutsche Sprache</s>
# (Germanismus) die deutsche Sprache</s>
# (Germanismus) die deutsche Sprache</s>
# eine Primzahl, die rückwärts gelesen eine andere Primzahl ergibt</s>
# eine Primzahl, die rückwärts gelesen eine andere Primzahl ergibt</s>
# eine Primzahl, die rückwärts gelesen eine andere Primzahl ergibt</s>
# eine Primzahl, die rückwärts gelesen eine andere Primzahl ergibt</s>
# eine Primzahl, die rückwärts gelesen eine andere Primzahl ergibt</s>
# Interpunktionszeichen, Satzzeichen</s>
# Interpunktionszeichen, Satzzeichen</s>
# Interpunktionszeichen, Satzzeichen</s>
# Interpunktionszeichen, Satzzeichen</s>
# Interpunktionszeichen, Satzzeichen</s>
# Interpunktionszeichen, Satzzeichen</s>
# Trennzeichen in Dezimalzahlen</s>
# kleinere rhythmische Unterteilung der PeriodeGero von Wilpert Sachwörterbuch der Literatur 8., verbesserte und erweiterte Auflage Kröner Stuttgart 2001 ISBN 3-520-23108-5.</s>
# ein kleines Musikintervall als Pythagoreisches Komma</s>
# Wasser, in dem Salz (meist Natriumchlorid) in mehr oder weniger hoher Konzentration gelöst ist</s>
# andere Bezeichnung für Meerwasser (siehe 1)</s>
# andere Bezeichnung für Meerwasser (siehe 1)</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# geschriebene, verschlossene Mitteilung, die (meist gegen Bezahlung) per Post oder Boten verschickt wird</s>
# Kapitalgesellschaft, bei der das Grundkapital in Aktien zerlegt ist</s>
# Kapitalgesellschaft, bei der das Grundkapital in Aktien zerlegt ist</s>
# Kapitalgesellschaft, bei der das Grundkapital in Aktien zerlegt ist</s>
# Kapitalgesellschaft, bei der das Grundkapital in Aktien zerlegt ist</s>
# Militär, Technik Teil eines Unterseebootes, das einen Blick nach draußen ermöglicht</s>
# Militär, Technik Teil eines Unterseebootes, das einen Blick nach draußen ermöglicht</s>
# Anteilsschein am Grundkapital einer Aktiengesellschaft</s>
# Anteilsschein am Grundkapital einer Aktiengesellschaft</s>
# massereiche, selbst leuchtende Gaskugel, Himmelskörper</s>
# jeder Himmelskörper, der dem bloßen Auge punktförmig erscheint</s>
# jeder Himmelskörper, der dem bloßen Auge punktförmig erscheint</s>
# mehrstrahliges oder mehrzackiges Symbol oder Arrangement</s>
# Kosebezeichnung für einen geliebten oder verehrten Menschen</s>
# Kosebezeichnung für einen geliebten oder verehrten Menschen</s>
# Malzeichen auf der Tastatur</s>
# Heck eines Bootes, Schiffes</s>
# Wohngebiet in Potsdam-Drewitz, Potsdam, Brandenburg</s>
# Vertreter einer Tiergruppe der Wirbeltiere mit Flügeln und Federn</s>
# Vertreter einer Tiergruppe der Wirbeltiere mit Flügeln und Federn</s>
# Vertreter einer Tiergruppe der Wirbeltiere mit Flügeln und Federn</s>
# Vertreter einer Tiergruppe der Wirbeltiere mit Flügeln und Federn</s>
# Vertreter einer Tiergruppe der Wirbeltiere mit Flügeln und Federn</s>
# Vertreter einer Tiergruppe der Wirbeltiere mit Flügeln und Federn</s>
# Ausdruck in Redewendungen in Verbindung mit haben für spinnen, verrückt sein</s>
# Ausdruck in Redewendungen in Verbindung mit haben für spinnen, verrückt sein</s>
# Mann</s>
# Flugzeug</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# deutschsprachiger Nachname, Familienname</s>
# Reiz, welche eine Reaktion hervorruft</s>
# Reiz, welche eine Reaktion hervorruft</s>
# etwas, das eine Veranlassung/Motivation darstellt, etwas Bestimmtes zu tun oder zu lassen</s>
# Werkzeug zum Anziehen beziehungsweise zum Lösen von Schrauben</s>
# Werkzeug zum Anziehen beziehungsweise zum Lösen von Schrauben</s>
# allgemein Gerät, das mathematische oder logische Operationen ausführt</s>
# hochtechnologische Rechenmaschine</s>
# hochtechnologische Rechenmaschine</s>
# hochtechnologische Rechenmaschine</s>
# hochtechnologische Rechenmaschine</s>
# hochtechnologische Rechenmaschine</s>
# tragbares technisches Hilfsmittel zur Lösung mathematischer Aufgaben</s>
# tragbares technisches Hilfsmittel zur Lösung mathematischer Aufgaben</s>
# eine Person, die eine Sache genau durchrechnet oder kalkuliert</s>
# eine Person, die eine Sache genau durchrechnet oder kalkuliert</s>
# (Sitz-)Möbel, meist mit vier hohen Beinen, Rückenlehne und eventuell Armlehnen</s>
# (Sitz-)Möbel, meist mit vier hohen Beinen, Rückenlehne und eventuell Armlehnen</s>
# (Sitz-)Möbel, meist mit vier hohen Beinen, Rückenlehne und eventuell Armlehnen</s>
# (Sitz-)Möbel, meist mit vier hohen Beinen, Rückenlehne und eventuell Armlehnen</s>
# (Sitz-)Möbel, meist mit vier hohen Beinen, Rückenlehne und eventuell Armlehnen</s>
# Kot (feste Exkremente)</s>
# Begriff für ein Amt</s>
# überall</s>
# alle angehend</s>
# alle angehend</s>
# unspezifisch</s>
# anderes Wort für Faustregel (eine eingebürgerte ungenaue Regel oder Vorgehensweise, die sich im Laufe der Zeit bewährt hat, aber nicht von Gremien oder Institutionen als allgemeingültige Formel festgesetzt wurde)</s>
# Rechtssprache nach geltendem Recht</s>
# Rechtssprache nach geltendem Recht</s>
# Rechtssprache nach geltendem Recht</s>
# Rechtssprache nach geltendem Recht</s>
# Rechtssprache nach geltendem Recht</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# Vereinbarung zur Unterbrechung der Kämpfe in einem bewaffneten Konflikt – meist um Friedensverhandlungen zu führen</s>
# vor langer Zeit gemacht oder geschehen</s>
# von hohem Alter</s>
# von hohem Alter</s>
# nicht mehr im Amt</s>
# ästhetisch, eine angenehme Wirkung auf die Sinne habend zum Beispiel ein gutes Aussehen habend, sich gut anhörend</s>
# ästhetisch, eine angenehme Wirkung auf die Sinne habend zum Beispiel ein gutes Aussehen habend, sich gut anhörend</s>
# ästhetisch, eine angenehme Wirkung auf die Sinne habend zum Beispiel ein gutes Aussehen habend, sich gut anhörend</s>
# angenehm, gut, anständig</s>
# angenehm, gut, anständig</s>
# angenehm, gut, anständig</s>
# verstärkend im Sinne von beträchtlich</s>
# verstärkend im Sinne von beträchtlich</s>
# zustimmende Antwort auf eine Frage</s>
# so, wie es sich gehört</s>
# so, wie es sich gehört</s>
# Lehre von den grundlegenden Gesetzen der Natur</s>
# Lehre von den grundlegenden Gesetzen der Natur</s>
# ein Unterrichtsfach</s>
# kleine Siedlung, ländlicher Wohnort</s>
# kleine Siedlung, ländlicher Wohnort</s>
# kleine Siedlung, ländlicher Wohnort</s>
# kleine Siedlung, ländlicher Wohnort</s>
# kleine Siedlung, ländlicher Wohnort</s>
# die gesamte Einwohnerschaft eines Dorfes</s>
# umgangssprachlich, abwertend kleine, abgelegene, unbedeutende Ortschaft</s>
# umgangssprachlich, abwertend kleine, abgelegene, unbedeutende Ortschaft</s>
# norddeutsch Spreu</s>
# norddeutsch Spreu</s>
# Einwohner eines Dorfes, der in Bezug auf seine Intelligenz nicht mit anderen mithalten kann und allgemein dafür bekannt ist</s>
# Einwohner eines Dorfes, der in Bezug auf seine Intelligenz nicht mit anderen mithalten kann und allgemein dafür bekannt ist</s>
# Einwohner eines Dorfes, der in Bezug auf seine Intelligenz nicht mit anderen mithalten kann und allgemein dafür bekannt ist</s>
# meist nicht zur Familie gehörende Person, die man gut kennt und die man mag, mit der man gern Umgang hat</s>
# meist nicht zur Familie gehörende Person, die man gut kennt und die man mag, mit der man gern Umgang hat</s>
# etwas oder jemandem angeschlossen oder damit als gewisse Einheit verbunden zusammen</s>
# etwas oder jemandem angeschlossen oder damit als gewisse Einheit verbunden zusammen</s>
# etwas oder jemandem angeschlossen oder damit als gewisse Einheit verbunden zusammen</s>
# unter Ausnutzung, durch die Hilfe von etwas</s>
# unter Ausnutzung, durch die Hilfe von etwas</s>
# unter Ausnutzung, durch die Hilfe von etwas</s>
# beim Kämpfen mit einem Gegner (im Wettkampf mit) gegen</s>
# beim Kämpfen mit einem Gegner (im Wettkampf mit) gegen</s>
# wie andere, zusammen mit anderen</s>
# rotierender, mit kleinen Spiegelplatten beklebter Ball, der meist als Lichteffekt in Diskotheken verwendet, indem er mit einem Punktstrahler beleuchtet wird und Punkte in den Raum reflektiert</s>
# rotierender, mit kleinen Spiegelplatten beklebter Ball, der meist als Lichteffekt in Diskotheken verwendet, indem er mit einem Punktstrahler beleuchtet wird und Punkte in den Raum reflektiert</s>
# rotierender, mit kleinen Spiegelplatten beklebter Ball, der meist als Lichteffekt in Diskotheken verwendet, indem er mit einem Punktstrahler beleuchtet wird und Punkte in den Raum reflektiert</s>
# Aufhänger für Kleidung, meist in Form eines gleichschenkligen Dreiecks mit einem Haken</s>
# Aufhänger für Kleidung, meist in Form eines gleichschenkligen Dreiecks mit einem Haken</s>
# Aufhänger für Kleidung, meist in Form eines gleichschenkligen Dreiecks mit einem Haken</s>
# Volumen, das von einem Rand umgeben wird, dessen Punkte alle den gleichen Abstand von einem Punkt (Mittelpunkt) besitzen</s>
# Volumen, das von einem Rand umgeben wird, dessen Punkte alle den gleichen Abstand von einem Punkt (Mittelpunkt) besitzen</s>
# allgemein dreidimensionales rundes Objekt, im Gegensatz zum Ball meist hart</s>
# allgemein dreidimensionales rundes Objekt, im Gegensatz zum Ball meist hart</s>
# allgemein dreidimensionales rundes Objekt, im Gegensatz zum Ball meist hart</s>
# Objekt, das von Schusswaffen abgefeuert wird</s>
# Objekt, das von Schusswaffen abgefeuert wird</s>
# Objekt, das von Schusswaffen abgefeuert wird</s>
# Objekt, das von Schusswaffen abgefeuert wird</s>
# Objekt, das von Schusswaffen abgefeuert wird</s>
# wiederverwendbarer Behälter für Milch, meist aus Metall mit Henkel</s>
# wiederverwendbarer Behälter für Milch, meist aus Metall mit Henkel</s>
# wiederverwendbarer Behälter für Milch, meist aus Metall mit Henkel</s>
# wiederverwendbarer Behälter für Milch, meist aus Metall mit Henkel</s>
# wiederverwendbarer Behälter für Milch, meist aus Metall mit Henkel</s>
# zum Verzehr vorgesehene Flüssigkeit</s>
# zum Verzehr vorgesehene Flüssigkeit</s>
# grobes Steinmaterial, welches zum Auffüllen verwendet wird (zum Beispiel kantige Steine für die Trasse beim Gleisbau) oder in der Natur vorkommt (zum Beispiel gerundete Steine in einem Bachbett)</s>
# grobes Steinmaterial, welches zum Auffüllen verwendet wird (zum Beispiel kantige Steine für die Trasse beim Gleisbau) oder in der Natur vorkommt (zum Beispiel gerundete Steine in einem Bachbett)</s>
# grobes Steinmaterial, welches zum Auffüllen verwendet wird (zum Beispiel kantige Steine für die Trasse beim Gleisbau) oder in der Natur vorkommt (zum Beispiel gerundete Steine in einem Bachbett)</s>
# grobes Steinmaterial, welches zum Auffüllen verwendet wird (zum Beispiel kantige Steine für die Trasse beim Gleisbau) oder in der Natur vorkommt (zum Beispiel gerundete Steine in einem Bachbett)</s>
# Geld</s>
# Geld</s>
# Milch, die nur pasteurisiert ist</s>
# eine im Euter einer Kuh produzierte Milch</s>
# eine im Euter einer Kuh produzierte Milch</s>
# aus verdickter Milch hergestellte süße Masse</s>
# aus verdickter Milch hergestellte süße Masse</s>
# aus verdickter Milch hergestellte süße Masse</s>
# antreibende Maschine</s>
# antreibende Maschine</s>
# antreibende Maschine</s>
# etwas oder jemand, der etwas voranbringt Antreiber, treibende Kraft</s>
# etwas oder jemand, der etwas voranbringt Antreiber, treibende Kraft</s>
# etwas oder jemand, der etwas voranbringt Antreiber, treibende Kraft</s>
# dem Frosch ähnliche, kurzbeinige, springende Amphibie mit plumpem Körper und warzenbedeckter, Giftstoffe absondernder Haut</s>
# dem Frosch ähnliche, kurzbeinige, springende Amphibie mit plumpem Körper und warzenbedeckter, Giftstoffe absondernder Haut</s>
# dem Frosch ähnliche, kurzbeinige, springende Amphibie mit plumpem Körper und warzenbedeckter, Giftstoffe absondernder Haut</s>
# Schimpfwort für ein freches Kind</s>
# nur Plural Geld oder Bargeld</s>
# Turm mit Sendeanlagen für Hörfunk und Fernsehen</s>
# Turm mit Sendeanlagen für Hörfunk und Fernsehen</s>
# Turm mit Sendeanlagen für Hörfunk und Fernsehen</s>
# Turm mit Sendeanlagen für Hörfunk und Fernsehen</s>
# Turm mit Sendeanlagen für Hörfunk und Fernsehen</s>
# Turm mit Sendeanlagen für Hörfunk und Fernsehen</s>
# Turm mit Sendeanlagen für Hörfunk und Fernsehen</s>
# Turm in einer Kohlegrube mit Stahlseil und großem Umlenkrad zum Heben und Senken eines Förderkorbes</s>
# Turm mit Pumpe, zum Fördern von Erdöl verwendet</s>
# altertümlich Gefängnis</s>
# hohes, schlankes Gebäude zur drahtlosen Übermittlung von Informationen</s>
# hohes, schlankes Gebäude zur drahtlosen Übermittlung von Informationen</s>
# militärisch zu Beobachtungs- und Verteidigungszwecken errichteter, schwer zugänglicher Turm</s>
# militärisch zu Beobachtungs- und Verteidigungszwecken errichteter, schwer zugänglicher Turm</s>
# militärisch zu Beobachtungs- und Verteidigungszwecken errichteter, schwer zugänglicher Turm</s>
# getrocknetes Gras in der Sprache der Landwirtschaft insbesondere der erste Grasschnitt</s>
# getrocknetes Gras in der Sprache der Landwirtschaft insbesondere der erste Grasschnitt</s>
# getrocknetes Gras in der Sprache der Landwirtschaft insbesondere der erste Grasschnitt</s>
# getrocknetes Gras in der Sprache der Landwirtschaft insbesondere der erste Grasschnitt</s>
# getrocknetes Gras in der Sprache der Landwirtschaft insbesondere der erste Grasschnitt</s>
# getrocknetes Gras in der Sprache der Landwirtschaft insbesondere der erste Grasschnitt</s>
# reichlich Geld</s>
# Jargon Marihuana</s>
# eine sanitäre Vorrichtung oder Anlage zur Aufnahme von Körperausscheidungen</s>
# eine sanitäre Vorrichtung oder Anlage zur Aufnahme von Körperausscheidungen</s>
# eine sanitäre Vorrichtung oder Anlage zur Aufnahme von Körperausscheidungen</s>
# eine sanitäre Vorrichtung oder Anlage zur Aufnahme von Körperausscheidungen</s>
# eine sanitäre Vorrichtung oder Anlage zur Aufnahme von Körperausscheidungen</s>
# das Sich-zurecht-Machen (Körperreinigung, Körperpflege und Ankleiden)</s>
# das Sich-zurecht-Machen (Körperreinigung, Körperpflege und Ankleiden)</s>
# das Sich-zurecht-Machen (Körperreinigung, Körperpflege und Ankleiden)</s>
# das Sich-zurecht-Machen (Körperreinigung, Körperpflege und Ankleiden)</s>
# festliche Kleidung (meist der Frauen)</s>
# festliche Kleidung (meist der Frauen)</s>
# festliche Kleidung (meist der Frauen)</s>
# ein Kosmetiktisch oder Frisiertisch</s>
# allgemein sechzigster Teil einer Minute Grundeinheit der Zeit</s>
# allgemein sechzigster Teil einer Minute Grundeinheit der Zeit</s>
# allgemein sechzigster Teil einer Minute Grundeinheit der Zeit</s>
# allgemein sechzigster Teil einer Minute Grundeinheit der Zeit</s>
# allgemein sechzigster Teil einer Minute Grundeinheit der Zeit</s>
# zweite Tonstufe das Intervall zwischen zwei benachbarten Tonstufen</s>
# Winkelmaß Der 60. Teil einer (Bogen-)Minute = der 3600. Teil eines Grads (siehe Bogensekunde)</s>
# sehr schnelles Pferd, das speziell für den Einsatz bei Pferderennen gezüchtet wird</s>
# sehr schnelles Pferd, das speziell für den Einsatz bei Pferderennen gezüchtet wird</s>
# sehr schnelles Pferd, das speziell für den Einsatz bei Pferderennen gezüchtet wird</s>
# etwas, das nicht mehr zu übertreffen ist, das Allerbeste</s>
# etwas, das nicht mehr zu übertreffen ist, das Allerbeste</s>
# die Mitte, der Mittelpunkt eines zweidimensionalen oder dreidimensionalen Gegenstandes, einer Figur, einer Fläche oder eines lebenden Wesens</s>
# die Mitte, der Mittelpunkt eines zweidimensionalen oder dreidimensionalen Gegenstandes, einer Figur, einer Fläche oder eines lebenden Wesens</s>
# die Mitte, der Mittelpunkt eines zweidimensionalen oder dreidimensionalen Gegenstandes, einer Figur, einer Fläche oder eines lebenden Wesens</s>
# zentrale oder wichtige Einrichtung einer Institution oder Organisation Gebäudekomplex, in dem sich viele gleichgeartete Dienste/Angebote/Zuständigkeiten finden</s>
# zentrale oder wichtige Einrichtung einer Institution oder Organisation Gebäudekomplex, in dem sich viele gleichgeartete Dienste/Angebote/Zuständigkeiten finden</s>
# Deutsche Zentrumspartei, politische Partei mit katholizistischem Schwerpunkt</s>
# politische Kräfte, die eine mittlere Linie verfechten</s>
# die Felder d4, d5, e4, e5 auf einem Schachbrett</s>
# Militär militärische Auseinandersetzung am Himmel, an der mindestens zwei Flugzeuge beteiligt sind</s>
# Militär militärische Auseinandersetzung am Himmel, an der mindestens zwei Flugzeuge beteiligt sind</s>
# Militär militärische Auseinandersetzung am Himmel, an der mindestens zwei Flugzeuge beteiligt sind</s>
# Militär militärische Auseinandersetzung am Himmel, an der mindestens zwei Flugzeuge beteiligt sind</s>
# Geruch betreffend widerwärtig, ekelhaft, bestialisch</s>
# gehoben Ausdruck für Applaus, Beifall, Dank</s>
# gehoben Ausdruck für Applaus, Beifall, Dank</s>
# gehoben Ausdruck für Applaus, Beifall, Dank</s>
# Politik und Recht eine Form der Wahl, bei der per Zuruf oder Handzeichen angenommen oder abgelehnt wird</s>
# nicht eindeutig/einheitlich, hin und her gerissen</s>
# nicht eindeutig/einheitlich, hin und her gerissen</s>
# nicht eindeutig/einheitlich, hin und her gerissen</s>
# Wissenschaftler, der die Verhaltensweisen von Tieren und Menschen studiert und beschreibt</s>
# Wissenschaftler, der die Verhaltensweisen von Tieren und Menschen studiert und beschreibt</s>
# Wissenschaftler, der die Verhaltensweisen von Tieren und Menschen studiert und beschreibt</s>
# ...
# einen rechten Winkel bildend</s>
# einen rechten Winkel bildend</s>
# Steigerung selten, von aufrechter, rechtschaffener Gesinnung</s>
# Steigerung selten, von aufrechter, rechtschaffener Gesinnung</s>
# Steigerung selten, von aufrechter, rechtschaffener Gesinnung</s>
# umgangssprachlich, abwertend verweichlichter, unmännlicher, weibischer oder übervorsichtiger Mann</s>
# umgangssprachlich, abwertend verweichlichter, unmännlicher, weibischer oder übervorsichtiger Mann</s>
# umgangssprachlich, abwertend verweichlichter, unmännlicher, weibischer oder übervorsichtiger Mann</s>
# umgangssprachlich, abwertend verweichlichter, unmännlicher, weibischer oder übervorsichtiger Mann</s>
# in einem bewaffneten Konflikt/im Krieg hinter der Truppe (auch aus vorgetäuschter Entkräftung) zurückbleiben und plündernd umherziehen</s>
# in einem bewaffneten Konflikt/im Krieg hinter der Truppe (auch aus vorgetäuschter Entkräftung) zurückbleiben und plündernd umherziehen</s>
# in einem bewaffneten Konflikt/im Krieg hinter der Truppe (auch aus vorgetäuschter Entkräftung) zurückbleiben und plündernd umherziehen</s>
# um sich greifen sich ausbreiten</s>
# um sich greifen sich ausbreiten</s>
# um sich greifen sich ausbreiten</s>
# Sprache der Albaner (Landessprache von Albanien und Kosovo)</s>
# Sprache der Albaner (Landessprache von Albanien und Kosovo)</s>
# Sprache der Albaner (Landessprache von Albanien und Kosovo)</s>
# Sprache der Albaner (Landessprache von Albanien und Kosovo)</s>
# kaukasisch Albanisch (oder Aluanisch, Aghwanisch, Agwanisch, Alwanisch), Sprache des antiken kaukasischen Albanias, die durch Inschriften und ein Lektionar bezeugt ist und dem Udischen nahe steht oder dessen Vorläufer ist</s>
# professioneller Zeichner japanischer Comics (Manga)</s>
# professionelle Zeichnerin japanischer Comics (Manga)</s>
# eine religiöse Konfession, etwa Ahmad<unk> tum</s>
# eine religiöse Konfession, etwa Ahmad<unk> tum</s>
# eine religiöse Konfession, etwa Ahmad<unk> tum</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# negative oder unerwünschte Folge oder negativer Nebeneffekt, zum Beispiel einer Lösung, eines Vorgehens, einer Überlegung</s>
# etwas zu tun vermögen</s>
# etwas zu tun vermögen</s>
# durch bestimmte Umstände die Möglichkeit haben, etwas zu tun</s>
# durch bestimmte Umstände die Möglichkeit haben, etwas zu tun</s>
# durch bestimmte Umstände die Möglichkeit haben, etwas zu tun</s>
# aufgrund bestimmter Gegebenheiten zu einem Verhalten berechtigt sein</s>
# aufgrund bestimmter Gegebenheiten zu einem Verhalten berechtigt sein</s>
# sofern es erlaubt ist, die Möglichkeit haben, etwas zu tun (schwächere Form als dürfen)</s>
# sofern es erlaubt ist, die Möglichkeit haben, etwas zu tun (schwächere Form als dürfen)</s>
# unter Umständen in Betracht kommen, vielleicht der Fall sein</s>
# unter Umständen in Betracht kommen, vielleicht der Fall sein</s>
# von Zeit zu Zeit etwas zu tun vermögen</s>
# von Zeit zu Zeit etwas zu tun vermögen</s>
# meist im Konjunktiv etwas auf Wunsch einer anderen Person tun sollen</s>
# meist im Konjunktiv etwas auf Wunsch einer anderen Person tun sollen</s>
# etwas beherrschen, wissen fähig sein, etwas zu tun</s>
# etwas beherrschen, wissen fähig sein, etwas zu tun</s>
# etwas beherrschen, wissen fähig sein, etwas zu tun</s>
# auf eine bestimmte Art und Weise zu etwas in der Lage sein</s>
# auf eine bestimmte Art und Weise zu etwas in der Lage sein</s>
# auf eine bestimmte Art und Weise zu etwas in der Lage sein</s>
# die Erlaubnis, die Möglichkeit haben, etwas tun zu dürfen</s>
# umgangssprachlich noch die nötige Kraft für etwas haben</s>
# Didaktik durch Handlungen (Wissen erschließend)</s>
# Didaktik durch Handlungen (Wissen erschließend)</s>
# Didaktik durch Handlungen (Wissen erschließend)</s>
# Didaktik durch Handlungen (Wissen erschließend)</s>
# Didaktik durch Handlungen (Wissen erschließend)</s>
# vielleicht</s>
# vielleicht</s>
# vulgärlateinisch</s>
# Abfolge von Bildern Film</s>
# ohne Plural, Kunst Film, Filmkunst, Kinematografie</s>
# Technik Band auf dem 1 aufgezeichnet ist Film, Filmband</s>
# Fotografie Film</s>
# dünne Schicht von etwas</s>
# Material für die Fotografie von statischen Bildern</s>
# Abfolge von bewegten Bildern</s>
# lichtempfindlicher oder entwickelter Streifen Film</s>
# Kinematografie zur audiovisuellen Vorführung bestimmtes schöpferisches Werk Film</s>
# dünner Überzug Film</s>
# Einheitensymbol für Nanometer. 1 nm = 10<unk> 9 m.</s>
# Einheitensymbol für Pikometer. 1 pm = 10-12 m.</s>
# Festmeter</s>
# Festmeter</s>
# Materie im gasförmigen Aggregatzustand nicht Festkörper oder Flüssigkeit</s>
# Materie im gasförmigen Aggregatzustand nicht Festkörper oder Flüssigkeit</s>
# Materie im gasförmigen Aggregatzustand nicht Festkörper oder Flüssigkeit</s>
# Materie im gasförmigen Aggregatzustand nicht Festkörper oder Flüssigkeit</s>
# das Gaspedal in Kraftfahrzeugen (und damit verbunden der Vorgang, dass ein Luft-Gas-Gemisch in den Zylinder gelangt und so in Antrieb/Tempo umgesetzt wird)</s>
# das Gaspedal in Kraftfahrzeugen (und damit verbunden der Vorgang, dass ein Luft-Gas-Gemisch in den Zylinder gelangt und so in Antrieb/Tempo umgesetzt wird)</s>
# das Gaspedal in Kraftfahrzeugen (und damit verbunden der Vorgang, dass ein Luft-Gas-Gemisch in den Zylinder gelangt und so in Antrieb/Tempo umgesetzt wird)</s>
# innerste, glänzende Schicht bestimmter Schalen bildender Mollusken, etwa Perlmuscheln und Seeschnecken</s>
# innerste, glänzende Schicht bestimmter Schalen bildender Mollusken, etwa Perlmuscheln und Seeschnecken</s>
# innerste, glänzende Schicht bestimmter Schalen bildender Mollusken, etwa Perlmuscheln und Seeschnecken</s>
# innerste, glänzende Schicht bestimmter Schalen bildender Mollusken, etwa Perlmuscheln und Seeschnecken</s>
# innerste, glänzende Schicht bestimmter Schalen bildender Mollusken, etwa Perlmuscheln und Seeschnecken</s>
# blühende Pflanze</s>
# blühende Pflanze</s>
# blühende Pflanze</s>
# blühende Pflanze</s>
# blühende Pflanze</s>
# Schaumkrone auf einem gefüllten Bierglas</s>
# Schwanz eines Hasen oder eines Kaninchens</s>
# typischer Geruch eines Weines</s>
# allgemein für Grünpflanze (auch nicht blühende)</s>
# Einheitssymbol für Quadratmikrometer</s>
# Telekommunikationsdienst zur Übermittlung kurzer Textnachrichten</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# eine über das Mobilfunknetz durch den in 1 erwähnten Dienst versandte Kurznachricht</s>
# ein durch Sinneswahrnehmung oder gefühlsmäßig gewonnener Eindruck</s>
# kugelförmiges, aus weichem Material bestehendes Objekt</s>
# kugelförmiges, aus weichem Material bestehendes Objekt</s>
# kugelförmiges, aus weichem Material bestehendes Objekt</s>
# die Art, wie dieses gespielt wird</s>
# festliche Veranstaltung, gesellschaftliches Ereignis meist mit Tanz</s>
# festliche Veranstaltung, gesellschaftliches Ereignis meist mit Tanz</s>
# festliche Veranstaltung, gesellschaftliches Ereignis meist mit Tanz</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Nachname, Familienname</s>
# Gerät zum Befüllen eines geschlossenen Behälters (z.&nbspB. eines Reifens) mit Luft</s>
# Gerät zum Befüllen eines geschlossenen Behälters (z.&nbspB. eines Reifens) mit Luft</s>
# kein Plural, Astronomie ein Sternbild des südlichen Sternenhimmels</s>
# mündliche oder schriftliche Folge von Sätzen, die miteinander syntaktisch und semantisch verbunden sind (Kohärenz, Kohäsion), eine abgeschlossene Einheit bilden (Kompletion) und eine bestimmte kommunikative Funktion (Textfunktion) erfüllen</s>
# mündliche oder schriftliche Folge von Sätzen, die miteinander syntaktisch und semantisch verbunden sind (Kohärenz, Kohäsion), eine abgeschlossene Einheit bilden (Kompletion) und eine bestimmte kommunikative Funktion (Textfunktion) erfüllen</s>
# mündliche oder schriftliche Folge von Sätzen, die miteinander syntaktisch und semantisch verbunden sind (Kohärenz, Kohäsion), eine abgeschlossene Einheit bilden (Kompletion) und eine bestimmte kommunikative Funktion (Textfunktion) erfüllen</s>
# mündliche oder schriftliche Folge von Sätzen, die miteinander syntaktisch und semantisch verbunden sind (Kohärenz, Kohäsion), eine abgeschlossene Einheit bilden (Kompletion) und eine bestimmte kommunikative Funktion (Textfunktion) erfüllen</s>
# Sprachinformation (zum Beispiel in einem Buch, Lied oder Film) 2a Sprachinformation in einem Lied 2b Sprachinformation in einem Film</s>
# zum Volk der Deutschen (auch historisch) gehörig</s>
# zum Volk der Deutschen (auch historisch) gehörig</s>
# zum Volk der Deutschen (auch historisch) gehörig</s>
# zum Volk der Deutschen (auch historisch) gehörig</s>
# zum Volk der Deutschen (auch historisch) gehörig</s>
# zu Deutschland gehörig</s>
# zu Deutschland gehörig</s>
# zur Sprache Deutsch gehörig</s>
# zur Sprache Deutsch gehörig</s>
# zur Sprache Deutsch gehörig</s>
# eintönig, uninteressant</s>
# eintönig, uninteressant</s>
# eintönig, uninteressant</s>
# eintönig, uninteressant</s>
# eintönig, uninteressant</s>
# Gefäß (Eimer) zur Aufbewahrung und/oder zum Transport von Wasser</s>
# Gefäß (Eimer) zur Aufbewahrung und/oder zum Transport von Wasser</s>
# Gefäß (Eimer) zur Aufbewahrung und/oder zum Transport von Wasser</s>
# aufblasbarer Ball, der zum Im-Wasser-Spielen verwendet wird</s>
# nur Singular Sportart, die mit 1 gespielt wird</s>
# plötzliches Eindringen von Wasser</s>
# plötzliches Eindringen von Wasser</s>
# plötzliches Eindringen von Wasser</s>
# Medizin zu hohe Blutfettwerte</s>
# ein Trinkgefäß, das zum Trinken von Wasser dient</s>
# ein Trinkgefäß, das zum Trinken von Wasser dient</s>
# ein Trinkgefäß, das zum Trinken von Wasser dient</s>
# ein Trinkgefäß, das zum Trinken von Wasser dient</s>
# ein Trinkgefäß, das zum Trinken von Wasser dient</s>
# ein Alkalisilikat Natriumsilikat oder Kaliumsilikat</s>
# im Wasser lebendes Nagetier</s>
# Mensch, der sich sehr gerne im Wasser aufhält</s>
# Mensch, der sich sehr gerne im Wasser aufhält</s>
# Stern- und Himmelskunde als exakte Naturwissenschaft Astronomie</s>
# Ereignis, bei dem der Mond die Sonne verdunkelt</s>
# Ereignis, bei dem der Mond die Sonne verdunkelt</s>
# Ereignis, bei dem der Mond die Sonne verdunkelt</s>
# Ereignis, bei dem der Mond die Sonne verdunkelt</s>
# Hammer</s>
# hämmern</s>
# die Einbeziehung, Eingliederung in ein größeres Ganzes</s>
# Berechnung der Stammfunktion Umkehrung der Ableitung</s>
# die Einbeziehung, die Einbindung von Personen, sozialen Gruppen, Körperschaften, die Verschmelzung von sozialen Gruppen und Körperschaften</s>
# die Einbeziehung, die Einbindung von Personen, sozialen Gruppen, Körperschaften, die Verschmelzung von sozialen Gruppen und Körperschaften</s>
# die Einbeziehung, die Einbindung von Personen, sozialen Gruppen, Körperschaften, die Verschmelzung von sozialen Gruppen und Körperschaften</s>
# die Einbeziehung, die Einbindung von Personen, sozialen Gruppen, Körperschaften, die Verschmelzung von sozialen Gruppen und Körperschaften</s>
# die Einbeziehung, die Einbindung von Personen, sozialen Gruppen, Körperschaften, die Verschmelzung von sozialen Gruppen und Körperschaften</s>
# die Einbeziehung, die Einbindung von Personen, sozialen Gruppen, Körperschaften, die Verschmelzung von sozialen Gruppen und Körperschaften</s>
# in der Politik und in der Geschichte die Schaffung eines einheitlichen Marktgebiets, Staaten- oder Staatsgebietes</s>
# in der Politik und in der Geschichte die Schaffung eines einheitlichen Marktgebiets, Staaten- oder Staatsgebietes</s>
# in der Politik und in der Geschichte die Schaffung eines einheitlichen Marktgebiets, Staaten- oder Staatsgebietes</s>
# die Verschmelzung von verschiedenen Sprachen und Dialekten zu einer einheitlichen Sprache</s>
# die Verknüpfung unterschiedlicher Anwendungsprogramme</s>
# Tornado (Windhose) auf dem Wasser</s>
# Tornado (Windhose) auf dem Wasser</s>
# allgemeine Bezeichnung für ein im Wasser lebendes Tier</s>
# allgemein im Wasser lebende Schlangenart</s>
# Sternbild</s>
# Abstimmung der wahlberechtigten Bevölkerung über ein wichtiges politisches Thema</s>
# Abstimmung der wahlberechtigten Bevölkerung über ein wichtiges politisches Thema</s>
# Abstimmung der wahlberechtigten Bevölkerung über ein wichtiges politisches Thema</s>
# salopp sich einer ruhigen, beherrschten Aktion oder Art entsprechend verhaltend</s>
# salopp sich einer ruhigen, beherrschten Aktion oder Art entsprechend verhaltend</s>
# salopp sich einer ruhigen, beherrschten Aktion oder Art entsprechend verhaltend</s>
# salopp sich einer ruhigen, beherrschten Aktion oder Art entsprechend verhaltend</s>
# sehr positiv, gut, der Idealvorstellung entsprechend (vor allem im jugendlichen Sprachgebrauch)</s>
# sehr positiv, gut, der Idealvorstellung entsprechend (vor allem im jugendlichen Sprachgebrauch)</s>
# sehr positiv, gut, der Idealvorstellung entsprechend (vor allem im jugendlichen Sprachgebrauch)</s>
# sehr positiv, gut, der Idealvorstellung entsprechend (vor allem im jugendlichen Sprachgebrauch)</s>
# sehr positiv, gut, der Idealvorstellung entsprechend (vor allem im jugendlichen Sprachgebrauch)</s>
# salopp zu einer ruhigen, beherrschten Aktion oder Art</s>
# sehr positiv, gut, der Idealvorstellung entsprechend (vor allem im jugendlichen Sprachgebrauch)</s>
# kühl</s>
# Art, Typ cool, ruhig, beherrscht</s>
# für einen Job, Typ, eine CD, Musik oder <unk> hnliches sympathisch</s>
# sehr positiv, gut, der Idealvorstellung entsprechend (vor allem im jugendlichen Sprachgebrauch)</s>
# komplexe Waffe mit mehreren Komponenten</s>
# Kombination von Waffen zu einer Einheit</s>
# Online-Medium weltweites, öffentliches Computernetzwerk</s>
# Online-Medium weltweites, öffentliches Computernetzwerk</s>
# Online-Medium weltweites, öffentliches Computernetzwerk</s>
# Online-Medium weltweites, öffentliches Computernetzwerk</s>
# Online-Medium weltweites, öffentliches Computernetzwerk</s>

# %%
input_ids
# Out:
# tensor([[ 6634,    10,  7974,    74, 26082,    35,   736,    17,     7, 19107,
#            736,  3272,  2499,   436,   319,   411,  3522,    32,    64,  2262,
#           3484,    63,  9903, 30180,     5,  8262,     3,    23,  8919, 11589,
#              9,    89,  9629,     9,     7,   229,   736,  3272,  2499,  2800,
#           7537,     7,     3, 13392,    16, 22655,   587,  5704,    23,     9,
#            401, 22093, 12711,  1923,     9, 17801,     3, 18007,   551,     6,
#            211,   211,  1480,    77,  2014, 12503,   346,    17,  8533,     6,
#              3,   547,   736,  3272,  2499,  1834,  7367, 19102,     5,  2751,
#            229,    67, 15476,   193,    96,  8123,  3272,  2499,   121,    58,
#              1]], device='cuda:0')

# %%
torch.tensor(datapoint['input_ids']).to('cuda')
# Out:
# tensor([ 6634,    10,  7974,    74, 26082,    35,   736,    17,     7, 19107,
#           736,  3272,  2499,   436,   319,   411,  3522,    32,    64,  2262,
#          3484,    63,  9903, 30180,     5,  8262,     3,    23,  8919, 11589,
#             9,    89,  9629,     9,     7,   229,   736,  3272,  2499,  2800,
#          7537,     7,     3, 13392,    16, 22655,   587,  5704,    23,     9,
#           401, 22093, 12711,  1923,     9, 17801,     3, 18007,   551,     6,
#           211,   211,  1480,    77,  2014, 12503,   346,    17,  8533,     6,
#             3,   547,   736,  3272,  2499,  1834,  7367, 19102,     5,  2751,
#           229,    67, 15476,   193,    96,  8123,  3272,  2499,   121,    58,
#             1], device='cuda:0')

# %%
tokenizer.decode(datapoint['labels'], skip_special_tokens=True)
# Out:
# 'semitische, genauer äthiosemitische Sprache der Amharen, die vor allem in thiopien und Eritrea gesprochen wird'

# %%
tokenizer.decode(dataset_val[200]['input_ids'], skip_special_tokens=True)
# Out:
# 'Westfälische Kürassiere verfolgten die russischen Reiter. Was ist die Definition von "Kürassiere"?'

# %%
dataset_val[200]['gt']
# Out:
# 'im 15. bis 19.\u2002Jahrhundert ein Soldat der schweren Reiterei der einen Kürass (Brustpanzer) trägt; neben den Lanzierern die älteste Gattung der frühneuzeitlichen Kavallerie'

# %%
sanitize_context(dataset_val[200]['gt'])
# Out:
# 'im 15. bis 19.\u2002Jahrhundert ein Soldat der schweren Reiterei der einen Kürass (Brustpanzer) trägt neben den Lanzierern die älteste Gattung der frühneuzeitlichen Kavallerie'
