# %%
import sys

sys.path.insert(0, '../')

from src.utils import ModelInformation
from src.mlflow_utils import mlflow, download_run_data
import re
import pandas as pd
import numpy as np
import json

# %%
def sample_to_sw(sample, model_information: ModelInformation):
    ret_dict = {"model_information": model_information.to_dict()}
    selection = sample[['title', 'context_sentence', 'context_word', 'gt', 'prediction']].to_dict(orient='split')
    ret_dict.update(selection)
    return ret_dict

statistic_fns = {
    "Average": pd.Series.mean,
    "StdDev": pd.Series.std,
    "Median": pd.Series.median,
    "Max": pd.Series.max,
    "Min": pd.Series.min,
}


def calc_statistics(df):
    stats = dict()
    for column in df.columns[5:]:
        for k, v in statistic_fns.items():
            stats[(column, k)] = v(df[column])
    return stats

# %%
selected_runs = [# ModelInformation("wiktionary", "2bba85fab20b4ed6a1a89b0503fd5274", "rep-penality=1.5"),
                 ModelInformation("wiktionary", "a8fa79a989fc4a9fb7c876be01ac42d2", "rep-penality=1.5"),
                 ModelInformation("distillation", "d0a3f0265f404e48a07b56d7dc9e3f1b", "rep-penality=1.5")
                ]

# %%
selected_runs = tuple(set(selected_runs))
exports = []

for run in selected_runs:
    artifacts = mlflow.artifacts.list_artifacts(run_id=run.name)
    for artifact in artifacts:
        if artifact_name := re.match(r"evaluation_[0-9a-z]*.json", artifact.path):
            artifact_name = artifact_name.group(0)
            evaluation_data = download_run_data(run.name, artifact_name)
            if not evaluation_data:
                raise RuntimeError(f"Could not download evaluation data for run {run}")

            collected_data = pd.DataFrame(data=evaluation_data['data'], columns=evaluation_data['columns'])
            sample = collected_data.sample(frac=0.01, random_state=42)
            res = sample_to_sw(sample, run)
            exports.append((run, sample))
            with open(f"export/export_{run.name}_{run.type}.json", "w+") as file:
                json.dump(res, file)

# %%
exports[0]
# Out:
# {'model_information': {'type': 'distillation',
#   'name': 'd0a3f0265f404e48a07b56d7dc9e3f1b',
#   'example_prompt': 'rep-penality=1.5',
#   'question_prompt': '',
#   'system_prompt': ''},
#  'index': [7104,
#   18986,
#   20011,
#   11052,
#   29716,
#   5183,
#   31333,
#   11227,
#   32933,
#   14358,
#   31959,
#   12802,
#   24742,
#   3510,
#   6049,
#   27888,
#   10475,
#   25715,
#   20077,
#   1045,
#   15416,
#   25063,
#   19526,
#   10217,
#   19793,
#   17964,
#   31540,
#   9254,
#   12957,
#   566,
#   19562,
#   17808,
#   30671,
#   28738,
#   10951,
#   18049,
#   24793,
#   12238,
#   22037,
#   16171,
#   3507,
#   9584,
#   9430,
#   30083,
#   9899,
#   25132,
#   29845,
#   6138,
#   16815,
#   3067,
#   11724,
#   24843,
#   6912,
#   20405,
#   8612,
#   6888,
#   2726,
#   19208,
#   1796,
#   5460,
#   1662,
#   16685,
#   12362,
#   22583,
#   12365,
#   17877,
#   7775,
#   23687,
#   3382,
#   1520,
#   15016,
#   32804,
#   952,
#   31067,
#   15778,
#   23306,
#   31945,
#   2111,
#   20305,
#   13590,
#   7302,
#   16287,
#   19931,
#   14992,
#   926,
#   24757,
#   14117,
#   5688,
#   28154,
#   12959,
#   9731,
#   31113,
#   25048,
#   31956,
#   25205,
#   13118,
#   32297,
#   31929,
#   1786,
#   23119,
#   6690,
#   26902,
#   22594,
#   24621,
#   1092,
#   12623,
#   6483,
#   8617,
#   1291,
#   31876,
#   22454,
#   5139,
#   20879,
#   19372,
#   31125,
#   9331,
#   1397,
#   28983,
#   2857,
#   20956,
#   20575,
#   11852,
#   3122,
#   33233,
#   17702,
#   6484,
#   14169,
#   33532,
#   13632,
#   618,
#   30670,
#   10099,
#   7539,
#   24117,
#   11056,
#   14461,
#   447,
#   6815,
#   25395,
#   20302,
#   18208,
#   28957,
#   12657,
#   1395,
#   17035,
#   19025,
#   18697,
#   27087,
#   26227,
#   10359,
#   28724,
#   20105,
#   33549,
#   28656,
#   10290,
#   20060,
#   16090,
#   19571,
#   19817,
#   12358,
#   22040,
#   23859,
#   17238,
#   3619,
#   6072,
#   20053,
#   33266,
#   27574,
#   19626,
#   7757,
#   17829,
#   19113,
#   10953,
#   31227,
#   11679,
#   2029,
#   6675,
#   33454,
#   12659,
#   25460,
#   20270,
#   31932,
#   9124,
#   10059,
#   10873,
#   32173,
#   27358,
#   12099,
#   24630,
#   19271,
#   22135,
#   12868,
#   18317,
#   17403,
#   2683,
#   25804,
#   25677,
#   241,
#   10210,
#   17354,
#   28122,
#   19272,
#   15569,
#   30921,
#   1109,
#   11674,
#   8013,
#   10901,
#   15199,
#   21558,
#   22888,
#   30578,
#   17128,
#   13499,
#   28219,
#   25624,
#   15266,
#   9753,
#   19796,
#   15361,
#   9362,
#   22705,
#   25126,
#   12740,
#   3219,
#   20679,
#   32044,
#   12193,
#   12223,
#   27000,
#   4058,
#   31634,
#   369,
#   24083,
#   6271,
#   24195,
#   31829,
#   15488,
#   26210,
#   17286,
#   33387,
#   23353,
#   4229,
#   18430,
#   5533,
#   28348,
#   31794,
#   8761,
#   33616,
#   28373,
#   26844,
#   34143,
#   13756,
#   9162,
#   17364,
#   7499,
#   22545,
#   25828,
#   29874,
#   5732,
#   27909,
#   16631,
#   31663,
#   13823,
#   6896,
#   23647,
#   28651,
#   22093,
#   911,
#   24752,
#   28716,
#   10436,
#   18001,
#   31972,
#   9739,
#   22159,
#   8014,
#   21685,
#   32787,
#   18197,
#   17554,
#   1731,
#   31738,
#   10641,
#   28938,
#   21380,
#   24113,
#   4817,
#   4638,
#   12143,
#   23362,
#   4705,
#   21200,
#   11893,
#   33707,
#   31247,
#   8713,
#   33535,
#   4903,
#   21796,
#   25997,
#   15030,
#   25529,
#   2304,
#   21945,
#   9534,
#   29325,
#   14652,
#   33095,
#   31869,
#   15009,
#   8363,
#   6248,
#   28170,
#   9774,
#   16286,
#   22513,
#   6081,
#   1668,
#   1131,
#   6826,
#   21892,
#   2731,
#   22158,
#   20228,
#   32144,
#   27995,
#   27575,
#   18348,
#   24798,
#   15394,
#   31907,
#   31352,
#   4346,
#   27074,
#   20292,
#   251,
#   11502,
#   24673,
#   11044,
#   5893,
#   10166],
#  'columns': ['title', 'context_sentence', 'context_word', 'gt', 'prediction'],
#  'data': [['Spielschöpfung',
#    '"Die Grafiken zeigen sowohl tradierte Spiele als auch neue Spielschöpfungen."',
#    'Spielschöpfungen',
#    'kreative Neugestaltung einer Spielform oder eines Spielgeschehens',
#    'Ereignisse oder Handlungen, die während eines Spiels entstanden sind'],
#   ['Universitätsbildung',
#    '"Ich würde gerne daran festhalten, dass verfügbares und vergleichbares, abprüfbares Wissen (auch) zur Universitätsbildung gehört, um ein wissenschaftliches Gespräch zu ermöglichen, das von den Studenten nicht mit Geschwafel verwechselt werden kann."',
#    'Universitätsbildung',
#    'Bildung, die in einem Universitätsstudium erworben wird; akademischer Bildungsgrad',
#    'Ausbildung an einer Universität'],
#   ['Kehrseite',
#    '"Es bleibt also nur die Kehrseite des Guten, also das Böse." (Quelle: Karl May - Im Reiche des silbernen Löwen IV)',
#    'Kehrseite',
#    'die andere, entgegengesetzte, oftmals negative Seite einer Sache oder Angelegenheit',
#    'Die Kehrseite bezieht sich auf die äußere Seite oder der äußere Teil eines Gegenstandes oder einer Sache. In diesem Kontext bezieht sich die Kehrseite auf die äußere'],
#   ['mehrmalig',
#    '"(...) nur durch ein mehrmaliges Werfen des schönen Kopfes deutete er an, dass er an der Sache Geschmack gefunden habe." (Karl May: Weihnacht)',
#    'mehrmaliges',
#    'attributiv gebraucht, auch adverbial: mehr als ein Mal geschehend',
#    'einmalig bedeutet in diesem Kontext "mehrmals" oder "mehrmals", also etwas, das mehrmals einmal vorhanden ist oder existiert.'],
#   ['Teotihuacan',
#    'Die archäologische Stätte Teotihuacans gehört seit 1987 zum Weltkulturerbe der UNESCO',
#    'Teotihuacans',
#    'prähistorische Ruinenstadt im Zentralen Hochland von Mexiko',
#    'eine archäologische Stätte'],
#   ['Auswirkung',
#    '"Man muss bezweifeln, ob die Lohnzurückhaltung überhaupt nennenswerte Auswirkungen auf den Export hatte."',
#    'Auswirkungen',
#    'Folgen, Konsequenzen einer Handlung oder Unterlassung',
#    'Einfluss auf etwas oder jemanden'],
#   ['Tüte',
#    'Obwohl seine Eltern dabei waren, drehte er sich ganz genüsslich eine Tüte',
#    'Tüte',
#    'umgangssprachlich: Haschischzigarette',
#    'eine kurze Zeit'],
#   ['Krankheitssymptom',
#    '"Häufige Krankheitssymptome sind Veränderungen im Fress-/Trinkverhalten, Apathie, Bewegungslosigkeit, Abmagerung, Haut-und Fellveränderungen, Durchfall, Verletzungen an Ohren und Schwanz."',
#    'Krankheitssymptome',
#    'Medizin, Psychologie: Merkmal (Symptom), das ein erkrankter Patient (Mensch/Tier) zeigt und das Rückschlüsse auf die Erkrankung geben kann',
#    'Anzeichen einer Krankheit'],
#   ['zupflocken',
#    "Eine Bemerkung Wuttke's besagt, daß in Süddeutschland zum Schutze des Hauses gegen Behexung von einem Wunderdoktor oder Kapuziner in die Schwelle ein Loch gebohrt, etwas Geweihtes hineingesteckt und im Namen der Dreifaltigkeit zugepflockt werde",
#    'zugepflockt',
#    'besonders, bayrisch: mit einem Pflock oder Holzstift verschließen',
#    'hinzugefügt, hinzugefügt'],
#   ['Vorfahrt',
#    'Wir müssen einen Platz für die Vorfahrt der Kutsche freihalten',
#    'Vorfahrt',
#    'Straßenverkehr: Handlung, mit einem Fahrzeug zu einem bestimmten Punkt zu fahren und dort zu halten',
#    'eine Fahrt, die vor einem bestimmten Ort oder einer bestimmten Stelle führt'],
#   ['911',
#    '""Ich war in der 4. Klasse als das mit 9/11 passierte.""',
#    '911',
#    'Terroranschläge am 11. September 2001 in den Vereinigten Staaten von Amerika',
#    'Ein 9/11 ist ein medizinischer Fachbegriff, der sich auf die Behandlung von psychischen Problemen bezieht. Im Kontext des Satzes bezieht sich der Begriff "9/11" wahrscheinlich auf eine medizinische Behandlung, bei der'],
#   ['Abgasmanipulation',
#    'Die Höhe der Kfz-Steuer richtet sich auch nach den Emissionswerten. Durch Abgasmanipulation der Autohersteller entgehen den EU-Ländern Steuereinnahmen in Milliardenhöhe',
#    'Abgasmanipulation',
#    'Täuschung von Behörden bei der Einhaltung von Abgasgrenzwerten in einer technischen Anlage, beispielsweise Autos',
#    'Beeinflussung von Abgasen'],
#   ['Koalitionskrise',
#    '"Nach Kritik, Unterstützung, Neudefinition - Vollverschleierung statt Kopftuch - und einer Koalitionskrise steht fest: Das Tragen von Burka oder Niqab wird in Österreich künftig mit einer Geldstrafe in Höhe von 150 Euro geahndet."',
#    'Koalitionskrise',
#    'Zeitabschnitt, in dem das Scheitern einer bestehenden Koalition droht',
#    'eine Krise oder ein Konflikt zwischen zwei oder mehreren Parteien, insbesondere in einem politischen oder sozialen Kontext'],
#   ['Alex',
#    '""Alex, zieh nicht alles ins Lächerliche", ermahnte Elke ihre Freundin."',
#    'Alex',
#    'weiblicher Vorname',
#    'Alex ist in diesem Kontext der Name einer Person,'],
#   ['Weltraummonster',
#    '"Und in der Essenspause verschwand Edgerton gern im Hinterzimmer eines Imbisses in der East Baltimore Street, wo er sich vor die Reihe von Videospielen stellte und sich fieberhaft bemühte, grellbunte Weltraummonster mit einer Laserkanone wegzupusten."',
#    'Weltraummonster',
#    'Monster aus dem Weltraum',
#    'mythische Wesen, die in der Welt existieren'],
#   ['Klassenchef',
#    '"Wenn man heute durchfällt, fällt man eben durch, muss sich im nächsten Jahr nicht so plagen, ist kräftiger und nicht so kindisch wie die anderen und hat gute Chancen, bald der neue Klassenchef zu sein."',
#    'Klassenchef',
#    'Schweiz: Schüler, der von seinen Mitschülern gewählt wird, um die Interessen/Anliegen der Schulklasse zu vertreten und als Bindeglied zwischen Schülern und Lehrern/der Schulleitung fungiert',
#    'Leiter einer Klasse'],
#   ['Klaue',
#    'Er starrte auf die schmutzigen Klauen dieses Menschen',
#    'Klauen',
#    'übertragen:, abwertend: Hand',
#    'Schuhe'],
#   ['Kindesliebe',
#    '"Er hätte gern mehr gewusst, aber mit dem untrüglichen Instinkt der Kindesliebe schonte er seine Eltern, die, wenn die Rede auf ihre Eltern kam, traurig und unbeholfen wurden wie Kinder, die ein Geheimnis zu wahren haben, das viel zu groß und zu schwer für sie ist."',
#    'Kindesliebe',
#    'Liebe, die ein Kind seinen Eltern entgegenbringt',
#    'tiefe, innige Zuneigung zu Kindern'],
#   ['über den Jordan gehen',
#    '"Auch Festplatten können über den Jordan gehen, wenn man den PC fest genug schlägt, tritt oder umwirft, stellten zahlreiche Nutzer fest."',
#    'über den Jordan gehen',
#    'schadhaft werden, stückweise auseinanderfallen; (wirtschaftlich) zugrunde gehen',
#    'In diesem Kontext bedeutet "über den Jordan gehen", dass man den PC fest genug schlägt, tritt oder umwirft, wenn man den PC fest genug schlägt, tritt oder umwir'],
#   ['Ansager',
#    '"Die Musik untermalte noch immer die Stimme des Ansagers."',
#    'Ansagers',
#    'jemand, der etwas ansagt, ankündigt, zum Beispiel in den Medien (Rundfunk, Fernsehen)',
#    'eine Person, die etwas besitzt oder besitzt'],
#   ['Wärmegewitter',
#    '"Beim Luftmassengewitter oder Wärmegewitter entsteht die hoch reichende Labilität durch eine starke Aufheizung der Erdoberfläche."',
#    'Wärmegewitter',
#    'Gewitterart, die fast ausschließlich im Sommer auftritt',
#    'eine starke Labilität, die durch eine starke Aufheizung der Erdoberfläche entsteht'],
#   ['Wahlkabine',
#    '"Wer sich ein Bild davon machen will, was ihn am 26. Mai in der Wahlkabine erwartet, kann sich die Stimmzettel des Wahlkreises seines Bezirks schon einmal online anschauen und damit vertraut machen, wie die Innenbehörde am Dienstag mitteilte."',
#    'Wahlkabine',
#    'ein für Dritte nicht einsehbarer Raum oder Verschlag, der eine geheime Wahl ermöglichen soll',
#    'Raum, in dem Wahlen stattfinden'],
#   ['Felsenpinguin',
#    '"Mit der leuchtend gelben Federbüscheln am Kopf ist der Felsenpinguin ein auffälliges Mitglied seiner Familie."',
#    'Felsenpinguin',
#    'Zoologie: eine Art aus der Familie der Pinguine',
#    'Ein Felsenpinguin ist ein kleines, flugfähiges Säugetier, das in der Nähe von Felsen lebt.'],
#   ['unterminieren',
#    'Bei der Belagerung Wiens versuchten die Türken, die Befestigungsanlagen der Stadt zu unterminieren',
#    'unterminieren',
#    'Militär, Pionierwesen: Hohlräume und Stollen unterhalb eines Bauwerks anlegen (Festung, Stadtmauer etc.) zu dessen Zerstörung etwa durch eine anschließende Sprengung',
#    'zerstören, vernichten'],
#   ['Mitarbeiterin',
#    '"Bruni, als Mitarbeiterin am MPI für biophysikalische Chemie auf diesem Gebiet praktizierender Weise firm, hat ihr eine Mixtur zusammengebraut, die es in sich hat."',
#    'Mitarbeiterin',
#    'Arbeiterin oder Angestellte in einem Unternehmen oder einer Organisation',
#    'weibliche Person, die in einem Unternehmen oder einer Organisation arbeitet'],
#   ['Pfadüberdeckung',
#    '100% Pfadüberdeckung schließt 100% LCSAJ-Überdeckung ein',
#    'Pfadüberdeckung',
#    'ISTQB, Softwaretest: Anteil der vollständigen Pfade, die durch eine Testsuite ausgeführt wurden',
#    'Die Pfadüberdeckung bezieht sich auf die Fähigkeit, etwas zu überwinden oder zu überwinden, insbesondere im Hinblick auf die Fähigkeit, etwas zu überwinden oder zu überwinden'],
#   ['umstellen',
#    '"Laut einem Bericht des Korea Herald hat die Regierung von Südkorea vor, ihre Rechner auf Linux umzustellen."',
#    'umzustellen',
#    'eine Einstellung in einem oder mehreren Geräten verändern',
#    'etwas neu gestalten oder umgestalten'],
#   ['polizeilich',
#    '"Er entschloss sich, sie überhaupt gänzlich aufzugeben, um so mehr, als auch der ehemalige Haushofmeister Aubry, den er mit einer schärferen sozusagen polizeilicheren Beobachtung Mareuils beauftragt hatte und der - letzterem vollkommen unbekannt - dem verhassten Nebenbuhler auf Schritt und Tritt nachspürte, nicht das geringste Verdächtige festzustellen vermochte."',
#    'polizeilicheren',
#    'zur Polizei gehörend, sie oder ihre Arbeit betreffend',
#    'polizeilich bedeutet in diesem Kontext wahrscheinlich "polizeilich" im Sinne von "polizeilich" im Sinne von "polizeilich" oder "polizeilich". Es geht also darum, dass Mareuils Be'],
#   ['köpfen',
#    '"Wenn du mich anlügst, lasse ich dich köpfen!"',
#    'köpfen',
#    'jemandem (meist zur Exekution) den Kopf abtrennen',
#    'In diesem Kontext bedeutet "köpfen" wahrscheinlich "belästigen" oder "verletzen". Es scheint, als ob der Sprecher einen kleinen Fehler gemacht hat und "köpfen" anstelle von "'],
#   ['Masturbieren',
#    '"Ich hatte in all den Jahren, in denen wir nicht zusammen waren, beim Masturbieren immer nur an Consuela gedacht."',
#    'Masturbieren',
#    'Handlung, bei der eine Person sich sexuell selbst befriedigt',
#    'Das Masturbieren bezieht sich auf die Handlung, bei der ein Mann sexuelle Dienstleistungen anbietet, insbesondere im Hinblick auf sexuelle Befriedigung. In diesem Kontext bedeutet Masturbieren, dass'],
#   ['Schlafkoje',
#    '"Die ganzen Aufregungen des Tages waren mir bald zu viel geworden, die Müdigkeit übermannte mich, und ich stieg nach oben in meine Schlafkoje."',
#    'Schlafkoje',
#    'schmale Schlafgelegenheit, oft auf Booten oder Schiffen, in Wohnmobilen oder Lastwagen',
#    'Schlafkoje ist ein umgangssprachlicher Ausdruck für "schlafen" oder "schlafen", was ein altes Wort für "schlafen" oder "schlafen" ist. In diesem Kontext bezieht sich die Definition von Schlaf'],
#   ['Erdball',
#    '"Nicht als Fehler gelten dagegen der sogenannte Erdball (wenn der vom Gegner kommende Ball erst den Boden berührt und dann trifft) und wenn ein vom Gegner kommender Ball einen Spieler trifft, abprellt und von ihm selbst oder einem anderen Spieler anschließend gefangen wird."',
#    'Erdball',
#    'Sport: Ball, der bei einem Abwurfspiel zuerst den Boden und dann eine Person berührt und somit ungültig ist',
#    'ein Fußballspiel, bei dem der Ball erst den Boden berührt und dann von ihm selbst oder einem anderen Spieler anschließend gefangen wird'],
#   ['Mundstück',
#    'Mundstücke, mit denen der Raucher die Pfeife mit den Zähnen im Mund halten kann, sind am weitesten verbreitet',
#    'Mundstücke',
#    'Bauteil einer Tabakspfeife, durch den der Rauch aufgenommen wird; mundgerecht geformtes Röhrchen, in das man eine Zigarette stecken kann',
#    'Teile des Mundes, die den Mund bedeckt'],
#   ['Frühaufsteher',
#    '"Frühaufsteher reden nicht nur sehr wenig mit Fremden, sie sprechen auch kaum miteinander."',
#    'Frühaufsteher',
#    'Person, die ihre Nachtruhe regelmäßig schon zu früher Stunde beendet',
#    'Person, die sich beruflich mit der Pflege und dem Schutz von Pflanzen beschäftigt'],
#   ['Bergfahrt',
#    '"Am Morgen liegen wir am Belgischen Kai von Strasbourg, die nächtliche Bergfahrt, den Rhein hinauf, blieb nicht geräuschlos."',
#    'Bergfahrt',
#    'Schifffahrt: Fahrt flussaufwärts mit einem Schiff',
#    'eine Fahrt in den Bergen'],
#   ['längen',
#    'Hier, findet man oft, mußte der Ausdruck des Gedankens gedehnt, dort die Empfindung gelängt und geweitert werden',
#    'gelängt',
#    'etwas länger machen, das Volumen vergrößern',
#    'erfüllt, erfüllt'],
#   ['verbittern',
#    '"Man sollte nicht so leicht mit Ehescheidungen vorschreiten. Was liegt daran, ob einige Paare sich prügeln und das Leben verbittern, wenn nur der allgemeine Begriff der Heiligkeit der Ehe aufrecht bleibt."',
#    'verbittern',
#    'zunehmend mehr die Freude/Lebensfreude nehmen, so dass man nicht mehr fröhlich und unbeschwert sein kann',
#    'sich verändern, sich wandeln'],
#   ['Abtritt',
#    'Der Oheim ist auf dem Abtritte eingeschlafen',
#    'Abtritte',
#    'veraltet, regional: für Toilette',
#    'eine Fläche, auf der sich etwas befindet'],
#   ['Windstoß',
#    '"Bei den heftigen Windstößen glaubte John deutlich zu spüren, wie sich die Behausung vom Erdboden löste und jeden Augenblick mit dem Hurrikan davonzufliegen drohte."',
#    'Windstößen',
#    'plötzlich auftretende, nur kurz dauernde, heftige Luftbewegung',
#    'starker, heftiger Wind'],
#   ['Moslemin',
#    '"Doch er weiß Rat: Die hübsche Moslemin Sabaha soll als Geisel dienen und gegen seinen Sohn ausgetauscht werden."',
#    'Moslemin',
#    'Religion, Islam: Anhängerin des islamischen Glaubens; zunehmend durch Muslima abgelöst',
#    'Moslemin ist ein umgangssprachlicher Ausdruck für "Mütze" oder "Mütze", was ein altes Wort für "Mütze" oder "Mütze" ist. In diesem Kontext bezieht sich die Definition von Mos'],
#   ['ehrrührig',
#    'Der Fürst empörte sich über diese ehrrührigen Behauptungen',
#    'ehrrührigen',
#    'die Ehre antastend, die Ehre beschädigend, die Ehre verletzend',
#    'sorgfältig, gründlich'],
#   ['Biskuitrolle',
#    '"Wie bekommt man die Biskuitrolle ordentlich eingerollt? Wir zeigen einen ganz einfachen Trick [...]."',
#    'Biskuitrolle',
#    'aufgerollte Backware mit einem Biskuitteig mit einer Füllung aus Creme oder Marmelade',
#    'eine Person, die sich mit der Herstellung oder dem Verkauf von Biskuit beschäftigt'],
#   ['Gemeine',
#    '"Erklären sowohl der Herr Pfarrer Füeßlin, als auch die endsunterschriebenen Herrn Kirchen-Vorsteher, vor sich und im Nahmen der Gemeine, ernstlich, daß wie Sie die vormalige unter Ihnen gewesene Uneinigkeit billig von Herzen bereuen."',
#    'Gemeine',
#    'vor allem.: Gemeinde',
#    'Gemeinschaft, Gemeinschaft'],
#   ['mutterwindallein',
#    '"Alte und junge Treibels, desgleichen die Felgentreus, hatten ſich in eigenen Equipagen eingefunden, während Krola, von ſeinem Quartett begleitet, aus nicht aufgeklärten Gründen die neue Dampfbahn, Korinna aber mutterwindallein - der Alte wollte nachkommen - die Stadtbahn benutzt hatte."',
#    'mutterwindallein',
#    'vor allem., bis, veraltend: ganz und gar allein, sehr einsam, völlig vereinsamt; ganz verlassen',
#    'In diesem Kontext bedeutet "mutterwindallein" wahrscheinlich "mütterwindallein" im Sinne von "mütterwindallein" oder "mütterwindallein", was ein Adjektiv ist, das eine'],
#   ['Mittagssonne',
#    '"Der Senf glänzte in der Mittagssonne wie flüssiges Gold."',
#    'Mittagssonne',
#    'der Sonnenschein am Mittag, wenn die Sonne ihren höchsten Stand erreicht hat',
#    'die Zeit um die Mitte des Tages'],
#   ['Assoziativität',
#    '"In einem Ausdruck mit mehreren Operatoren der gleichen Präzedenz bestimmt die Assoziativität die Reihenfolge, in der die Operationen ausgeführt werden."',
#    'Assoziativität',
#    'EDV: Eigenschaft eines Operators, die eine Vorgabe ergibt, in welcher Reihenfolge gleichwertige Operatoren abgearbeitet werden',
#    'Die Assoziativität bezieht sich auf die Reihenfolge, in der die Operationen ausgeführt werden. In diesem Kontext bezieht sich die Assoziativität auf die Reihenfolge, in der die Operationen ausgeführt werden'],
#   ['Radlader',
#    '"Die Täter rückten am Sonntag in den Morgenstunden mit einem Radlader an und durchbrachen damit die Außenwand einer Bankfiliale in Mellingen bei Weimar, wie die Polizei mitteilte."',
#    'Radlader',
#    'mit Schaufel ausgestatteter Bagger, der auf Rädern fährt',
#    'Ein Radlader ist ein Fahrrad, das speziell für den Transport von Personen oder Gütern konzipiert ist.'],
#   ['postsynodal',
#    '"Moraltheologisch höchst bedenklich ist schließlich auch der Umgang des postsynodalen Schreibens mit dem Gewissens-Begriff, der das dritte Element des angedachten Unterscheidungsprozesses bildet."',
#    'postsynodalen',
#    'nach dem Ende einer Synode',
#    'nach dem Synodal, also nach dem ersten Buchstaben des griechischen Alphabets'],
#   ['Fieber',
#    'Der Krankheitsverlauf ging mit Fieber einher',
#    'Fieber',
#    'Medizin: Erhöhung der Körpertemperatur im Krankheitsfall; Schutzreaktion des Körpers, um Krankheitserreger abzutöten',
#    'eine starke körperliche Anstrengung'],
#   ['Liebesleben',
#    '"Das unruhige Reise- und Liebesleben befriedigt ihn nicht, löst vielmehr eine Krisenstimmung aus."',
#    'Liebesleben',
#    'Gesamtheit sexueller Aktivität und Vorstellungen von jemandem',
#    'Das Liebesleben bezieht sich auf die emotionale Bindung zwischen zwei Menschen, insbesondere im Kontext von romantischen Beziehungen.'],
#   ['eingebildet',
#    'Auch der "Klugscheißer" ist kein angenehmer Mensch, sondern schlicht und einfach eingebildet und lästig, weil er ständig durch seine Bemerkungen den Eindruck erwecken will, dass er alles besser weiß und kann',
#    'eingebildet',
#    'abwertend: sich überlegen fühlend; übertrieben stolz auf die eigene Person sein; eigene Eigenschaften, Fähigkeiten oder die soziale Stellung als soviel besser ansehen, dass man es einem anderen auch zeigt',
#    'In diesem Kontext bedeutet "eingebildet" wahrscheinlich "gebildet", also jemand, der sich durch seine Bemerkungen und Bemerkungen auszeichnet. Der Kontext deutet darauf hin, dass der'],
#   ['beigeben',
#    'Ich habe noch Karo, also muss ich mit der 7 klein beigeben, denn den Stich kriege ich sowieso nicht, da wäre es schade um die 10',
#    'beigeben',
#    'in dem Kombination mit klein, Kartenspiel, oder übertragen: sich geschlagen geben und in einer Sache nachgeben',
#    'in diesem Kontext bedeutet "beigeben" wahrscheinlich "gewinnen" oder "gewinnen lassen". Es scheint, als ob es sich um einen Tippfehler handelt. Die korrekte Definition wäre also: "'],
#   ['Adjunkt',
#    'Der Adjunkt des Direktors des Botanischen Gartens ist ihm behilflich',
#    'Adjunkt',
#    'Bedvor allem.: der Gehilfe eines Beamten',
#    'eine Person, die eine wichtige Position oder Funktion in einem Unternehmen oder einer Organisation innehat'],
#   ['Durchmesserende',
#    '"Da hierbei natürlich nur die Längen und Neigungen wesentlich sind, so können wir die Sehnen auch vom untern Durchmesserende aus ziehen, und allgemein sagen: Der verticale Durchmesser eines Kreises wird in derselben Zeit durchfallen wie jede von einem Durchmesserendpunkte in diesem Kreise gezogene Sehne."',
#    'Durchmesserende',
#    'Endpunkt eines Durchmessers',
#    'der mittlere Punkt eines Kreises'],
#   ['Insidergeschäft',
#    '"Und um sich über das Gewühl zu erheben, braucht er einen Mentor. Irgendeinen Milliardär, der ihn unter seine Milliardärsfittiche nimmt und ihm alles über Geld beibringt, das sich selbst vermehrt wie Karnickel, über Insidergeschäfte und Warentermingeschäfte, über die unblutige Welt der Konzernübernahmen und Geldanlagen in irgendeinem Steuerparadies, die auf ihrem Nummernkonto ins Unendliche wachsen."',
#    'Insidergeschäfte',
#    'Handel, bei dem der Allgemeinheit nicht bekannte Informationen eine Rolle spielen',
#    'Geschäfte, die nicht öffentlich zugänglich sind'],
#   ['un',
#    'Das un- in "Unhold" generiert einen bösen Menschen, von dem man Gefahr und negative Folgen erwartet',
#    'un',
#    'in Zusammensetzungen, bei Substantiven: ungünstig und negativ belegt',
#    'etwas, das nicht existiert oder nicht existiert'],
#   ['Pünktlichkeit',
#    'Unser Chef legt besonderen Wert auf Pünktlichkeit',
#    'Pünktlichkeit',
#    'genaue Einhaltung eines festgesetzten Termins',
#    'Genauigkeit'],
#   ['Putzerei',
#    '"Die Putzerei hat viel geringere Abteilungsunkosten als Formerei und Kernmacherei."',
#    'Putzerei',
#    'Metalltechnik: Abteilung zur Nach-/Endbehandlung von Gussstücken in einer Gießerei',
#    'Die Putzerei bezieht sich auf die Herstellung oder Bearbeitung von Textilien, insbesondere von Textilien.'],
#   ['Gullydeckel',
#    '"Grundsätzlich sind Gullydeckel (korrekt: Kanalschachtdeckel) nach DIN-Normen klassifiziert; die entsprechenden Codes sind DIN 1229 und DIN EN 124."',
#    'Gullydeckel',
#    'Verschluss eines Gullys, als Gitter auf einem Straßenablauf für Regenwasser oder als Verschluss eines Wartungsschachtes zu einem unterirdischen Kanal',
#    'Kanalschachtdeckel'],
#   ['D',
#    'Achtung, du spielst falsch! Das ist ein D und kein C',
#    'D',
#    'Grundton in der Musik',
#    'ein Buchstabe'],
#   ['schleimig',
#    'Diese Hafergrütze ist ja ganz eklig schleimig geworden. Die mag ich nicht essen',
#    'schleimig',
#    'glitschig feucht, aus Schleim bestehend',
#    'schwierig, schwierig zu essen'],
#   ['Chordat',
#    'Auch der Mensch ist ein Chordat',
#    'Chordat',
#    'Biologie: ein Tier, das im Laufe seiner Individualentwicklung eine Chorda anlegt und ausbildet und somit zum Tierstamm der Chordata gehört',
#    'eine Person, die sich nicht um die Konsequenzen ihrer Handlungen kümmert'],
#   ['wehrsam',
#    '"Wehrlos werden die Drohnen von wehrsamen Bienen geschlachtet."',
#    'wehrsamen',
#    'fähig, sich etwas oder jemandem entgegenzusetzen; gegen etwas Widerstand leisten',
#    'In diesem Kontext bedeutet "wehrsamen" wahrscheinlich "gefährlich" oder "gefährlich". Es scheint, als ob es sich um einen Tippfehler handelt. Die korrekte Definition wäre also "gefährlich'],
#   ['Tschako',
#    '"Gendarmeriewachtmeister Schubert ließ das Papier sinken, nahm den Tschako vom Kopf, wischte den Innenrand mit dem Taschentuch ab, setzte den Helm wieder auf und ging ans Fenster."',
#    'Tschako',
#    'Militär, Polizei: helmartige Kopfbedeckung',
#    'eine Art von Kopfbedeckung'],
#   ['Leuchtturm',
#    'An Deutschlands Küsten stehen unzählige Leuchttürme',
#    'Leuchttürme',
#    'weithin Lichtsignale ausstrahlender Turm an der Küste',
#    'Türme, die sich an der Küste befinden'],
#   ['Elektroflugzeug',
#    '"Ein Propeller am Heck treibt das Elektroflugzeug an. Energie dafür soll ein leiser Elektromotor liefern."',
#    'Elektroflugzeug',
#    'Luftfahrt: Flugzeug, das mit Elektromotoren angetrieben wird',
#    'ein Flugzeug, das mit Elektrizität angetrieben wird'],
#   ['Kirchendach',
#    '"An der Stadtkirche in Unna brach während des Sturmes eine vier Meter hohe Zinne vom Turmumgang in 45 Metern Höhe ab und schlug durch das Kirchendach [...]."',
#    'Kirchendach',
#    'Dach einer Kirche',
#    'Dach eines Gebäudes'],
#   ['Nepal',
#    'Kathmandu ist die Hauptstadt von Nepal',
#    'Nepal',
#    'Staat in Südasien',
#    'ein Land in Südasien'],
#   ['Badeurlaub',
#    '"Badeurlaub ist am besten möglich im Frühjahr und im Herbst."',
#    'Badeurlaub',
#    'Tourismus: Urlaub am Meer oder einem Strand an einem See',
#    'ein Ort, an dem man sich erholen kann'],
#   ['Raffzahn',
#    '"Man nannte ihn kurz und bündig "Raffzahn", weil er anderen ständig die Stullen und die Schokolade wegaß."',
#    'Raffzahn',
#    'umgangssprachlich: jemand, der maßlos viel beziehungsweise gierig verschlingend übermäßig isst',
#    'eine umgangssprachliche Bezeichnung für jemanden, der ständig die Stullen und Schokolade wegaß'],
#   ['Kaiserpinguin',
#    'Der Kaiserpinguin ist der am südlichsten lebende Pinguin der Welt: es gibt rund 300.000 Exemplare, die auf dem Packeis im Südpolarmeer rund um die Antarktis leben',
#    'Kaiserpinguin',
#    'die größte Art aus der Familie der Pinguine; kann bis zu 1,30 Meter groß werden und wiegt bis zu 45 Kilogramm',
#    'ein Pinguin, der auf dem Packeis im Südpolarmeer lebt'],
#   ['Transatlantikflug',
#    '"So meinte der damalige British-Airways-Chef Rod Eddington 2003, dass es vielen Firmenchefs nicht mehr möglich sei, 8700 Euro für einen Transatlantikflug zu bezahlen, wenn sie gleichzeitig Jobs streichen müssten."',
#    'Transatlantikflug',
#    'Flug über den Atlantischen Ozean',
#    'Flug über den Atlantik'],
#   ['Beugung',
#    'Die Beugung der Knie kann Schmerzen verursachen',
#    'Beugung',
#    'das Beugen, Abwinkeln',
#    'eine plötzliche, unerwartete Bewegung'],
#   ['Fund',
#    'Zur Bestreitung der Kriegskosten brauchen wir einen zulänglichen Fund',
#    'Fund',
#    'vor allem.: Stammkapital, Kapital, Finanzmittel',
#    'eine wissenschaftliche Untersuchung oder Analyse'],
#   ['Milchstraße',
#    'In klaren Nächten kann man die Milchstraße sehen',
#    'Milchstraße',
#    'kein Plural, Astronomie: milchiges Band am Nachthimmel, unsere Sicht auf die Galaxis',
#    'eine Straße, die durch die Milchstraße führt'],
#   ['Freitagnachmittag',
#    'Der Freitagnachmittag ist bei uns traditionell der Familie gewidmet',
#    'Freitagnachmittag',
#    'der Nachmittag eines Freitages',
#    'der späte Nachmittag eines Freitags'],
#   ['Urlaub',
#    '"Nikolai brachte seinen ganzen Urlaub bei seinen Angehörigen zu."',
#    'Urlaub',
#    'die vom Arbeitgeber dem abhängig Beschäftigten oder Dienstherrn dem Unterstellten gewährte Freizeit in Höhe von einem oder meist mehreren Werktagen a im wirtschaftlichen, zivilen Bereich, in Behörden b im militärischen Bereich',
#    'eine kurze Unterbrechung oder ein kurzer Aufenthalt an einem Ort,'],
#   ['aufreihen',
#    'Hunderttausende haben sich aufgereiht, mindestens - die Times of India schreibt gar von fünf Millionen Frauen',
#    'aufgereiht',
#    'sich in einer Reihe aufstellen',
#    'sich in einer schwierigen oder unangenehmen Situation befindet'],
#   ['Glaswand',
#    '"Robert sah, wie Katell die Glaswand leicht beiseite schob, bis sie einen Durchlaß gewährte, und auf diese Weise eine nach der anderen Koje durchschritt, bis er plötzlich in die Höhe zu schweben begann."',
#    'Glaswand',
#    'Wand aus Glas',
#    'eine Wand aus Glas'],
#   ['kopiergeschützt',
#    'Diese CD ist kopiergeschützt',
#    'kopiergeschützt',
#    'EDV: mit einem Kopierschutz versehen, der unerlaubte Vervielfältigung der Daten verhindert',
#    'In diesem Kontext bedeutet "kopiergeschützt" so viel wie "abgeschützt" oder "abgeschützt", also dass die CD nicht mehr benutzt werden kann.'],
#   ['Grashüpfer',
#    'In der Wiese saßen so viele Grashüpfer, dass die Geräuschkulisse ohrenbetäubend war',
#    'Grashüpfer',
#    'Zoologie: Individuum, das 1 zuzurechnen ist',
#    'Tiere, die in der Wiese leben'],
#   ['schleudern',
#    '"Brenn mich, brenn mich, brenn mich, singt die alte Frau und dreht sich dabei, hübsch langsam und bedächtig, und jetzt schleudert sie die Holzpantinen von den Füßen, da fliegen sie im Bogen bis an den Zaun, und sie dreht sich nun noch schneller unter dem Apfelbäumchen." (Johannes Bobrowski: Brief aus Amerika)',
#    'schleudert',
#    'auch intransitiv: etwas mit großem Schwung von sich werfen',
#    'In diesem Kontext bedeutet "schleudert" wahrscheinlich "sich schnell bewegt" oder "sich schnell bewegt". Es scheint, als ob die alte Frau die Holzpantinen von den Füße'],
#   ['Supplikation',
#    '"Von den obrigkeitlichen Behörden oder von den Landesherren selbst wurden die Supplikationen mittels eines Reskripts, einem schriftlichen Gutachten, oder einer Dispensation, einem Erlass oder Ausnahmegenehmigung, beantwortet."',
#    'Supplikationen',
#    'vor allem.: Geschenk oder auch Opfer mit einem Bittgesuch; persönliche Gabe, die jemandem gewidmet, geweiht, geschenkt worden ist und eine Bitte enthält; das Supplizieren',
#    'Veränderungen oder Veränderungen in einem System oder einer Organisation, insbesondere im Kontext von Rechtsvorschriften oder Vorschriften'],
#   ['Landesversicherungsanstalt',
#    'Gegenwärtig gibt es in der BRD 22 Landesversicherungsanstalten',
#    'Landesversicherungsanstalten',
#    'Träger der gesetzlichen Rentenversicherung der abhängig beschäftigten Arbeiter sowie der gesetzlich pflichtversicherten selbständigen Handwerker, Gewerbetreibenden, Küstenfischer und -schiffer',
#    'Einrichtungen, die für die Sicherheit von Ländern in einem bestimmten Gebiet oder einer bestimmten Region zuständig sind'],
#   ['Bildschirm',
#    'Es knallte und der Bildschirm erlosch',
#    'Bildschirm',
#    'Teil des Fernsehapparates oder Computers, auf dem das Bild erscheint',
#    'Bildschirm ist hier ein Schreibfehler und sollte "Bildschirm" heißen, was wahrscheinlich "Bildschirm" heißen sollte. In diesem Kontext wäre die Definition von "Bildschirm" also "Bildschirm" oder "'],
#   ['Ausstellungshalle',
#    '"Ein Vorhang im Halbrund dunkelt die Ausstellungshalle ab, es wirkt, als gelte es, einen eigenen Kosmos zu vermessen."',
#    'Ausstellungshalle',
#    'großer Raum (Halle), in dem Ausstellungen abgehalten werden',
#    'großer Raum in einem Gebäude, in dem Kunstwerke ausgestellt werden'],
#   ['Massenimpfung',
#    'Pockenimpfung: "Die in den reichen Industriestaaten erfolgreich durchgeführten Massenimpfungen funktionierten in strukturschwächeren Gebieten etwa in Indien oder in Afrika allerdings nicht."',
#    'Massenimpfungen',
#    'Medizin: Verabreichung (meist per Spritze oder oral) eines Impfstoffs an breite Bevölkerungsschichten, um diese gegen eine Krankheit zu immunisieren',
#    'Maßnahmen zur Vermeidung von Krankheitserregern'],
#   ['Freiübernachtung',
#    '"Die zur Freiübernachtung geeigneten und nachstehend bekannt gemachten Stellen werden durch die Nationalparkverwaltung gekennzeichnet."',
#    'Freiübernachtung',
#    'Aufenthalt zum Schlafen während der Nacht unter freiem Himmel',
#    'Die Freiübernachtung bezieht sich auf die öffentliche Nutzung von öffentlichen Einrichtungen, insbesondere im Kontext von Naturschutz und Umweltschutz. In diesem Kontext bezieht sich die Freiübernachtung auf die öffentlich'],
#   ['Blockwart',
#    'Der Blockwart verriet das Versteck der Flüchtlinge',
#    'Blockwart',
#    'historisch: Zuständigkeitspersonal im Bereich eines Häuserblocks zur NS-Zeit in Deutschland',
#    'Person, die für die Sicherheit und Ordnung in einem Gebäude oder einer Anlage verantwortlich ist'],
#   ['wodurch',
#    'Er ist viel auf Reisen gewesen, wodurch natürlich auch kostbare Zeit verlorengegangen ist',
#    'wodurch',
#    'relativ: aus dem eben erwähnten Grund heraus',
#    'durch etwas oder jemanden'],
#   ['hochbringen',
#    'Ich fühle mich hundeelend und einer Explosion nahe, dann kann jede Kleinigkeit mich hochbringen',
#    'hochbringen',
#    'in einen erregten Zustand versetzen, provozieren',
#    'sehr stark beeinflussen oder beeinflussen'],
#   ['im Zusammenhang mit',
#    '"Trumps Entscheidung Anmerkung: ,den Stabschef zu entlassen, folgt auf massive Kritik an der amerikanischen Regierung für ihr Krisenmanagement im Zusammenhang mit dem neuartigen Coronavirus."',
#    'im Zusammenhang mit',
#    'häufig in einem Relativsatz oder gefolgt von einem Dativ: eine Verbindung beschreibend zwischen zwei (oder mehr) Dingen / Vorgängen',
#    'beziehungsweise auf etwas oder jemanden'],
#   ['pöbeln',
#    'Der Profi von Manchester City pöbelte, als ein Medienvertreter ihn zum Verschwinden aufforderte',
#    'pöbelte',
#    'sich frech und provozierend äußern; lauthals beschimpfen, beleidigen',
#    'sich plötzlich oder unerwartet bewegte'],
#   ['perlustrieren',
#    '"Ein deutscher Polizeifilm zeigt, wie Juden perlustriert und kontrolliert werden, Verhaftungen werden inszeniert."',
#    'perlustriert',
#    'Österreich, amtsspr.: jemanden zur Feststellung der Identität anhalten und genau durchsuchen',
#    'In diesem Kontext bedeutet "perlustriert" wahrscheinlich "verfolgt" oder "beschützt". Es scheint, als ob es sich um einen Tippfehler handelt. Die korrekte Definition wäre also "'],
#   ['algerisch',
#    'Constantine ist mit 255 000 Einwohnern (2800 Europäer) drittgrößte und seit jeher algerischste Stadt des Landes, zugleich die Metropole Ost-Algeriens',
#    'algerischste',
#    'Algerien oder auch die Algerier betreffend, aus Algerien kommend',
#    'am meisten von Algerien bewohnt'],
#   ['bundesstaatlich',
#    'Der Bundesrat ist eine wichtige bundesstaatliche Einschränkung der Macht des Bundestages',
#    'bundesstaatliche',
#    'Politikwissenschaft: dem föderalen System entsprechend',
#    'bezogen auf die Bundesrepublik Deutschland'],
#   ['Spieldeutung',
#    '"Gerade aber weil unsere akademische Psychologie der Psychoanalyse weitgehend kritisch gegenübersteht, ist für sie das System Piagets auch für die Spieldeutung so wichtig geworden."',
#    'Spieldeutung',
#    'Interpretation von Spielphänomenen beziehungsweise psychologische Ausleuchtung eines Spielgeschehens',
#    'Die Deutung oder Bedeutung von Spielen, insbesondere im Kontext der Psychoanalyse'],
#   ['tolerant',
#    '"Ich bin vor 12 Jahren aus Moskau hierher nach Sotschi gekommen, weil die Menschen hier toleranter sind. Es ist eine Touristen-Stadt, und deren Bewohner empfangen die Gäste unabhängig von ihrer sexuellen Orientierung - Hauptsache, sie bringen Geld", erklärt der Mitinhaber des Clubs "Majak" Andrej Tanitschew',
#    'toleranter',
#    'die Meinungen, Auffassungen, Ideale, Überzeugungen oder die Lebensführung anderer akzeptierend',
#    'In diesem Kontext bedeutet "toleranter" wahrscheinlich "freundlicher" oder "freundlicher". Es geht darum, dass die Menschen in Moskau eine positive Einstellung gegenüber ihrer sexuellen Orientierung haben,'],
#   ['überstrecken',
#    '"In der Welt des Yoga geben Lehrer ihren Schülern oft die Empfehlung oder fordern sie auf, die Knie vor allem in Standhaltungen nicht zu überstrecken."',
#    'überstrecken',
#    'weiter an etwas ziehen, es dehnen (strecken), als es vernünftig ist, wenn man keinen Schaden herbeiführen möchte',
#    'zu strecken bedeutet in diesem Kontext, die Knie zu strecken, also die Knie zu stützen oder zu stützen.'],
#   ['Orthosprache',
#    'Dementsprechend besteht die erste Aufgabe bei der Konstruktion einer Orthosprache darin die aus Sicht der Sprachanwender relevanten Fachbegriffe zu rekonstruieren',
#    'Orthosprache',
#    'Philosophie: eine von Grund auf methodisch aufgebaute Wissenschaftssprache, in der die Verwendung der Worte normiert werden',
#    'eine wissenschaftliche Disziplin, die sich mit der Erforschung von Fachbegriffen beschäftigt'],
#   ['Polizeistunde',
#    '"Er sagte, der Aufgang sei schon geschlossen, aber er könne mir den heimlichen Aufstieg zeigen, den sie immer benutzten, wenn sie nach der Polizeistunde noch hochwollten."',
#    'Polizeistunde',
#    'Zeit, zu der gastronomische Einrichtungen schließen müssen',
#    'eine öffentliche Veranstaltung, bei der die Polizei für die Aufrechterhaltung der öffentlichen Sicherheit und Ordnung zuständig ist'],
#   ['rich',
#    'Die Wiese steht voller Spitzwegerich',
#    'rich',
#    "nachgestelltes Wortbildungselement für maskuline Substantive, bezeichnet allgemein eine Person, ein Lebewesen mit den durch das Bestimmungswort gegebenen Eigenschaften, 'umstritten auch:' bezeichnet an ein feminines Substantiv angefügt, die männliche Variante",
#    'In diesem Kontext bedeutet "reich" wahrscheinlich "reichlich" oder "reichlich", was ein Adjektiv ist, das bedeutet, dass etwas stark oder intensiv ist, insbesondere im Hinblick'],
#   ['Starnitzel',
#    '"Spinatpalatschinken und Starnitzel gefüllt mit Schlag und Beeren der Saison verführen ebenfalls zu einer Einkehr beim Ladinig."',
#    'Starnitzel',
#    'bairisch, landschaftlich: trichterförmiger Behälter aus zumeist (zusammengedrehtem) Papier (besonders für Lebensmittel)',
#    'eine Art von Pilzen'],
#   ['Ladungserhaltungssatz',
#    '"Es gilt somit das Gesetz von der Erhaltung der elektrischen Ladung, welches besagt, daß in einem abgeschlossenen System die Summe der elektrischen Ladungen konstant ist. Die hier zu betrachtenden Schaltungen sind abgeschlossene Systeme, für die der Ladungserhaltungssatz gilt."',
#    'Ladungserhaltungssatz',
#    'Physik: Erhaltungssatz, der besagt, dass in jedem abgeschlossenen System (System ohne Wechselwirkungen mit seiner Umgebung) die Summe der vorhandenen elektrischen Ladung konstant bleibt',
#    'Ein Ladungserhaltungssatz ist ein Satz, der besagt, dass in einem abgeschlossenen System die Summe der elektrischen Ladungen konstant ist.'],
#   ['Wortgattung',
#    '"Wohl kaum eine Wortgattung unterliegt einem derart schnellen Wandel wie die der Schimpfwörter."',
#    'Wortgattung',
#    'inhaltlich definierte Klasse von Wörtern',
#    'eine Gruppe von Wörtern, die zusammen eine bestimmte Bedeutung haben'],
#   ['Normabweichung',
#    'Bei der Qualitätskontrolle wurde eine geringfügige Normabweichung festgestellt',
#    'Normabweichung',
#    'Abweichung von einer Norm',
#    'eine geringfügige Abweichung von der Norm'],
#   ['Nordlicht',
#    'Das Nordlicht entsteht wesentlich über der nördlichen Polkappe durch Fluoreszierung der Erdmagnetfelder',
#    'Nordlicht',
#    'Polarlicht des nördlichen Polarkreises',
#    'Himmelskörper, der nördlich des Äquators liegt'],
#   ['Systemprogrammiererin',
#    'Wir bemühen uns, haben aber immer noch nicht so viele Systemprogrammiererinnen in der Abteilung wie männliche Kollegen',
#    'Systemprogrammiererinnen',
#    'Programmiererin die auf die Systemprogrammierung spezialisiert ist, also systemnahe Software entwickelt oder einrichtet',
#    'Personen, die Software für Computerprogramme entwickeln'],
#   ['Gau',
#    '"Dem Völkerschaftsverband entspricht im fränkischen Reich der Gau."',
#    'Gau',
#    'historisch im fränkischen Reich: Grafschaft des Fränkischen Reiches (die meisten waren deckungsgleich mit den alten germanischen Gauen)',
#    'eine Gruppe von Menschen, die gemeinsam eine bestimmte Aufgabe oder ein gemeinsames Ziel verfolgen'],
#   ['Anis',
#    '"Gegen Blähungen helfen zum Beispiel Fenchel oder Anis."',
#    'Anis',
#    'Botanik: Pflanze, die zur Gattung Pimpinella und der Familie der Doldenblütler zählt',
#    'eine Art von Pilzen'],
#   ['Münchendorf',
#    'In Münchendorf wurde bereits Anfang des Jahres das alte Bahnhofsgebäude abgetragen und mit dem Bau des neuen Personendurchgangs begonnen. Derzeit wird dort am neuen Personendurchgang Bahnhof Münchendorf gearbeitet',
#    'Münchendorf',
#    'niederösterreichische Gemeinde',
#    'ein Ort in Bayern'],
#   ['gegenwärtig',
#    'Ich finde, dass gegenwärtig zu wenig in Bildung investiert wird',
#    'gegenwärtig',
#    'adverbieller Gebrauch: derzeit, im Moment, in der Gegenwart',
#    'in der Zukunft, zu einem früheren Zeitpunkt'],
#   ['Galactose',
#    '"Der Einfachzucker Galactose baut zusammen mit der Glucose den Zweifachzucker Lactose auf, der als Milchzucker in der Milch weit verbreitet ist."',
#    'Galactose',
#    'zur Klasse der Aldohexosen gehörender Zucker',
#    'ein einfacher Zucker, der in der Milch vorkommt'],
#   ['magisch',
#    '"Bei mehreren Flügen in den Höhenwinden (Lee-Wellen) über den argentinischen Anden gelang es einer Gruppe von Segelfliegern, mit der Stemme S10VT mehrfach die magische 1 000-Kilometer-Marke zu überwinden."',
#    'magische',
#    'auf unerklärliche Weise, scheinbar durch Magie',
#    'In diesem Kontext bedeutet "magische" wahrscheinlich "außergewöhnliche" oder "außergewöhnliche". Es beschreibt die Größe oder das Ausmaß von etwas, in diesem Fall von Segelflieger'],
#   ['Akzeptanz',
#    'Die neue Steuernovelle fand in der Bevölkerung nur geringe Akzeptanz',
#    'Akzeptanz',
#    '(zustimmende) Annahme, Anerkennung; auch Bereitschaft, etwas anzunehmen oder zu akzeptieren',
#    'Anerkennung oder Beurteilung von etwas oder jemandem'],
#   ['mehrmastig',
#    '"Mehrmastige Segelschiffe entdeckt man in den 35 ausgestellten Acryl- und Ölbildern ebenso wie Fischerboote und Lastkähne."',
#    'Mehrmastige',
#    'Schifffahrt: über mehrere Masten verfügend',
#    'Segelschiffe mit mehreren Masten'],
#   ['Tirol',
#    '"Er wandte sich dann ins Tirol, war im April 1529 im Appenzellerland und wurde am 6. September 1529 in Clausen bei Innsbruck verbrannt."',
#    'Tirol',
#    'Region, die sich in den Alpen über Teile der heutigen Staatsgebiete Österreichs und Italiens erstreckt',
#    'ein Bundesland im Südwesten Österreichs'],
#   ['virtualisieren',
#    '"Wir virtualisieren die Wirklichkeit in einem Ausmaß, das unser Beharrungsvermögen in einer relativ fest verfugten Umwelt auf das Äußerste provoziert."',
#    'virtualisieren',
#    'in die virtuelle, nicht körperliche Welt übernehmen, dort stattfinden lassen',
#    'etwas, das nicht existiert oder nicht existiert'],
#   ['Roggen',
#    'Roggen ist nur mit Sauerteig backfähig',
#    'Roggen',
#    'langstielige Getreideart mit relativ langen Ähren und Grannen',
#    'ein Getränk, das aus Roggen hergestellt wird'],
#   ['simuliert',
#    '"Die modernen "Games" spielt man meist zu zweit, sie fördern die Interaktivität und bieten Möglichkeiten für simulierte Lebenserfahrungen."',
#    'simulierte',
#    '(häufig zu Test- oder Übungszwecken) modellhaft nachgebildet, beispielsweise in einem Computer oder Labor',
#    'künstlich erschaffene, nicht künstlich erschaffene'],
#   ['Ionengenerator',
#    '"Ionengenerator mit einer Nadelelektrode und einer Masseelektrode, die mit der Nadelelektrode zusammenwirken kann, um zum Produzieren von Ionen eine Koronaentladung in der Luft zu erzeugen, wobei die Masseelektrode derart angeordnet ist, dass sie eine imaginäre Verlängerung einer Längsachse der Nadelelektrode umgibt, dadurch gekennzeichnet, dass ein Teil der Masseelektrode entleert ist, um eine darin ausgebildete Spaltregion zu bilden."',
#    'Ionengenerator',
#    'Technik: Gerät bestehend aus einem Ionisator und einer Hochspannungsquelle zur Erzeugung von Koronaentladungen in Luft oder einem technischen Gas',
#    'Gerät zur Erzeugung von Ionen'],
#   ['GenImpfstoff',
#    '"Größter Vorteil verglichen mit herkömmlichen Methoden: Das Gendesign geht um ein Vielfaches schneller als das mühsame Züchten von Viren in Eiern oder Tieren. Zudem muss der Gen-Impfstoff anders als die temperaturempfindlichen natürlich hergestellten Mittel beim Transport in alle Welt nicht durchgängig gekühlt werden."',
#    'GenImpfstoff',
#    'Medizin: Vakzin (Impfstoff), das dazu führt, dass der Empfänger ein virales Protein selbst herstellt und somit selbst für das Antigen sorgt, das dann die Bildung von Antikörpern anregt und somit zu einer Immunantwort führt, wenn der Empfänger dem entsprechenden Erreger/Virus ausgesetzt wird',
#    'Ein Gen-Impfstoff ist ein Material, das zur Herstellung von Genen verwendet wird.'],
#   ['beigesellen',
#    'Darf ich mich Ihnen beigesellen?',
#    'beigesellen',
#    'reflexiv, gehoben: zu anderen, die schon da sind, hingehen/dazukommen und mitmachen',
#    'sich jemandem oder etwas nähern, sich jemandem oder etwas nähern'],
#   ['schwelgen',
#    '"In Architektur kann man hier schwelgen, in alter und uralter gotischer und flämischer - und auch in moderner."',
#    'schwelgen',
#    'gehoben: sich genüsslich in etwas versenken, sich an etwas berauschen, einem Genuss hingeben',
#    'In diesem Kontext bedeutet "schwelgen" wahrscheinlich "schwierig" oder "schwierig zu bewältigen". Es scheint, als ob es sich um einen Tippfehler handelt. Die korrekte Definition wär'],
#   ['Jugendorganisation',
#    '"Nach ghanaischem Vorbild gründete er eine eigene Jugendorganisation der NDP, die im Wesentlichen für die von der Partei ausgehende Einschüchterung und Gewalt verantwortlich war."',
#    'Jugendorganisation',
#    'öffentliche Einrichtung/Organisation speziell für Jugendliche',
#    'eine Organisation, die sich für die Interessen von Jugendlichen einsetzt'],
#   ['Pflichtlektüre',
#    'Heute habe ich mir die Pflichtlektüre für die nächsten Wochen zugelegt',
#    'Pflichtlektüre',
#    'Werk mit wichtigen Informationen (meist in schriftlicher Form), das von 1 umfasst wird',
#    'Die Pflichtlektüre ist in diesem Kontext wahrscheinlich ein Schreibfehler und sollte eigentlich "Pflanzen" heißen, was ein altes Wort für "Pflanzen" oder "Pflanzen" ist.'],
#   ['Ungeimpfter',
#    '"Seit dem 31. August weist das LAGuS die Inzidenz auch gesondert bei Geimpften und Ungeimpften aus. Bei Geimpften liegt sie bei 7,1 (+-0), bei Ungeimpften bei 72,5 (+2,1)."',
#    'Ungeimpften',
#    'Person, die keine Impfung erhalten hat',
#    'Personen, die keine Impfung haben'],
#   ['Schlesien',
#    'Sie kommen aus Schlesien',
#    'Schlesien',
#    'mitteleuropäische Region, die zu Polen und zu Tschechien gehört, in historischer Zeit auch deutsches, preußisches und österreich-ungarisches Territorium war',
#    'Schlesien sind in diesem Kontext offensichtlich eine umgangssprachliche Bezeichnung für die Region Schlesien, die sich im Südwesten von Deutschland befindet.'],
#   ['Albanerin',
# ...
#   ['Fischerei',
#    'Um Kunden für das Unternehmen zu bekommen, wird die Fischerei potenzieller Käufer durch die Werbung gefördert',
#    'Fischerei',
#    'Personen oder Gegenstände für einen bestimmten Zweck sammeln',
#    'Die Fischerei bezieht sich auf die Förderung oder Förderung von Produkten oder Dienstleistungen, insbesondere im Kontext von Unternehmen oder Dienstleistungen. In diesem Kontext bezieht sich die Fischerei auf die Förderung'],
#   ['dementsprechend',
#    'Wir haben uns dementsprechend entschlossen, nicht zu verreisen',
#    'dementsprechend',
#    'gemäß dem, was bereits bekannt ist',
#    'in einer Weise, die als unangemessen oder unangemessen empfunden wird'],
#   ['auflöten',
#    'Auf die aus einer Pressung basierenden Ringschiene sind im Schulterbereich zwei blattförmige Ornamente aufgelötet, die den Ringkopf halten',
#    'aufgelötet',
#    'etwas auf etwas löten',
#    'in einem bestimmten Muster oder einer bestimmten Form angeordnet'],
#   ['Gewalt',
#    'Er wurde mit Gewalt aus seinem Auto gezerrt und verprügelt',
#    'Gewalt',
#    'ohne Plural: erhebliche oder übermäßige Kraft, dies bei gezieltem Tun gegen Widerstände, oft ohne Legitimation',
#    'eine Form der körperlichen Anstrengung, bei der ein Gegenstand oder ein anderes Körperteil von einem Ort zu einem anderen bewegt wird'],
#   ['Aggo',
#    'Aggo wohnt hinterm Deich',
#    'Aggo',
#    'männlicher Vorname',
#    'eine Person, die hinter dem Deich wohnt'],
#   ['Notexamen',
#    '"Viele Kriegsfreiwilligen melden sich bei den Meldestellen, Schüler und höhere Klassen können Notexamina ablegen."',
#    'Notexamina',
#    'vorgezogene Abschlussprüfung, um zum Militär einberufenen Schülern/Studenten einen Abschluss ihrer Ausbildung vor/bald nach Dienstantritt zu ermöglichen',
#    'Notexamina ist ein Schreibfehler und sollte wahrscheinlich "Notexamina" heißen. In diesem Kontext bezieht sich die Definition von Notexamina auf die Notwendigkeit oder das Bedürfnis, jemanden oder etwa'],
#   ['Schrottpresse',
#    '"Allerdings gäbe es einen Weg, die für die Schrottpresse vorgesehenen Autos wieder in Umlauf zu bringen: Denn 2014 sollen alle Daten zur Abwrackprämie, die beim Bundesamt für Wirtschaft und Ausfuhrkontrolle (Bafa) liegen, gelöscht werden. Die Vorgeschichte des Autos wäre dann passé."',
#    'Schrottpresse',
#    'Technik: Gerät, mit dem Metallschrott verdichtet wird',
#    'Die Schrottpresse bezieht sich auf die Presse, die für die Abwrackprämie von Autos verantwortlich ist. In diesem Kontext bezieht sich die Schrottpresse auf die Presse, die für die Abwrackprämie von'],
#   ['Krisenmanager',
#    '"Wer gefahrenträchtige Ereignisse auf sich zutreiben läßt, wird sich bestenfalls als ein gutwilliger, an der Aufgabe wachsender, wohl kaum aber als ein sehr kompetenter Krisenmanager in der akuten Situation erweisen."',
#    'Krisenmanager',
#    'Person, die sachliche Problemsituationen und menschliche Konflikte zu regulieren versucht',
#    'Person, die in einer Krisensituation eine wichtige Rolle spielt'],
#   ['Schreiberling',
#    '"Der schwächliche Schreiberling ist ein geschickter Textverstecker. Große Teile seines Tagebuchs quetscht er zwischen die Zeilen des sogenannten "Trinker"-Manuskripts."',
#    'Schreiberling',
#    'abwertend: jemand, der viele und schlechte Texte verfasst, insbesondere ein Schriftsteller oder Journalist',
#    'eine Person, die Texte schreibt'],
#   ['Gesprächsraum',
#    '"Der Gesprächsraum von Pastorin Biermann befindet sich im ersten Stock, direkt über dem Gefängniscafé. "Seelsorgliche Gespräche führen oft in Tiefen und in Sorgen und Nöte hinein", sagt sie."',
#    'Gesprächsraum',
#    'Raum, der der direkten Kommunikation dient; meist ausgestattet mit einem oder mehreren Tischen und Stühlen',
#    'ein Raum, in dem Gespräche stattfinden'],
#   ['Aggression',
#    '"Das Ziel seiner Aggression waren jetzt nicht mehr die anderen Heimbewohner, sondern ich."',
#    'Aggression',
#    'feindliche Einstellung',
#    'Aggression bezeichnet in diesem Kontext die Handlung oder das Verhalten von jemandem oder etwas, insbesondere von einer Person oder einem Objekt. Es geht darum, dass jemand oder etwas'],
#   ['durchstreifen',
#    '"Es würde jetzt bald dunkel sein, und was hatte er nicht schon für schaurige Geschichten über Messerstecher gehört, die in den großen Städten bei Nacht und Nebel die Straßen nach wehrlosen Opfern durchstreiften."',
#    'durchstreiften',
#    'systematisch, zielgerichtet, aufmerksam durch ein Gebiet gehen, um etwas Bestimmtes zu finden, auf etwas Bestimmtes zu achten',
#    'In diesem Kontext bedeutet "durchstreiften" wahrscheinlich "durchquerten" oder "durchquerten", also die Straßen nach wehrlosen Opfern durchquerten oder durchquerten. Es scheint, als ob der'],
#   ['Coach',
#    '"Dabei wirkte der Coach der Ukraine jedoch nicht wie ein Trainer, dessen Team eben gegen einen der Turnierfavoriten verloren hat, auch wenn der den Beweis dafür dessen sic in diversen Phasen des Spiels schuldig geblieben war."',
#    'Coach',
#    'Sport: jemand, der eine Person oder Mannschaft trainiert und betreut',
#    'Eine Person, die für ein Team oder eine Organisation verantwortlich ist, insbesondere in einem sportlichen oder technischen Kontext.'],
#   ['berauschen',
#    '"Sich am freien Tag auf dem Sofa breitmachen und fernsehkucken... am bloßen Gedanken daran kann man sich berauschen."',
#    'berauschen',
#    'reflexiv: sich nicht satt sehen können und mehr von etwas haben wollen, weil es starke positive Gefühle schafft',
#    'sich erinnern, sich besinnen'],
#   ['ungelernt',
#    'Wann denkst du, dass du deine 22 ungelernten Gedichte aus der Schulzeit endlich lernst?',
#    'ungelernten',
#    'nicht gelernt',
#    'nicht gelernt oder nicht gelernt'],
#   ['davonbrausen',
#    'Der Porsche, mit dem er nach dem Heimsieg davonbrauste, ist ein letztes Relikt aus seiner wilden Zeit',
#    'davonbrauste',
#    'umgangssprachlich: mit großer Geschwindigkeit und großem Getöse davonfahren',
#    'weggegangen'],
#   ['Anforderung',
#    '"Sie stellt aber auch Anforderungen an die Bürger als Sprachrezipienten, an ihr sprachliches Wissen und Können, etwa bei der Aufnahme von Wortungetümen wie "Wachstumsbeschleunigungsgesetz"."',
#    'Anforderungen',
#    'Eigenschaft oder Fähigkeit, die zur Bewältigung bestimmter Aufgaben vorhanden sein muss',
#    'Anforderungen sind in diesem Kontext die Anforderungen oder Bedürfnisse, die jemand oder etwas benötigt, um etwas zu erreichen oder zu erfüllen.'],
#   ['Schnurre',
#    '"So eine richtige "Züri-Schnurre" gilt als arrogant - zu Recht?" Eigentlich ist die Zürcher Mundart eher unauffällig. Starke Assoziationen und Emotionen weckt sie dennoch',
#    'Schnurre',
#    'Schweiz, mundartlich, mit Bezug auf Menschen derb: Mund, Maul',
#    'eine abwertende Bezeichnung für eine Person, die als arrogant oder überheblich empfunden wird'],
#   ['Etage',
#    '"Ich ging hoch in die obere Etage und klopfte an die Tür."',
#    'Etage',
#    'Erdgeschoss oder Stockwerk eines Bauwerks; "erste Etage" bezeichnet meistens den 1. Stock und manchmal das Erdgeschoss',
#    'ein Raum in einem Haus'],
#   ['Zehenspitze',
#    '"Auf Zehenspitzen schlich sie in sein Zimmer hinüber."',
#    'Zehenspitzen',
#    'vorderster Bereich einer Zehe',
#    'Zehenspitzen sind in diesem Kontext wahrscheinlich die Zehenspitzen der Zehen, also die Zehenspitzen der Zehen.'],
#   ['Antichrese',
#    '"Wenn der Antichrese die pfandrechtliche Wirkung abgesprochen wird, so ist damit gesagt, daß der Gläubiger aus derselben nicht den Anspruch herleiten kann, vor anderen Gläubigern des Eigenthümers, namentlich im Fall der Eröffnung des Konkursverfahrens über das Vermögen desselben, aus dem Grundstück oder dessen Nutzungen befriedigt zu werden, beziehungsweise der Befriedigung anderer Gläubiger aus dem Gegenstande der Antichrese entgegenzutreten."',
#    'Antichrese',
#    'Zivilrecht: beim Pfandrecht die in Deutschland mögliche, in Österreich untersagte Berechtigung des Pfandgläubigers, die Nutzungen des Pfandes zu ziehen; z.B. im deutschen Zivilrecht gemäß  und bei gesetzlichem Pfandrecht analog § 1213 I BGB',
#    'Eine Person, die eine pfandrechtliche Wirkung auf eine andere Person ausübt, insbesondere im Kontext von Konkursverfahren.'],
#   ['Kretschmer',
#    'Der Kretschmer hat gestern Abend selbst zu tief ins Glas geschaut',
#    'Kretschmer',
#    'Niederschlesien, Spreewald: der Betreiber einer Dorfschenke (eines Kretschams), der Schenkwirt',
#    'Ein Kretschmer ist ein Handwerker, der sich auf die Herstellung von Getränken spezialisiert hat.'],
#   ['Kamerad',
#    '"Von der Odyssee, die die Kameraden der Schönheider Feuerwehr hinter sich haben, können viele Retter ein Lied singen."',
#    'Kameraden',
#    'Person, mit der man auf eine bestimmte Art (Sport, Schule, Beruf, Freundschaft oder Ähnliches) verbunden ist',
#    'Kameraden sind in diesem Kontext wahrscheinlich die Kameraden der Schönheider Feuerwehr, also die Mitglieder der Schönheider Feuerwehr.'],
#   ['Kunststoffpreis',
#    'Der Rohstoff Kunststoff wird aus Erdöl hergestellt und zum börsennotierten Kunststoffpreis abgegeben',
#    'Kunststoffpreis',
#    'den beim Erwerb einer Ware oder Dienstleistung aus Kunststoff zu zahlende Geldbetrag',
#    'Preis für Kunststoffe'],
#   ['Fußkissen',
#    '"Sie wies mit einem Zeremoniell, das ihr sonst fremd war, auf einen der zur Seite stehenden japanischen Stühle, schob sich ein Fußkissen heran und nahm ihrerseits auf dem Sofa Platz."',
#    'Fußkissen',
#    'Kissen, auf das man die Füße stützen kann',
#    'eine Art von Kissen, das speziell für die Füße verwendet wird'],
#   ['arbeitsreich',
#    '"Es ist jedesmal eine schöne erholsame Zeit, in der man Kraft tanken kann für den arbeitsreichen Sommer."',
#    'arbeitsreichen',
#    'voll, gefüllt mit Arbeit',
#    'arbeitsreich bedeutet in diesem Kontext, dass der Sommer sehr anstrengend oder mühsam ist, insbesondere im Hinblick auf die Arbeit.'],
#   ['hinreißend',
#    'Sie hat einen hinreißenden Charme',
#    'hinreißenden',
#    'in Bezug auf persönliche Eigenschaften, wie Aussehen, Charakter, Wesen: begeisternd',
#    'In diesem Kontext bedeutet "hinreißend" wahrscheinlich "hübsch" oder "angenehm". Es beschreibt die Art und Weise, wie sie sich verhält, insbesondere im Hinblick auf '],
#   ['Kirsche',
#    'Hast Du schon die blühende Kirsche in unserem Garten gesehen?',
#    'Kirsche',
#    'Botanik: der in der Natur wachsende Kirschbaum',
#    'eine Frucht,'],
#   ['aufschießen',
#    'Der Schlüssel ist jedenfalls weg, wir werden das Schloss aufschießen müssen, wenn wir jetzt ranwollen',
#    'aufschießen',
#    'haben, umgangssprachlich: etwas zugänglich machen/aufmachen, indem der Verschluss mit einem Schuss zerstört und so geöffnet wird',
#    'öffnen, öffnen'],
#   ['Nordwest',
#    'Nordwest-Kreuz, Wien Nordwestbahnhof',
#    'Nordwest',
#    'Geografie, als Bestimmungswort in Toponymen, die Zusammensetzungen und Verbindungen sind',
#    'Himmelsrichtung zwischen Nordwest und West'],
#   ['Asien',
#    '"Natürlich gehört Indien zu Asien."',
#    'Asien',
#    'der größte Kontinent der Erde; bildet zusammen mit Europa den Großkontinent Eurasien',
#    'ein Land in Südasien'],
#   ['Männerchor',
#    '"Noch gab es nur reinen Wohlklang, die drei Os rollten wie die Bassstimmen eines Männerchors."',
#    'Männerchors',
#    'Chor, in dem ausschließlich männliche, meist erwachsene Personen singen',
#    'eine Gruppe von Männern'],
#   ['entschuldigen',
#    'Ich entschuldige mich',
#    'entschuldigen',
#    'reflexiv, der Kürze zuliebe etwas salopp: den eigenen - oft durch Gesten angedeuteten - Abgang ansagen und um Verständnis dafür bitten',
#    'sich entschuldigen bedeutet in diesem Kontext, dass man sich für etwas entschuldigt oder sich für etwas entschuldigt. Es bedeutet also, dass man sich für etwas '],
#   ['Ikosaeder',
#    'Ein Ikosaeder hat zwölf Ecken, in denen jeweils fünf Flächen zusammentreffen',
#    'Ikosaeder',
#    'Geometrie: von zwanzig gleichseitigen Dreiecken begrenzter Körper',
#    'eine geometrische Figur mit fünf Ecken'],
#   ['Flutgebiet',
#    '"Flächen im mittleren Flutgebiet werden von den Kleinfluten nicht mehr betroffen und erfahren also auch durch solche keinen Schaden."',
#    'Flutgebiet',
#    'Areal, das von Wasser geflutet wird oder wurde',
#    'Gebiet, in dem ein Flut fliesst'],
#   ['Augenschirm',
#    '"Außerdem kaufte er sich einen grünen Augenschirm, mit dem er schon lange geliebäugelt hatte und der ihm half, hinter seinem Redaktionstisch einen gewichtigen Eindruck zu machen."',
#    'Augenschirm',
#    'Schutzschirm für die Augen',
#    'Ein Augenschirm ist ein Schirm, der speziell für die Augen entwickelt wurde.'],
#   ['Schlögel',
#    'Weiters werden aus dem Schlögel Steaks oder Schnitzel geschnitten, die gebraten, gegrillt oder gebacken werden. Gewürfelt ist der Schlögel ideal für kurz gebratene Ragouts, Spieße und Fondues',
#    'Schlögel',
#    'östereichisch:: Hinterschenkel des Kalbs, Lamms oder Rehs',
#    'ein Stück Fleisch, das zum Backen verwendet wird'],
#   ['Pi',
#    '"Pi ist eine der grundlegenden Zahlen, die sich durch die ganze Mathematik zieht."',
#    'Pi',
#    'Mathematik, ohne Plural: Konstante, die das Verhältnis des Umfangs zum Durchmesser eines Kreises beschreibt',
#    'Eine Zahlenzahl, die sich durch die ganze Mathematik zieht und sich durch die ganze Mathematik zieht.'],
#   ['Baack',
#    'Baack kommt und geht',
#    'Baack',
#    'deutschsprachiger Familienname',
#    'eine Person, die sich nicht lange an einem Ort aufhält'],
#   ['EsDur',
#    'Es-Dur hat drei ♭ als Vorzeichen',
#    'EsDur',
#    'meist ohne Artikel: eine Tonart des Tongeschlechts Dur, die auf dem Grundton Es basiert',
#    'eine musikalische Tonart'],
#   ['überdauern',
#    '"Allerdings werden diese zur Kodierung von Informationen auf einer Oberfläche eingesetzt, die sehr lange Zeiträume überdauern soll."',
#    'überdauern',
#    'eine lange Zeitspanne ohne Schaden zu nehmen erhalten bleiben',
#    'überdauern bedeutet in diesem Kontext, dass die Kodierung von Informationen auf einer Oberfläche sehr lange Zeitdauern soll. Es geht also darum, dass die Kodierung von Informationen auf einer Oberfläche'],
#   ['Echtermeyer',
#    'Der Echtermeyer trägt nie die Pullover, die die Echtermeyer ihm strickt',
#    'Echtermeyer',
#    'deutschsprachiger Nachname, Familienname',
#    'eine Person, die sich nicht um ihre Kleidung kümmert'],
#   ['Stromboli',
#    'Der Stromboli ist der aktivste europäische Vulkan mit einer stündlichen Frequenz der Eruptionen',
#    'Stromboli',
#    'ein 924 Meter hoher, aktiver Schichtvulkan der Insel Stromboli',
#    'ein Vulkan mit einer stündlichen Frequenz von Eruptionen'],
#   ['Lehnübersetzung',
#    'Ein Beispiel für eine Lehnübersetzung ist das deutsche Wort "Halbwelt", das eine genaue Übersetzung des französischen "demi-monde" darstellt',
#    'Lehnübersetzung',
#    'Linguistik: ein (auch zusammengesetztes) Wort, das nach einem Fremdwort gebildet wurde, indem ein Ausgangswort (oder dessen Bestandteile, einzeln) übersetzt wurden',
#    'Umsetzung eines Wortes aus einer anderen Sprache in eine andere'],
#   ['Chorraum',
#    '"Im Chorraum der heutigen, im Jahre 1934 geweihten Kirche befindet sich ein Mosaikbild, das die Kirche prägt und das den gekreuzigten Christus als König und Hohepriester mit Maria und Johannes darstellt. Es besteht aus vier Millionen Steinchen."',
#    'Chorraum',
#    'Architektur: Altarraum in einer Kirche',
#    'ein Raum in einem Gebäude, in dem sich die Kirche befindet'],
#   ['Selm',
#    'Selm liegt im Westen Deutschlands',
#    'Selm',
#    'eine Stadt in Nordrhein-Westfalen, Deutschland',
#    'eine Stadt'],
#   ['Felsenpinguin',
#    '"Wie die meisten Pinguinarten nistet der Felsenpinguin nicht auf dem antarktischen Festland, sondern bevorzugt etwas wärmeren Regionen fern der Polkappe"',
#    'Felsenpinguin',
#    'Zoologie: eine Art aus der Familie der Pinguine',
#    'eine Vogelart'],
#   ['speichern',
#    'Dunkle Steine speichern die Sonnenwärme besser als helle',
#    'speichern',
#    'einen Vorrat von etwas anlegen, damit man etwas zur Verfügung hat',
#    'speichern bedeutet hier, dass die Steine die Wärme von einem Ort zu einem anderen transportieren, indem sie die Wärme von einem Ort zu einem anderen transportieren.']]}

# %%
sample_b = collected_data.sample(frac=0.01, random_state=42)
sample_b
# Out:
#                      title                                   context_sentence  \
# 7104        Spielschöpfung  "Die Grafiken zeigen sowohl tradierte Spiele a...
# 18986  Universitätsbildung  "Ich würde gerne daran festhalten, dass verfüg...
# 20011            Kehrseite  "Es bleibt also nur die Kehrseite des Guten, a...
# 11052            mehrmalig  "(...) nur durch ein mehrmaliges Werfen des sc...
# 29716          Teotihuacan  Die archäologische Stätte Teotihuacans gehört ...
# ...                    ...                                                ...
# 11502      Lehnübersetzung  Ein Beispiel für eine Lehnübersetzung ist das ...
# 24673             Chorraum  "Im Chorraum der heutigen, im Jahre 1934 gewei...
# 11044                 Selm                  Selm liegt im Westen Deutschlands
# 5893         Felsenpinguin  "Wie die meisten Pinguinarten nistet der Felse...
# 10166            speichern  Dunkle Steine speichern die Sonnenwärme besser...
#
#               context_word                                                 gt  \
# 7104      Spielschöpfungen  kreative Neugestaltung einer Spielform oder ei...
# 18986  Universitätsbildung  Bildung, die in einem Universitätsstudium erwo...
# 20011            Kehrseite  die andere, entgegengesetzte, oftmals negative...
# 11052          mehrmaliges  attributiv gebraucht, auch adverbial: mehr als...
# 29716         Teotihuacans  prähistorische Ruinenstadt im Zentralen Hochla...
# ...                    ...                                                ...
# 11502      Lehnübersetzung  Linguistik: ein (auch zusammengesetztes) Wort,...
# 24673             Chorraum             Architektur: Altarraum in einer Kirche
# 11044                 Selm     eine Stadt in Nordrhein-Westfalen, Deutschland
# 5893         Felsenpinguin    Zoologie: eine Art aus der Familie der Pinguine
# 10166            speichern  einen Vorrat von etwas anlegen, damit man etwa...
#
#                                               prediction  bertscore_precision  \
# 7104   Ereignisse oder Handlungen, die während eines ...             0.706347
# 18986                    Ausbildung an einer Universität             0.806967
# 20011  Die Kehrseite bezieht sich auf die äußere Seit...             0.671636
# 11052  einmalig bedeutet in diesem Kontext "mehrmals"...             0.646891
# 29716                         eine archäologische Stätte             0.760008
# ...                                                  ...                  ...
# 11502  Umsetzung eines Wortes aus einer anderen Sprac...             0.708310
# 24673  ein Raum in einem Gebäude, in dem sich die Kir...             0.737418
# 11044                                         eine Stadt             0.812981
# 5893                                       eine Vogelart             0.703371
# 10166  speichern bedeutet hier, dass die Steine die W...             0.628200
#
#        bertscore_recall  bertscore_f1  bleurt_score  meteor_score  \
# 7104           0.708531      0.707437      0.523777      0.136986
# 18986          0.674842      0.735014      0.568951      0.000000
# 20011          0.735254      0.702007      0.415403      0.273529
# 11052          0.628518      0.637572      0.448108      0.040650
# 29716          0.677525      0.716400      0.430773      0.000000
# ...                 ...           ...           ...           ...
# 11502          0.637986      0.671311      0.378624      0.057252
# 24673          0.767538      0.752176      0.508865      0.151515
# 11044          0.621065      0.704181      0.237533      0.334821
# 5893           0.632380      0.665989      0.162500      0.060241
# 10166          0.643850      0.635929      0.277241      0.072993
#
#        moverscore_score   rouge_1   rouge_2   rouge_L  rouge_Lsum  \
# 7104           0.555608  0.235294  0.000000  0.235294    0.235294
# 18986          0.552810  0.133333  0.000000  0.133333    0.133333
# 20011          0.546962  0.250000  0.052632  0.200000    0.200000
# 11052          0.531657  0.000000  0.000000  0.000000    0.000000
# 29716          0.509784  0.000000  0.000000  0.000000    0.000000
# ...                 ...       ...       ...       ...         ...
# 11502          0.539513  0.000000  0.000000  0.000000    0.000000
# 24673          0.547370  0.235294  0.000000  0.235294    0.235294
# 11044          0.584785  0.500000  0.333333  0.500000    0.500000
# 5893           0.538057  0.200000  0.000000  0.200000    0.200000
# 10166          0.521053  0.050000  0.000000  0.050000    0.050000
#
#        sentence-embedding_score
# 7104                   0.535478
# 18986                  0.664373
# 20011                  0.308328
# 11052                  0.431801
# 29716                  0.232325
# ...                         ...
# 11502                  0.599027
# 24673                  0.758891
# 11044                  0.460503
# 5893                   0.323958
# 10166                  0.164931
#
# [342 rows x 16 columns]

# %%
sample_stats = calc_statistics(sample)
total_stats = calc_statistics(collected_data)

# %%
def compare_stats(total, subset):
    for k, v_total in total.items():
        v_subset = subset[k]
        print(f"{k}: {np.abs(v_total - v_subset) / v_total * 100:.2f} %")
        
compare_stats(total_stats, sample_stats)
# Out:
# ('bertscore_precision', 'Average'): 0.88 %
# ('bertscore_precision', 'StdDev'): 1.37 %
# ('bertscore_precision', 'Median'): 0.85 %
# ('bertscore_precision', 'Max'): 0.00 %
# ('bertscore_precision', 'Min'): 9.14 %
# ('bertscore_recall', 'Average'): 0.67 %
# ('bertscore_recall', 'StdDev'): 0.84 %
# ('bertscore_recall', 'Median'): 0.62 %
# ('bertscore_recall', 'Max'): 0.00 %
# ('bertscore_recall', 'Min'): 0.00 %
# ('bertscore_f1', 'Average'): 0.77 %
# ('bertscore_f1', 'StdDev'): 0.13 %
# ('bertscore_f1', 'Median'): 0.66 %
# ('bertscore_f1', 'Max'): 0.00 %
# ('bertscore_f1', 'Min'): 0.00 %
# ('bleurt_score', 'Average'): 2.04 %
# ('bleurt_score', 'StdDev'): 0.05 %
# ('bleurt_score', 'Median'): 1.73 %
# ('bleurt_score', 'Max'): 0.00 %
# ('bleurt_score', 'Min'): -183.83 %
# ('meteor_score', 'Average'): 4.40 %
# ('meteor_score', 'StdDev'): 2.02 %
# ('meteor_score', 'Median'): 6.60 %
# ('meteor_score', 'Max'): 0.04 %
# ('meteor_score', 'Min'): nan %
# ('moverscore_score', 'Average'): 0.55 %
# ('moverscore_score', 'StdDev'): 2.62 %
# ('moverscore_score', 'Median'): 0.32 %
# ('moverscore_score', 'Max'): 0.01 %
# ('moverscore_score', 'Min'): 0.00 %
# ('rouge_1', 'Average'): 5.75 %
# ('rouge_1', 'StdDev'): 2.45 %
# ('rouge_1', 'Median'): 5.88 %
# ('rouge_1', 'Max'): 0.00 %
# ('rouge_1', 'Min'): nan %
# ('rouge_2', 'Average'): 8.01 %
# ('rouge_2', 'StdDev'): 4.31 %
# ('rouge_2', 'Median'): nan %
# ('rouge_2', 'Max'): 0.00 %
# ('rouge_2', 'Min'): nan %
# ('rouge_L', 'Average'): 5.55 %
# ('rouge_L', 'StdDev'): 2.42 %
# ('rouge_L', 'Median'): 5.56 %
# ('rouge_L', 'Max'): 0.00 %
# ('rouge_L', 'Min'): nan %
# ('rouge_Lsum', 'Average'): 5.55 %
# ('rouge_Lsum', 'StdDev'): 2.42 %
# ('rouge_Lsum', 'Median'): 5.56 %
# ('rouge_Lsum', 'Max'): 0.00 %
# ('rouge_Lsum', 'Min'): nan %
# ('sentence-embedding_score', 'Average'): 3.35 %
# ('sentence-embedding_score', 'StdDev'): 1.09 %
# ('sentence-embedding_score', 'Median'): 5.84 %
# ('sentence-embedding_score', 'Max'): 0.00 %
# ('sentence-embedding_score', 'Min'): -56.92 %
# /tmp/ipykernel_1308101/473780017.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"{k}: {np.abs(v_total - v_subset) / v_total * 100:.2f} %")

# %%
sample_stats
# Out:
# {('bertscore_precision', 'Average'): 0.7147142674546519,
#  ('bertscore_precision', 'StdDev'): 0.09685577550322344,
#  ('bertscore_precision', 'Median'): 0.6991021633,
#  ('bertscore_precision', 'Max'): 1.0000002384,
#  ('bertscore_precision', 'Min'): 0.4883389771,
#  ('bertscore_recall', 'Average'): 0.6991255719491516,
#  ('bertscore_recall', 'StdDev'): 0.09220142517053445,
#  ('bertscore_recall', 'Median'): 0.6800351143,
#  ('bertscore_recall', 'Max'): 1.0000002384,
#  ('bertscore_recall', 'Min'): 0.3554219306,
#  ('bertscore_f1', 'Average'): 0.705756886808777,
#  ('bertscore_f1', 'StdDev'): 0.0904252456024084,
#  ('bertscore_f1', 'Median'): 0.6888597012,
#  ('bertscore_f1', 'Max'): 1.0000002384,
#  ('bertscore_f1', 'Min'): 0.4423691332,
#  ('bleurt_score', 'Average'): 0.3996637937767116,
#  ('bleurt_score', 'StdDev'): 0.20525684982405243,
#  ('bleurt_score', 'Median'): 0.3832337856,
#  ('bleurt_score', 'Max'): 1.0809522867,
#  ('bleurt_score', 'Min'): 0.0103823692,
#  ('meteor_score', 'Average'): 0.16725934202656526,
#  ('meteor_score', 'StdDev'): 0.20894395727029288,
#  ('meteor_score', 'Median'): 0.0943396226,
#  ('meteor_score', 'Max'): 0.9993141289,
#  ('meteor_score', 'Min'): 0.0,
#  ('moverscore_score', 'Average'): 0.5636159162210065,
#  ('moverscore_score', 'StdDev'): 0.08264819530594007,
#  ('moverscore_score', 'Median'): 0.5430918282,
#  ('moverscore_score', 'Max'): 0.9999309514,
#  ('moverscore_score', 'Min'): 0.4594893957,
#  ('rouge_1', 'Average'): 0.17959229031211232,
#  ('rouge_1', 'StdDev'): 0.22400698476375555,
#  ('rouge_1', 'Median'): 0.1176470588,
#  ('rouge_1', 'Max'): 1.0,
#  ('rouge_1', 'Min'): 0.0,
#  ('rouge_2', 'Average'): 0.07476363086787595,
#  ('rouge_2', 'StdDev'): 0.19016064568174157,
#  ('rouge_2', 'Median'): 0.0,
#  ('rouge_2', 'Max'): 1.0,
#  ('rouge_2', 'Min'): 0.0,
#  ('rouge_L', 'Average'): 0.17306019741866588,
#  ('rouge_L', 'StdDev'): 0.21963327972122035,
#  ('rouge_L', 'Median'): 0.1111111111,
#  ('rouge_L', 'Max'): 1.0,
#  ('rouge_L', 'Min'): 0.0,
#  ('rouge_Lsum', 'Average'): 0.17306019741866588,
#  ('rouge_Lsum', 'StdDev'): 0.21963327972122035,
#  ('rouge_Lsum', 'Median'): 0.1111111111,
#  ('rouge_Lsum', 'Max'): 1.0,
#  ('rouge_Lsum', 'Min'): 0.0,
#  ('sentence-embedding_score', 'Average'): 0.46359866981638387,
#  ('sentence-embedding_score', 'StdDev'): 0.23032424877337368,
#  ('sentence-embedding_score', 'Median'): 0.4371580184,
#  ('sentence-embedding_score', 'Max'): 1.0000001192,
#  ('sentence-embedding_score', 'Min'): -0.0391876623}

# %%
from scipy import stats

t_stat, p_value = stats.ttest_ind(collected_data["sentence-embedding_score"], sample["sentence-embedding_score"], equal_var=False)
t_stat, p_value
# Out:
# (0.8881104369218126, 0.3750961021751934)

# %%
def sample_to_sw(sample, model_information: ModelInformation):
    ret_dict = {"model_information": model_information.to_dict()}
    selection = sample[['title', 'context_sentence', 'context_word', 'gt', 'prediction']].to_dict(orient='split')
    ret_dict.update(selection)
    return ret_dict

# %%
import json


with open("export_example.json", "w+") as f:
    json.dump(sample_to_sw(sample_a, ModelInformation("Wiktionary", "2bba85fab20b4ed6a1a89b0503fd5274")), f)

# %%
# Out:
# {'index': [7104,
#   18986,
#   20011,
#   11052,
#   29716,
#   5183,
#   31333,
#   11227,
#   32933,
#   14358,
#   31959,
#   12802,
#   24742,
#   3510,
#   6049,
#   27888,
#   10475,
#   25715,
#   20077,
#   1045,
#   15416,
#   25063,
#   19526,
#   10217,
#   19793,
#   17964,
#   31540,
#   9254,
#   12957,
#   566,
#   19562,
#   17808,
#   30671,
#   28738,
#   10951,
#   18049,
#   24793,
#   12238,
#   22037,
#   16171,
#   3507,
#   9584,
#   9430,
#   30083,
#   9899,
#   25132,
#   29845,
#   6138,
#   16815,
#   3067,
#   11724,
#   24843,
#   6912,
#   20405,
#   8612,
#   6888,
#   2726,
#   19208,
#   1796,
#   5460,
#   1662,
#   16685,
#   12362,
#   22583,
#   12365,
#   17877,
#   7775,
#   23687,
#   3382,
#   1520,
#   15016,
#   32804,
#   952,
#   31067,
#   15778,
#   23306,
#   31945,
#   2111,
#   20305,
#   13590,
#   7302,
#   16287,
#   19931,
#   14992,
#   926,
#   24757,
#   14117,
#   5688,
#   28154,
#   12959,
#   9731,
#   31113,
#   25048,
#   31956,
#   25205,
#   13118,
#   32297,
#   31929,
#   1786,
#   23119,
#   6690,
#   26902,
#   22594,
#   24621,
#   1092,
#   12623,
#   6483,
#   8617,
#   1291,
#   31876,
#   22454,
#   5139,
#   20879,
#   19372,
#   31125,
#   9331,
#   1397,
#   28983,
#   2857,
#   20956,
#   20575,
#   11852,
#   3122,
#   33233,
#   17702,
#   6484,
#   14169,
#   33532,
#   13632,
#   618,
#   30670,
#   10099,
#   7539,
#   24117,
#   11056,
#   14461,
#   447,
#   6815,
#   25395,
#   20302,
#   18208,
#   28957,
#   12657,
#   1395,
#   17035,
#   19025,
#   18697,
#   27087,
#   26227,
#   10359,
#   28724,
#   20105,
#   33549,
#   28656,
#   10290,
#   20060,
#   16090,
#   19571,
#   19817,
#   12358,
#   22040,
#   23859,
#   17238,
#   3619,
#   6072,
#   20053,
#   33266,
#   27574,
#   19626,
#   7757,
#   17829,
#   19113,
#   10953,
#   31227,
#   11679,
#   2029,
#   6675,
#   33454,
#   12659,
#   25460,
#   20270,
#   31932,
#   9124,
#   10059,
#   10873,
#   32173,
#   27358,
#   12099,
#   24630,
#   19271,
#   22135,
#   12868,
#   18317,
#   17403,
#   2683,
#   25804,
#   25677,
#   241,
#   10210,
#   17354,
#   28122,
#   19272,
#   15569,
#   30921,
#   1109,
#   11674,
#   8013,
#   10901,
#   15199,
#   21558,
#   22888,
#   30578,
#   17128,
#   13499,
#   28219,
#   25624,
#   15266,
#   9753,
#   19796,
#   15361,
#   9362,
#   22705,
#   25126,
#   12740,
#   3219,
#   20679,
#   32044,
#   12193,
#   12223,
#   27000,
#   4058,
#   31634,
#   369,
#   24083,
#   6271,
#   24195,
#   31829,
#   15488,
#   26210,
#   17286,
#   33387,
#   23353,
#   4229,
#   18430,
#   5533,
#   28348,
#   31794,
#   8761,
#   33616,
#   28373,
#   26844,
#   34143,
#   13756,
#   9162,
#   17364,
#   7499,
#   22545,
#   25828,
#   29874,
#   5732,
#   27909,
#   16631,
#   31663,
#   13823,
#   6896,
#   23647,
#   28651,
#   22093,
#   911,
#   24752,
#   28716,
#   10436,
#   18001,
#   31972,
#   9739,
#   22159,
#   8014,
#   21685,
#   32787,
#   18197,
#   17554,
#   1731,
#   31738,
#   10641,
#   28938,
#   21380,
#   24113,
#   4817,
#   4638,
#   12143,
#   23362,
#   4705,
#   21200,
#   11893,
#   33707,
#   31247,
#   8713,
#   33535,
#   4903,
#   21796,
#   25997,
#   15030,
#   25529,
#   2304,
#   21945,
#   9534,
#   29325,
#   14652,
#   33095,
#   31869,
#   15009,
#   8363,
#   6248,
#   28170,
#   9774,
#   16286,
#   22513,
#   6081,
#   1668,
#   1131,
#   6826,
#   21892,
#   2731,
#   22158,
#   20228,
#   32144,
#   27995,
#   27575,
#   18348,
#   24798,
#   15394,
#   31907,
#   31352,
#   4346,
#   27074,
#   20292,
#   251,
#   11502,
#   24673,
#   11044,
#   5893,
#   10166],
#  'columns': ['title', 'context_sentence', 'context_word', 'gt', 'prediction'],
#  'data': [['Spielschöpfung',
#    '"Die Grafiken zeigen sowohl tradierte Spiele als auch neue Spielschöpfungen."',
#    'Spielschöpfungen',
#    'kreative Neugestaltung einer Spielform oder eines Spielgeschehens',
#    'schöpferische Gestaltung eines Spielgeschehens'],
#   ['Universitätsbildung',
#    '"Ich würde gerne daran festhalten, dass verfügbares und vergleichbares, abprüfbares Wissen (auch) zur Universitätsbildung gehört, um ein wissenschaftliches Gespräch zu ermöglichen, das von den Studenten nicht mit Geschwafel verwechselt werden kann."',
#    'Universitätsbildung',
#    'Bildung, die in einem Universitätsstudium erworben wird; akademischer Bildungsgrad',
#    'Bildung, die an einer Universität vermittelt wird'],
#   ['Kehrseite',
#    '"Es bleibt also nur die Kehrseite des Guten, also das Böse." (Quelle: Karl May - Im Reiche des silbernen Löwen IV)',
#    'Kehrseite',
#    'die andere, entgegengesetzte, oftmals negative Seite einer Sache oder Angelegenheit',
#    'übertragen:: die äußere, äußere Seite eines Gegenstandes oder einer Sache'],
#   ['mehrmalig',
#    '"(...) nur durch ein mehrmaliges Werfen des schönen Kopfes deutete er an, dass er an der Sache Geschmack gefunden habe." (Karl May: Weihnacht)',
#    'mehrmaliges',
#    'attributiv gebraucht, auch adverbial: mehr als ein Mal geschehend',
#    'mehrere Male stattfindend, mehrere Male vorkommend'],
#   ['Teotihuacan',
#    'Die archäologische Stätte Teotihuacans gehört seit 1987 zum Weltkulturerbe der UNESCO',
#    'Teotihuacans',
#    'prähistorische Ruinenstadt im Zentralen Hochland von Mexiko',
#    'Hauptstadt der chinesischen Provinz Teotihuacan'],
#   ['Auswirkung',
#    '"Man muss bezweifeln, ob die Lohnzurückhaltung überhaupt nennenswerte Auswirkungen auf den Export hatte."',
#    'Auswirkungen',
#    'Folgen, Konsequenzen einer Handlung oder Unterlassung',
#    'etwas, das eine Wirkung auf etwas hat'],
#   ['Tüte',
#    'Obwohl seine Eltern dabei waren, drehte er sich ganz genüsslich eine Tüte',
#    'Tüte',
#    'umgangssprachlich: Haschischzigarette',
#    'umgangssprachlich,, scherzhaft: kleines Gefäß, das zum Transport von Lebensmitteln benutzt wird'],
#   ['Krankheitssymptom',
#    '"Häufige Krankheitssymptome sind Veränderungen im Fress-/Trinkverhalten, Apathie, Bewegungslosigkeit, Abmagerung, Haut-und Fellveränderungen, Durchfall, Verletzungen an Ohren und Schwanz."',
#    'Krankheitssymptome',
#    'Medizin, Psychologie: Merkmal (Symptom), das ein erkrankter Patient (Mensch/Tier) zeigt und das Rückschlüsse auf die Erkrankung geben kann',
#    'Medizin: Symptom einer Krankheit'],
#   ['zupflocken',
#    "Eine Bemerkung Wuttke's besagt, daß in Süddeutschland zum Schutze des Hauses gegen Behexung von einem Wunderdoktor oder Kapuziner in die Schwelle ein Loch gebohrt, etwas Geweihtes hineingesteckt und im Namen der Dreifaltigkeit zugepflockt werde",
#    'zugepflockt',
#    'besonders, bayrisch: mit einem Pflock oder Holzstift verschließen',
#    'etwas mit einem Pflock versehen'],
#   ['Vorfahrt',
#    'Wir müssen einen Platz für die Vorfahrt der Kutsche freihalten',
#    'Vorfahrt',
#    'Straßenverkehr: Handlung, mit einem Fahrzeug zu einem bestimmten Punkt zu fahren und dort zu halten',
#    'der Vorgang, an dem sich etwas befindet'],
#   ['911',
#    '""Ich war in der 4. Klasse als das mit 9/11 passierte.""',
#    '911',
#    'Terroranschläge am 11. September 2001 in den Vereinigten Staaten von Amerika',
#    "umgangssprachlich,, scherzhaft: 'T'eutscher 'V'eutscher 'V'eutscher 'T'eutscher 'V'eutscher 'F'"],
#   ['Abgasmanipulation',
#    'Die Höhe der Kfz-Steuer richtet sich auch nach den Emissionswerten. Durch Abgasmanipulation der Autohersteller entgehen den EU-Ländern Steuereinnahmen in Milliardenhöhe',
#    'Abgasmanipulation',
#    'Täuschung von Behörden bei der Einhaltung von Abgasgrenzwerten in einer technischen Anlage, beispielsweise Autos',
#    'fachsprachlich: Maßnahme, bei der ein Abgas verwendet wird'],
#   ['Koalitionskrise',
#    '"Nach Kritik, Unterstützung, Neudefinition - Vollverschleierung statt Kopftuch - und einer Koalitionskrise steht fest: Das Tragen von Burka oder Niqab wird in Österreich künftig mit einer Geldstrafe in Höhe von 150 Euro geahndet."',
#    'Koalitionskrise',
#    'Zeitabschnitt, in dem das Scheitern einer bestehenden Koalition droht',
#    'Wirtschaft: Krise, die durch eine Koalition verursacht wird'],
#   ['Alex',
#    '""Alex, zieh nicht alles ins Lächerliche", ermahnte Elke ihre Freundin."',
#    'Alex',
#    'weiblicher Vorname',
#    'männlicher Vorname'],
#   ['Weltraummonster',
#    '"Und in der Essenspause verschwand Edgerton gern im Hinterzimmer eines Imbisses in der East Baltimore Street, wo er sich vor die Reihe von Videospielen stellte und sich fieberhaft bemühte, grellbunte Weltraummonster mit einer Laserkanone wegzupusten."',
#    'Weltraummonster',
#    'Monster aus dem Weltraum',
#    'umgangssprachlich,, scherzhaft: Mensch, der sich in den Weltraum befindet'],
#   ['Klassenchef',
#    '"Wenn man heute durchfällt, fällt man eben durch, muss sich im nächsten Jahr nicht so plagen, ist kräftiger und nicht so kindisch wie die anderen und hat gute Chancen, bald der neue Klassenchef zu sein."',
#    'Klassenchef',
#    'Schweiz: Schüler, der von seinen Mitschülern gewählt wird, um die Interessen/Anliegen der Schulklasse zu vertreten und als Bindeglied zwischen Schülern und Lehrern/der Schulleitung fungiert',
#    'Leiter einer Klasse'],
#   ['Klaue',
#    'Er starrte auf die schmutzigen Klauen dieses Menschen',
#    'Klauen',
#    'übertragen:, abwertend: Hand',
#    'umgangssprachlich,, abwertend: etwas, das nicht ganz besonders ernst zu nehmen ist'],
#   ['Kindesliebe',
#    '"Er hätte gern mehr gewusst, aber mit dem untrüglichen Instinkt der Kindesliebe schonte er seine Eltern, die, wenn die Rede auf ihre Eltern kam, traurig und unbeholfen wurden wie Kinder, die ein Geheimnis zu wahren haben, das viel zu groß und zu schwer für sie ist."',
#    'Kindesliebe',
#    'Liebe, die ein Kind seinen Eltern entgegenbringt',
#    'positive Einstellung zu einem Kind'],
#   ['über den Jordan gehen',
#    '"Auch Festplatten können über den Jordan gehen, wenn man den PC fest genug schlägt, tritt oder umwirft, stellten zahlreiche Nutzer fest."',
#    'über den Jordan gehen',
#    'schadhaft werden, stückweise auseinanderfallen; (wirtschaftlich) zugrunde gehen',
#    'umgangssprachlich,, übertragen:: etwas (beispielsweise ein Computer, einen Computer, einen Computer, einen Computer, einen Computer, einen Computer, einen Computer, einen Computer, einen Computer'],
#   ['Ansager',
#    '"Die Musik untermalte noch immer die Stimme des Ansagers."',
#    'Ansagers',
#    'jemand, der etwas ansagt, ankündigt, zum Beispiel in den Medien (Rundfunk, Fernsehen)',
#    'Person, die etwas anstrebt'],
#   ['Wärmegewitter',
#    '"Beim Luftmassengewitter oder Wärmegewitter entsteht die hoch reichende Labilität durch eine starke Aufheizung der Erdoberfläche."',
#    'Wärmegewitter',
#    'Gewitterart, die fast ausschließlich im Sommer auftritt',
#    'Wetter, bei dem die Temperatur von etwas erhöht wird'],
#   ['Wahlkabine',
#    '"Wer sich ein Bild davon machen will, was ihn am 26. Mai in der Wahlkabine erwartet, kann sich die Stimmzettel des Wahlkreises seines Bezirks schon einmal online anschauen und damit vertraut machen, wie die Innenbehörde am Dienstag mitteilte."',
#    'Wahlkabine',
#    'ein für Dritte nicht einsehbarer Raum oder Verschlag, der eine geheime Wahl ermöglichen soll',
#    'Raum, in dem eine Wahl stattfindet'],
#   ['Felsenpinguin',
#    '"Mit der leuchtend gelben Federbüscheln am Kopf ist der Felsenpinguin ein auffälliges Mitglied seiner Familie."',
#    'Felsenpinguin',
#    'Zoologie: eine Art aus der Familie der Pinguine',
#    'Zoologie: Vertreter einer Gattung aus der Familie der Pinguine'],
#   ['unterminieren',
#    'Bei der Belagerung Wiens versuchten die Türken, die Befestigungsanlagen der Stadt zu unterminieren',
#    'unterminieren',
#    'Militär, Pionierwesen: Hohlräume und Stollen unterhalb eines Bauwerks anlegen (Festung, Stadtmauer etc.) zu dessen Zerstörung etwa durch eine anschließende Sprengung',
#    'etwas mit einem Termin versehen'],
#   ['Mitarbeiterin',
#    '"Bruni, als Mitarbeiterin am MPI für biophysikalische Chemie auf diesem Gebiet praktizierender Weise firm, hat ihr eine Mixtur zusammengebraut, die es in sich hat."',
#    'Mitarbeiterin',
#    'Arbeiterin oder Angestellte in einem Unternehmen oder einer Organisation',
#    'weibliche Person, die in einem Unternehmen oder einer Organisation tätig ist'],
#   ['Pfadüberdeckung',
#    '100% Pfadüberdeckung schließt 100% LCSAJ-Überdeckung ein',
#    'Pfadüberdeckung',
#    'ISTQB, Softwaretest: Anteil der vollständigen Pfade, die durch eine Testsuite ausgeführt wurden',
#    'Chemie: Methode, bei der die Anzahl von Pfadüberdeckungen in einem bestimmten Gebiet nicht überschritten werden kann'],
#   ['umstellen',
#    '"Laut einem Bericht des Korea Herald hat die Regierung von Südkorea vor, ihre Rechner auf Linux umzustellen."',
#    'umzustellen',
#    'eine Einstellung in einem oder mehreren Geräten verändern',
#    'etwas in einen neuen Zustand bringen'],
#   ['polizeilich',
#    '"Er entschloss sich, sie überhaupt gänzlich aufzugeben, um so mehr, als auch der ehemalige Haushofmeister Aubry, den er mit einer schärferen sozusagen polizeilicheren Beobachtung Mareuils beauftragt hatte und der - letzterem vollkommen unbekannt - dem verhassten Nebenbuhler auf Schritt und Tritt nachspürte, nicht das geringste Verdächtige festzustellen vermochte."',
#    'polizeilicheren',
#    'zur Polizei gehörend, sie oder ihre Arbeit betreffend',
#    'die Polizei betreffend, zu ihr gehörend'],
#   ['köpfen',
#    '"Wenn du mich anlügst, lasse ich dich köpfen!"',
#    'köpfen',
#    'jemandem (meist zur Exekution) den Kopf abtrennen',
#    'umgangssprachlich,, scherzhaft: jemanden oder etwas mit den Fingern (Köpfen) bewegen'],
#   ['Masturbieren',
#    '"Ich hatte in all den Jahren, in denen wir nicht zusammen waren, beim Masturbieren immer nur an Consuela gedacht."',
#    'Masturbieren',
#    'Handlung, bei der eine Person sich sexuell selbst befriedigt',
#    'sexuelle Handlungen durchführen'],
#   ['Schlafkoje',
#    '"Die ganzen Aufregungen des Tages waren mir bald zu viel geworden, die Müdigkeit übermannte mich, und ich stieg nach oben in meine Schlafkoje."',
#    'Schlafkoje',
#    'schmale Schlafgelegenheit, oft auf Booten oder Schiffen, in Wohnmobilen oder Lastwagen',
#    'umgangssprachlich: Wohnung, in der man schlafen kann'],
#   ['Erdball',
#    '"Nicht als Fehler gelten dagegen der sogenannte Erdball (wenn der vom Gegner kommende Ball erst den Boden berührt und dann trifft) und wenn ein vom Gegner kommender Ball einen Spieler trifft, abprellt und von ihm selbst oder einem anderen Spieler anschließend gefangen wird."',
#    'Erdball',
#    'Sport: Ball, der bei einem Abwurfspiel zuerst den Boden und dann eine Person berührt und somit ungültig ist',
#    'Sport: Ball, bei dem der Ball erst den Boden berührt und dann den Boden berührt'],
#   ['Mundstück',
#    'Mundstücke, mit denen der Raucher die Pfeife mit den Zähnen im Mund halten kann, sind am weitesten verbreitet',
#    'Mundstücke',
#    'Bauteil einer Tabakspfeife, durch den der Rauch aufgenommen wird; mundgerecht geformtes Röhrchen, in das man eine Zigarette stecken kann',
#    'etwas, das mit dem Mund gehalten wird'],
#   ['Frühaufsteher',
#    '"Frühaufsteher reden nicht nur sehr wenig mit Fremden, sie sprechen auch kaum miteinander."',
#    'Frühaufsteher',
#    'Person, die ihre Nachtruhe regelmäßig schon zu früher Stunde beendet',
#    'vor allem.: jemand, der früh aufsteher ist; jemand, der früh aufsteher ist'],
#   ['Bergfahrt',
#    '"Am Morgen liegen wir am Belgischen Kai von Strasbourg, die nächtliche Bergfahrt, den Rhein hinauf, blieb nicht geräuschlos."',
#    'Bergfahrt',
#    'Schifffahrt: Fahrt flussaufwärts mit einem Schiff',
#    'Fahrt in einem Berg'],
#   ['längen',
#    'Hier, findet man oft, mußte der Ausdruck des Gedankens gedehnt, dort die Empfindung gelängt und geweitert werden',
#    'gelängt',
#    'etwas länger machen, das Volumen vergrößern',
#    'etwas in eine bestimmte Richtung bringen'],
#   ['verbittern',
#    '"Man sollte nicht so leicht mit Ehescheidungen vorschreiten. Was liegt daran, ob einige Paare sich prügeln und das Leben verbittern, wenn nur der allgemeine Begriff der Heiligkeit der Ehe aufrecht bleibt."',
#    'verbittern',
#    'zunehmend mehr die Freude/Lebensfreude nehmen, so dass man nicht mehr fröhlich und unbeschwert sein kann',
#    'umgangssprachlich,, abwertend: etwas verhindern, etwas verhindern'],
#   ['Abtritt',
#    'Der Oheim ist auf dem Abtritte eingeschlafen',
#    'Abtritte',
#    'veraltet, regional: für Toilette',
#    'Vorrichtung zum Abtrennen von etwas'],
#   ['Windstoß',
#    '"Bei den heftigen Windstößen glaubte John deutlich zu spüren, wie sich die Behausung vom Erdboden löste und jeden Augenblick mit dem Hurrikan davonzufliegen drohte."',
#    'Windstößen',
#    'plötzlich auftretende, nur kurz dauernde, heftige Luftbewegung',
#    'plötzlich auftretender Wind, der von oben nach unten bewegt wird'],
#   ['Moslemin',
#    '"Doch er weiß Rat: Die hübsche Moslemin Sabaha soll als Geisel dienen und gegen seinen Sohn ausgetauscht werden."',
#    'Moslemin',
#    'Religion, Islam: Anhängerin des islamischen Glaubens; zunehmend durch Muslima abgelöst',
#    'weiblicher Moslem'],
#   ['ehrrührig',
#    'Der Fürst empörte sich über diese ehrrührigen Behauptungen',
#    'ehrrührigen',
#    'die Ehre antastend, die Ehre beschädigend, die Ehre verletzend',
#    'gehoben: sehr ehrenvoll'],
#   ['Biskuitrolle',
#    '"Wie bekommt man die Biskuitrolle ordentlich eingerollt? Wir zeigen einen ganz einfachen Trick [...]."',
#    'Biskuitrolle',
#    'aufgerollte Backware mit einem Biskuitteig mit einer Füllung aus Creme oder Marmelade',
#    'aus Biskuit hergestellte Rolle'],
#   ['Gemeine',
#    '"Erklären sowohl der Herr Pfarrer Füeßlin, als auch die endsunterschriebenen Herrn Kirchen-Vorsteher, vor sich und im Nahmen der Gemeine, ernstlich, daß wie Sie die vormalige unter Ihnen gewesene Uneinigkeit billig von Herzen bereuen."',
#    'Gemeine',
#    'vor allem.: Gemeinde',
#    'Gesamtheit der Mitglieder einer Gemeinschaft'],
#   ['mutterwindallein',
#    '"Alte und junge Treibels, desgleichen die Felgentreus, hatten ſich in eigenen Equipagen eingefunden, während Krola, von ſeinem Quartett begleitet, aus nicht aufgeklärten Gründen die neue Dampfbahn, Korinna aber mutterwindallein - der Alte wollte nachkommen - die Stadtbahn benutzt hatte."',
#    'mutterwindallein',
#    'vor allem., bis, veraltend: ganz und gar allein, sehr einsam, völlig vereinsamt; ganz verlassen',
#    'weiblicher Vorname'],
#   ['Mittagssonne',
#    '"Der Senf glänzte in der Mittagssonne wie flüssiges Gold."',
#    'Mittagssonne',
#    'der Sonnenschein am Mittag, wenn die Sonne ihren höchsten Stand erreicht hat',
#    'Sonne, die am Mittag herrscht'],
#   ['Assoziativität',
#    '"In einem Ausdruck mit mehreren Operatoren der gleichen Präzedenz bestimmt die Assoziativität die Reihenfolge, in der die Operationen ausgeführt werden."',
#    'Assoziativität',
#    'EDV: Eigenschaft eines Operators, die eine Vorgabe ergibt, in welcher Reihenfolge gleichwertige Operatoren abgearbeitet werden',
#    'Linguistik: Eigenschaft, Assoziativ zu sein'],
#   ['Radlader',
#    '"Die Täter rückten am Sonntag in den Morgenstunden mit einem Radlader an und durchbrachen damit die Außenwand einer Bankfiliale in Mellingen bei Weimar, wie die Polizei mitteilte."',
#    'Radlader',
#    'mit Schaufel ausgestatteter Bagger, der auf Rädern fährt',
#    'umgangssprachlich,, abwertend: Person, die ein Fahrrad fährt'],
#   ['postsynodal',
#    '"Moraltheologisch höchst bedenklich ist schließlich auch der Umgang des postsynodalen Schreibens mit dem Gewissens-Begriff, der das dritte Element des angedachten Unterscheidungsprozesses bildet."',
#    'postsynodalen',
#    'nach dem Ende einer Synode',
#    'Linguistik: sich auf die Sprache beziehend, sich auf die Sprache beziehend'],
#   ['Fieber',
#    'Der Krankheitsverlauf ging mit Fieber einher',
#    'Fieber',
#    'Medizin: Erhöhung der Körpertemperatur im Krankheitsfall; Schutzreaktion des Körpers, um Krankheitserreger abzutöten',
#    'Medizin: Infektionskrankheit, die durch eine Infektion mit Fieber verursacht wird'],
#   ['Liebesleben',
#    '"Das unruhige Reise- und Liebesleben befriedigt ihn nicht, löst vielmehr eine Krisenstimmung aus."',
#    'Liebesleben',
#    'Gesamtheit sexueller Aktivität und Vorstellungen von jemandem',
#    'Gesamtheit der sexuellen Beziehungen, die jemand mit einer anderen Person führt'],
#   ['eingebildet',
#    'Auch der "Klugscheißer" ist kein angenehmer Mensch, sondern schlicht und einfach eingebildet und lästig, weil er ständig durch seine Bemerkungen den Eindruck erwecken will, dass er alles besser weiß und kann',
#    'eingebildet',
#    'abwertend: sich überlegen fühlend; übertrieben stolz auf die eigene Person sein; eigene Eigenschaften, Fähigkeiten oder die soziale Stellung als soviel besser ansehen, dass man es einem anderen auch zeigt',
#    'bildungsspr.: jemanden oder etwas in eine bestimmte Art und Weise einbilden'],
#   ['beigeben',
#    'Ich habe noch Karo, also muss ich mit der 7 klein beigeben, denn den Stich kriege ich sowieso nicht, da wäre es schade um die 10',
#    'beigeben',
#    'in dem Kombination mit klein, Kartenspiel, oder übertragen: sich geschlagen geben und in einer Sache nachgeben',
#    'umgangssprachlich,, scherzhaft: etwas mit etwas versehen'],
#   ['Adjunkt',
#    'Der Adjunkt des Direktors des Botanischen Gartens ist ihm behilflich',
#    'Adjunkt',
#    'Bedvor allem.: der Gehilfe eines Beamten',
#    'Amtsbezeichnung für einen Adjunkt'],
#   ['Durchmesserende',
#    '"Da hierbei natürlich nur die Längen und Neigungen wesentlich sind, so können wir die Sehnen auch vom untern Durchmesserende aus ziehen, und allgemein sagen: Der verticale Durchmesser eines Kreises wird in derselben Zeit durchfallen wie jede von einem Durchmesserendpunkte in diesem Kreise gezogene Sehne."',
#    'Durchmesserende',
#    'Endpunkt eines Durchmessers',
#    'Mathematik: letzter Punkt eines Durchmessers'],
#   ['Insidergeschäft',
#    '"Und um sich über das Gewühl zu erheben, braucht er einen Mentor. Irgendeinen Milliardär, der ihn unter seine Milliardärsfittiche nimmt und ihm alles über Geld beibringt, das sich selbst vermehrt wie Karnickel, über Insidergeschäfte und Warentermingeschäfte, über die unblutige Welt der Konzernübernahmen und Geldanlagen in irgendeinem Steuerparadies, die auf ihrem Nummernkonto ins Unendliche wachsen."',
#    'Insidergeschäfte',
#    'Handel, bei dem der Allgemeinheit nicht bekannte Informationen eine Rolle spielen',
#    'Geschäft, das in einem bestimmten Gebiet vermittelt wird'],
#   ['un',
#    'Das un- in "Unhold" generiert einen bösen Menschen, von dem man Gefahr und negative Folgen erwartet',
#    'un',
#    'in Zusammensetzungen, bei Substantiven: ungünstig und negativ belegt',
#    'vorangestelltes Wortbildungselement in Fremdwörtern aus dem Griechischen mit der Bedeutung: nicht'],
#   ['Pünktlichkeit',
#    'Unser Chef legt besonderen Wert auf Pünktlichkeit',
#    'Pünktlichkeit',
#    'genaue Einhaltung eines festgesetzten Termins',
#    'Eigenschaft, pünktlich zu sein'],
#   ['Putzerei',
#    '"Die Putzerei hat viel geringere Abteilungsunkosten als Formerei und Kernmacherei."',
#    'Putzerei',
#    'Metalltechnik: Abteilung zur Nach-/Endbehandlung von Gussstücken in einer Gießerei',
#    'handwerkliche Tätigkeit, die mit der Herstellung von Putzen beschäftigt ist'],
#   ['Gullydeckel',
#    '"Grundsätzlich sind Gullydeckel (korrekt: Kanalschachtdeckel) nach DIN-Normen klassifiziert; die entsprechenden Codes sind DIN 1229 und DIN EN 124."',
#    'Gullydeckel',
#    'Verschluss eines Gullys, als Gitter auf einem Straßenablauf für Regenwasser oder als Verschluss eines Wartungsschachtes zu einem unterirdischen Kanal',
#    'Geometrie: senkrecht stehender, flacher oder ovaler Streifen auf einem Gabelgestell, der die Form eines Dreiecks hat und die Form eines Dreiecks hat'],
#   ['D',
#    'Achtung, du spielst falsch! Das ist ein D und kein C',
#    'D',
#    'Grundton in der Musik',
#    "'D'eutsche 'D'eutsche 'd'eutsche 'D'eutsche 'd'eutsche 'd'eutsche 'd'eutsche "],
#   ['schleimig',
#    'Diese Hafergrütze ist ja ganz eklig schleimig geworden. Die mag ich nicht essen',
#    'schleimig',
#    'glitschig feucht, aus Schleim bestehend',
#    'umgangssprachlich,, abwertend: schmutzig, schleimig'],
#   ['Chordat',
#    'Auch der Mensch ist ein Chordat',
#    'Chordat',
#    'Biologie: ein Tier, das im Laufe seiner Individualentwicklung eine Chorda anlegt und ausbildet und somit zum Tierstamm der Chordata gehört',
#    'veraltet: Person, die in einem Chor lebt'],
#   ['wehrsam',
#    '"Wehrlos werden die Drohnen von wehrsamen Bienen geschlachtet."',
#    'wehrsamen',
#    'fähig, sich etwas oder jemandem entgegenzusetzen; gegen etwas Widerstand leisten',
#    'fähig, sich zu verteidigen'],
#   ['Tschako',
#    '"Gendarmeriewachtmeister Schubert ließ das Papier sinken, nahm den Tschako vom Kopf, wischte den Innenrand mit dem Taschentuch ab, setzte den Helm wieder auf und ging ans Fenster."',
#    'Tschako',
#    'Militär, Polizei: helmartige Kopfbedeckung',
#    'männlicher Vorname'],
#   ['Leuchtturm',
#    'An Deutschlands Küsten stehen unzählige Leuchttürme',
#    'Leuchttürme',
#    'weithin Lichtsignale ausstrahlender Turm an der Küste',
#    'Tür, die dazu dient, etwas zu leuchten'],
#   ['Elektroflugzeug',
#    '"Ein Propeller am Heck treibt das Elektroflugzeug an. Energie dafür soll ein leiser Elektromotor liefern."',
#    'Elektroflugzeug',
#    'Luftfahrt: Flugzeug, das mit Elektromotoren angetrieben wird',
#    'Flugzeug, das von einem Elektromotor angetrieben wird'],
#   ['Kirchendach',
#    '"An der Stadtkirche in Unna brach während des Sturmes eine vier Meter hohe Zinne vom Turmumgang in 45 Metern Höhe ab und schlug durch das Kirchendach [...]."',
#    'Kirchendach',
#    'Dach einer Kirche',
#    'Architektur: Dach eines Kirchengebäudes'],
#   ['Nepal',
#    'Kathmandu ist die Hauptstadt von Nepal',
#    'Nepal',
#    'Staat in Südasien',
#    'amtlich: Staat in Südostasien'],
#   ['Badeurlaub',
#    '"Badeurlaub ist am besten möglich im Frühjahr und im Herbst."',
#    'Badeurlaub',
#    'Tourismus: Urlaub am Meer oder einem Strand an einem See',
#    'Reise, beispielsweise zur Erholung, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen, Schwimmen'],
#   ['Raffzahn',
#    '"Man nannte ihn kurz und bündig "Raffzahn", weil er anderen ständig die Stullen und die Schokolade wegaß."',
#    'Raffzahn',
#    'umgangssprachlich: jemand, der maßlos viel beziehungsweise gierig verschlingend übermäßig isst',
#    'umgangssprachlich,, abwertend: jemand, der sich ständig und schnell von etwas entfernt'],
#   ['Kaiserpinguin',
#    'Der Kaiserpinguin ist der am südlichsten lebende Pinguin der Welt: es gibt rund 300.000 Exemplare, die auf dem Packeis im Südpolarmeer rund um die Antarktis leben',
#    'Kaiserpinguin',
#    'die größte Art aus der Familie der Pinguine; kann bis zu 1,30 Meter groß werden und wiegt bis zu 45 Kilogramm',
#    'Zoologie: Vertreter einer Gattung aus der Familie der Pinguine'],
#   ['Transatlantikflug',
#    '"So meinte der damalige British-Airways-Chef Rod Eddington 2003, dass es vielen Firmenchefs nicht mehr möglich sei, 8700 Euro für einen Transatlantikflug zu bezahlen, wenn sie gleichzeitig Jobs streichen müssten."',
#    'Transatlantikflug',
#    'Flug über den Atlantischen Ozean',
#    'Flug, der im Transatlantik stattfindet'],
#   ['Beugung',
#    'Die Beugung der Knie kann Schmerzen verursachen',
#    'Beugung',
#    'das Beugen, Abwinkeln',
#    'Anatomie: das Bedecken eines Gelenks'],
#   ['Fund',
#    'Zur Bestreitung der Kriegskosten brauchen wir einen zulänglichen Fund',
#    'Fund',
#    'vor allem.: Stammkapital, Kapital, Finanzmittel',
#    'etwas, das einem bestimmten Zweck dient'],
#   ['Milchstraße',
#    'In klaren Nächten kann man die Milchstraße sehen',
#    'Milchstraße',
#    'kein Plural, Astronomie: milchiges Band am Nachthimmel, unsere Sicht auf die Galaxis',
#    'Geografie: eine Straße, die hauptsächlich von der Milch geprägt ist'],
#   ['Freitagnachmittag',
#    'Der Freitagnachmittag ist bei uns traditionell der Familie gewidmet',
#    'Freitagnachmittag',
#    'der Nachmittag eines Freitages',
#    'der Nachmittag eines Freitages'],
#   ['Urlaub',
#    '"Nikolai brachte seinen ganzen Urlaub bei seinen Angehörigen zu."',
#    'Urlaub',
#    'die vom Arbeitgeber dem abhängig Beschäftigten oder Dienstherrn dem Unterstellten gewährte Freizeit in Höhe von einem oder meist mehreren Werktagen a im wirtschaftlichen, zivilen Bereich, in Behörden b im militärischen Bereich',
#    'Urlaub, der während eines bestimmten Zeitraums stattfindet'],
#   ['aufreihen',
#    'Hunderttausende haben sich aufgereiht, mindestens - die Times of India schreibt gar von fünf Millionen Frauen',
#    'aufgereiht',
#    'sich in einer Reihe aufstellen',
#    'umgangssprachlich: sich auf eine bestimmte Art und Weise an einen bestimmten Ort begeben'],
#   ['Glaswand',
#    '"Robert sah, wie Katell die Glaswand leicht beiseite schob, bis sie einen Durchlaß gewährte, und auf diese Weise eine nach der anderen Koje durchschritt, bis er plötzlich in die Höhe zu schweben begann."',
#    'Glaswand',
#    'Wand aus Glas',
#    'Wand aus Glas'],
#   ['kopiergeschützt',
#    'Diese CD ist kopiergeschützt',
#    'kopiergeschützt',
#    'EDV: mit einem Kopierschutz versehen, der unerlaubte Vervielfältigung der Daten verhindert',
#    'etwas mit Kopien versehen, so dass es nicht gedruckt werden kann'],
#   ['Grashüpfer',
#    'In der Wiese saßen so viele Grashüpfer, dass die Geräuschkulisse ohrenbetäubend war',
#    'Grashüpfer',
#    'Zoologie: Individuum, das 1 zuzurechnen ist',
#    'Zoologie: Vogel aus der Familie der Schmetterlingsvögel'],
#   ['schleudern',
#    '"Brenn mich, brenn mich, brenn mich, singt die alte Frau und dreht sich dabei, hübsch langsam und bedächtig, und jetzt schleudert sie die Holzpantinen von den Füßen, da fliegen sie im Bogen bis an den Zaun, und sie dreht sich nun noch schneller unter dem Apfelbäumchen." (Johannes Bobrowski: Brief aus Amerika)',
#    'schleudert',
#    'auch intransitiv: etwas mit großem Schwung von sich werfen',
#    'umgangssprachlich,, abwertend: etwas von einem Ort an einen anderen Ort entfernen'],
#   ['Supplikation',
#    '"Von den obrigkeitlichen Behörden oder von den Landesherren selbst wurden die Supplikationen mittels eines Reskripts, einem schriftlichen Gutachten, oder einer Dispensation, einem Erlass oder Ausnahmegenehmigung, beantwortet."',
#    'Supplikationen',
#    'vor allem.: Geschenk oder auch Opfer mit einem Bittgesuch; persönliche Gabe, die jemandem gewidmet, geweiht, geschenkt worden ist und eine Bitte enthält; das Supplizieren',
#    'bildungssprachlich: etwas, das als Suppliation dient; etwas, das als Suppliation dient'],
#   ['Landesversicherungsanstalt',
#    'Gegenwärtig gibt es in der BRD 22 Landesversicherungsanstalten',
#    'Landesversicherungsanstalten',
#    'Träger der gesetzlichen Rentenversicherung der abhängig beschäftigten Arbeiter sowie der gesetzlich pflichtversicherten selbständigen Handwerker, Gewerbetreibenden, Küstenfischer und -schiffer',
#    'Bundesrepublik Deutschland, Österreich: öffentliche Versicherungsanstalt, die in der Bundesrepublik Deutschland tätig ist'],
#   ['Bildschirm',
#    'Es knallte und der Bildschirm erlosch',
#    'Bildschirm',
#    'Teil des Fernsehapparates oder Computers, auf dem das Bild erscheint',
#    'grafische Darstellung eines Computerprogramms'],
#   ['Ausstellungshalle',
#    '"Ein Vorhang im Halbrund dunkelt die Ausstellungshalle ab, es wirkt, als gelte es, einen eigenen Kosmos zu vermessen."',
#    'Ausstellungshalle',
#    'großer Raum (Halle), in dem Ausstellungen abgehalten werden',
#    'Halle, in der eine Ausstellung stattfindet'],
#   ['Massenimpfung',
#    'Pockenimpfung: "Die in den reichen Industriestaaten erfolgreich durchgeführten Massenimpfungen funktionierten in strukturschwächeren Gebieten etwa in Indien oder in Afrika allerdings nicht."',
#    'Massenimpfungen',
#    'Medizin: Verabreichung (meist per Spritze oder oral) eines Impfstoffs an breite Bevölkerungsschichten, um diese gegen eine Krankheit zu immunisieren',
#    'Medizin: Impfung, die von sehr vielen Menschen (beispielsweise einer Familie, einer Familie, einem bestimmten Krankheitserreger) verursacht wird'],
#   ['Freiübernachtung',
#    '"Die zur Freiübernachtung geeigneten und nachstehend bekannt gemachten Stellen werden durch die Nationalparkverwaltung gekennzeichnet."',
#    'Freiübernachtung',
#    'Aufenthalt zum Schlafen während der Nacht unter freiem Himmel',
#    'geruhsame, freie Zeit zum Schlafen (beispielsweise in einem Hotel, einem Hotel, einem Hotel, einem Hotel, einem Hotel, einem Hotel oder Ähnlichem)'],
#   ['Blockwart',
#    'Der Blockwart verriet das Versteck der Flüchtlinge',
#    'Blockwart',
#    'historisch: Zuständigkeitspersonal im Bereich eines Häuserblocks zur NS-Zeit in Deutschland',
#    'Person, die in einem Block bewaffnet ist'],
#   ['wodurch',
#    'Er ist viel auf Reisen gewesen, wodurch natürlich auch kostbare Zeit verlorengegangen ist',
#    'wodurch',
#    'relativ: aus dem eben erwähnten Grund heraus',
#    'vorangestelltes Wortbildungselement in Fremdwörtern aus dem Griechischen mit der Bedeutung: durch, durch, durch, durch, durch, durch, durch, durch, durch, durch, durch, durch, durch, durch,'],
#   ['hochbringen',
#    'Ich fühle mich hundeelend und einer Explosion nahe, dann kann jede Kleinigkeit mich hochbringen',
#    'hochbringen',
#    'in einen erregten Zustand versetzen, provozieren',
#    'umgangssprachlich: etwas von oben nach unten bringen'],
#   ['im Zusammenhang mit',
#    '"Trumps Entscheidung Anmerkung: ,den Stabschef zu entlassen, folgt auf massive Kritik an der amerikanischen Regierung für ihr Krisenmanagement im Zusammenhang mit dem neuartigen Coronavirus."',
#    'im Zusammenhang mit',
#    'häufig in einem Relativsatz oder gefolgt von einem Dativ: eine Verbindung beschreibend zwischen zwei (oder mehr) Dingen / Vorgängen',
#    'mit etwas, mit etwas, mit etwas, mit etwas, mit etwas, mit etwas, mit etwas, mit etwas, mit etwas, mit etwas,'],
#   ['pöbeln',
#    'Der Profi von Manchester City pöbelte, als ein Medienvertreter ihn zum Verschwinden aufforderte',
#    'pöbelte',
#    'sich frech und provozierend äußern; lauthals beschimpfen, beleidigen',
#    'umgangssprachlich,, abwertend: jemanden oder etwas mit lauter Stimme äußern'],
#   ['perlustrieren',
#    '"Ein deutscher Polizeifilm zeigt, wie Juden perlustriert und kontrolliert werden, Verhaftungen werden inszeniert."',
#    'perlustriert',
#    'Österreich, amtsspr.: jemanden zur Feststellung der Identität anhalten und genau durchsuchen',
#    'bildungssprachlich: jemanden oder etwas in seinen eigenen Besitz bringen'],
#   ['algerisch',
#    'Constantine ist mit 255 000 Einwohnern (2800 Europäer) drittgrößte und seit jeher algerischste Stadt des Landes, zugleich die Metropole Ost-Algeriens',
#    'algerischste',
#    'Algerien oder auch die Algerier betreffend, aus Algerien kommend',
#    'Algerien betreffend, aus Algerien kommend'],
#   ['bundesstaatlich',
#    'Der Bundesrat ist eine wichtige bundesstaatliche Einschränkung der Macht des Bundestages',
#    'bundesstaatliche',
#    'Politikwissenschaft: dem föderalen System entsprechend',
#    'die Bundesrepublik Deutschland betreffend, zu ihr gehörend'],
#   ['Spieldeutung',
#    '"Gerade aber weil unsere akademische Psychologie der Psychoanalyse weitgehend kritisch gegenübersteht, ist für sie das System Piagets auch für die Spieldeutung so wichtig geworden."',
#    'Spieldeutung',
#    'Interpretation von Spielphänomenen beziehungsweise psychologische Ausleuchtung eines Spielgeschehens',
#    'Linguistik: Deutung eines Spiels'],
#   ['tolerant',
#    '"Ich bin vor 12 Jahren aus Moskau hierher nach Sotschi gekommen, weil die Menschen hier toleranter sind. Es ist eine Touristen-Stadt, und deren Bewohner empfangen die Gäste unabhängig von ihrer sexuellen Orientierung - Hauptsache, sie bringen Geld", erklärt der Mitinhaber des Clubs "Majak" Andrej Tanitschew',
#    'toleranter',
#    'die Meinungen, Auffassungen, Ideale, Überzeugungen oder die Lebensführung anderer akzeptierend',
#    'freundlich gegenüber jemandem oder etwas'],
#   ['überstrecken',
#    '"In der Welt des Yoga geben Lehrer ihren Schülern oft die Empfehlung oder fordern sie auf, die Knie vor allem in Standhaltungen nicht zu überstrecken."',
#    'überstrecken',
#    'weiter an etwas ziehen, es dehnen (strecken), als es vernünftig ist, wenn man keinen Schaden herbeiführen möchte',
#    'etwas oder jemanden über etwas hinwegstrecken'],
#   ['Orthosprache',
#    'Dementsprechend besteht die erste Aufgabe bei der Konstruktion einer Orthosprache darin die aus Sicht der Sprachanwender relevanten Fachbegriffe zu rekonstruieren',
#    'Orthosprache',
#    'Philosophie: eine von Grund auf methodisch aufgebaute Wissenschaftssprache, in der die Verwendung der Worte normiert werden',
#    'Linguistik: Sprachform, bei der die sprachlichen Einheiten in einer bestimmten Sprache gebildet werden'],
#   ['Polizeistunde',
#    '"Er sagte, der Aufgang sei schon geschlossen, aber er könne mir den heimlichen Aufstieg zeigen, den sie immer benutzten, wenn sie nach der Polizeistunde noch hochwollten."',
#    'Polizeistunde',
#    'Zeit, zu der gastronomische Einrichtungen schließen müssen',
#    'Stunde, in der die Polizei tätig ist'],
#   ['rich',
#    'Die Wiese steht voller Spitzwegerich',
#    'rich',
#    "nachgestelltes Wortbildungselement für maskuline Substantive, bezeichnet allgemein eine Person, ein Lebewesen mit den durch das Bestimmungswort gegebenen Eigenschaften, 'umstritten auch:' bezeichnet an ein feminines Substantiv angefügt, die männliche Variante",
#    'landschaftlich, besonders, ostmitteldeutsch, österreichisch: reich'],
#   ['Starnitzel',
#    '"Spinatpalatschinken und Starnitzel gefüllt mit Schlag und Beeren der Saison verführen ebenfalls zu einer Einkehr beim Ladinig."',
#    'Starnitzel',
#    'bairisch, landschaftlich: trichterförmiger Behälter aus zumeist (zusammengedrehtem) Papier (besonders für Lebensmittel)',
#    'Gastronomie, österreichisch: kleines Stück Fleisch, das vor allem in der Küche verwendet wird'],
#   ['Ladungserhaltungssatz',
#    '"Es gilt somit das Gesetz von der Erhaltung der elektrischen Ladung, welches besagt, daß in einem abgeschlossenen System die Summe der elektrischen Ladungen konstant ist. Die hier zu betrachtenden Schaltungen sind abgeschlossene Systeme, für die der Ladungserhaltungssatz gilt."',
#    'Ladungserhaltungssatz',
#    'Physik: Erhaltungssatz, der besagt, dass in jedem abgeschlossenen System (System ohne Wechselwirkungen mit seiner Umgebung) die Summe der vorhandenen elektrischen Ladung konstant bleibt',
#    'Physik, Elektrotechnik: Satz, bei dem die elektrische Ladungen konstant sind'],
#   ['Wortgattung',
#    '"Wohl kaum eine Wortgattung unterliegt einem derart schnellen Wandel wie die der Schimpfwörter."',
#    'Wortgattung',
#    'inhaltlich definierte Klasse von Wörtern',
#    'Linguistik: Gruppe von Wörtern, die in einer bestimmten Sprache vorkommen'],
#   ['Normabweichung',
#    'Bei der Qualitätskontrolle wurde eine geringfügige Normabweichung festgestellt',
#    'Normabweichung',
#    'Abweichung von einer Norm',
#    'etwas, das nicht der Norm entspricht'],
#   ['Nordlicht',
#    'Das Nordlicht entsteht wesentlich über der nördlichen Polkappe durch Fluoreszierung der Erdmagnetfelder',
#    'Nordlicht',
#    'Polarlicht des nördlichen Polarkreises',
#    'Astronomie: Licht, das von der nördlichen Polkappe ausgestrahlt wird'],
#   ['Systemprogrammiererin',
#    'Wir bemühen uns, haben aber immer noch nicht so viele Systemprogrammiererinnen in der Abteilung wie männliche Kollegen',
#    'Systemprogrammiererinnen',
#    'Programmiererin die auf die Systemprogrammierung spezialisiert ist, also systemnahe Software entwickelt oder einrichtet',
#    'Informatik: weibliche Person, die in einem System programmiert'],
#   ['Gau',
#    '"Dem Völkerschaftsverband entspricht im fränkischen Reich der Gau."',
#    'Gau',
#    'historisch im fränkischen Reich: Grafschaft des Fränkischen Reiches (die meisten waren deckungsgleich mit den alten germanischen Gauen)',
#    'historisch: Völkerstaat im Nordwesten Deutschlands'],
#   ['Anis',
#    '"Gegen Blähungen helfen zum Beispiel Fenchel oder Anis."',
#    'Anis',
#    'Botanik: Pflanze, die zur Gattung Pimpinella und der Familie der Doldenblütler zählt',
#    'Botanik: eine Pflanze aus der Familie der Blütengewächse (Anatidae)'],
#   ['Münchendorf',
#    'In Münchendorf wurde bereits Anfang des Jahres das alte Bahnhofsgebäude abgetragen und mit dem Bau des neuen Personendurchgangs begonnen. Derzeit wird dort am neuen Personendurchgang Bahnhof Münchendorf gearbeitet',
#    'Münchendorf',
#    'niederösterreichische Gemeinde',
#    'Stadt in Bayern, Deutschland'],
#   ['gegenwärtig',
#    'Ich finde, dass gegenwärtig zu wenig in Bildung investiert wird',
#    'gegenwärtig',
#    'adverbieller Gebrauch: derzeit, im Moment, in der Gegenwart',
#    'in der Zukunft, im aktuellen Zustand'],
#   ['Galactose',
#    '"Der Einfachzucker Galactose baut zusammen mit der Glucose den Zweifachzucker Lactose auf, der als Milchzucker in der Milch weit verbreitet ist."',
#    'Galactose',
#    'zur Klasse der Aldohexosen gehörender Zucker',
#    'Chemie: chemisches Element mit der Ordnungszahl 68, das zur Gruppe der Einfachzuckergewächse gehört'],
#   ['magisch',
#    '"Bei mehreren Flügen in den Höhenwinden (Lee-Wellen) über den argentinischen Anden gelang es einer Gruppe von Segelfliegern, mit der Stemme S10VT mehrfach die magische 1 000-Kilometer-Marke zu überwinden."',
#    'magische',
#    'auf unerklärliche Weise, scheinbar durch Magie',
#    'umgangssprachlich,, abwertend: großartig, besonders gut'],
#   ['Akzeptanz',
#    'Die neue Steuernovelle fand in der Bevölkerung nur geringe Akzeptanz',
#    'Akzeptanz',
#    '(zustimmende) Annahme, Anerkennung; auch Bereitschaft, etwas anzunehmen oder zu akzeptieren',
#    'allgemein: Möglichkeit, etwas zu beurteilen oder zu beurteilen'],
#   ['mehrmastig',
#    '"Mehrmastige Segelschiffe entdeckt man in den 35 ausgestellten Acryl- und Ölbildern ebenso wie Fischerboote und Lastkähne."',
#    'Mehrmastige',
#    'Schifffahrt: über mehrere Masten verfügend',
#    'Seemannssprache: mit mehreren Masten ausgestattet'],
#   ['Tirol',
#    '"Er wandte sich dann ins Tirol, war im April 1529 im Appenzellerland und wurde am 6. September 1529 in Clausen bei Innsbruck verbrannt."',
#    'Tirol',
#    'Region, die sich in den Alpen über Teile der heutigen Staatsgebiete Österreichs und Italiens erstreckt',
#    'österreichische Region im Süden der Republik Österreich'],
#   ['virtualisieren',
#    '"Wir virtualisieren die Wirklichkeit in einem Ausmaß, das unser Beharrungsvermögen in einer relativ fest verfugten Umwelt auf das Äußerste provoziert."',
#    'virtualisieren',
#    'in die virtuelle, nicht körperliche Welt übernehmen, dort stattfinden lassen',
#    'bildungssprachlich: etwas in einem virtuellen Zustand verwandeln'],
#   ['Roggen',
#    'Roggen ist nur mit Sauerteig backfähig',
#    'Roggen',
#    'langstielige Getreideart mit relativ langen Ähren und Grannen',
#    'Gastronomie: Gemüse, das aus Roggenkörnern hergestellt wird'],
#   ['simuliert',
#    '"Die modernen "Games" spielt man meist zu zweit, sie fördern die Interaktivität und bieten Möglichkeiten für simulierte Lebenserfahrungen."',
#    'simulierte',
#    '(häufig zu Test- oder Übungszwecken) modellhaft nachgebildet, beispielsweise in einem Computer oder Labor',
#    'etwas (beispielsweise ein Spiel, ein Theaterstück, ein Theaterstück) simuliert'],
#   ['Ionengenerator',
#    '"Ionengenerator mit einer Nadelelektrode und einer Masseelektrode, die mit der Nadelelektrode zusammenwirken kann, um zum Produzieren von Ionen eine Koronaentladung in der Luft zu erzeugen, wobei die Masseelektrode derart angeordnet ist, dass sie eine imaginäre Verlängerung einer Längsachse der Nadelelektrode umgibt, dadurch gekennzeichnet, dass ein Teil der Masseelektrode entleert ist, um eine darin ausgebildete Spaltregion zu bilden."',
#    'Ionengenerator',
#    'Technik: Gerät bestehend aus einem Ionisator und einer Hochspannungsquelle zur Erzeugung von Koronaentladungen in Luft oder einem technischen Gas',
#    'Elektrotechnik: Gerät zur Erzeugung von Ionen'],
#   ['GenImpfstoff',
#    '"Größter Vorteil verglichen mit herkömmlichen Methoden: Das Gendesign geht um ein Vielfaches schneller als das mühsame Züchten von Viren in Eiern oder Tieren. Zudem muss der Gen-Impfstoff anders als die temperaturempfindlichen natürlich hergestellten Mittel beim Transport in alle Welt nicht durchgängig gekühlt werden."',
#    'GenImpfstoff',
#    'Medizin: Vakzin (Impfstoff), das dazu führt, dass der Empfänger ein virales Protein selbst herstellt und somit selbst für das Antigen sorgt, das dann die Bildung von Antikörpern anregt und somit zu einer Immunantwort führt, wenn der Empfänger dem entsprechenden Erreger/Virus ausgesetzt wird',
#    'Medizin, Gentechnologie: Substanz, die das Immunsystem gegen bestimmte Krankheiten verhindern soll'],
#   ['beigesellen',
#    'Darf ich mich Ihnen beigesellen?',
#    'beigesellen',
#    'reflexiv, gehoben: zu anderen, die schon da sind, hingehen/dazukommen und mitmachen',
#    'umgangssprachlich,, reflexiv: jemandem etwas oder jemanden verletzen'],
#   ['schwelgen',
#    '"In Architektur kann man hier schwelgen, in alter und uralter gotischer und flämischer - und auch in moderner."',
#    'schwelgen',
#    'gehoben: sich genüsslich in etwas versenken, sich an etwas berauschen, einem Genuss hingeben',
#    'bildungssprachlich: etwas mit einem schwelgen Geräusch versehen'],
#   ['Jugendorganisation',
#    '"Nach ghanaischem Vorbild gründete er eine eigene Jugendorganisation der NDP, die im Wesentlichen für die von der Partei ausgehende Einschüchterung und Gewalt verantwortlich war."',
#    'Jugendorganisation',
#    'öffentliche Einrichtung/Organisation speziell für Jugendliche',
#    'Gruppe von Jugendlichen'],
#   ['Pflichtlektüre',
#    'Heute habe ich mir die Pflichtlektüre für die nächsten Wochen zugelegt',
#    'Pflichtlektüre',
#    'Werk mit wichtigen Informationen (meist in schriftlicher Form), das von 1 umfasst wird',
#    'wichtige Lektüre, die jemandem oder etwas besonders wichtig ist'],
#   ['Ungeimpfter',
#    '"Seit dem 31. August weist das LAGuS die Inzidenz auch gesondert bei Geimpften und Ungeimpften aus. Bei Geimpften liegt sie bei 7,1 (+-0), bei Ungeimpften bei 72,5 (+2,1)."',
#    'Ungeimpften',
#    'Person, die keine Impfung erhalten hat',
#    'Medizin: Person, die nicht geimpft ist'],
#   ['Schlesien',
#    'Sie kommen aus Schlesien',
#    'Schlesien',
#    'mitteleuropäische Region, die zu Polen und zu Tschechien gehört, in historischer Zeit auch deutsches, preußisches und österreich-ungarisches Territorium war',
#    'Geografie: Region im mittleren Mittelmeerraum, die hauptsächlich in Südosteuropa liegt'],
#   ['Albanerin',
#    '"Sie sieht auch wenig Chancen dafür, dass die Albaner und Albanerinnen selbst in der Lage sein werden, ihr Land wieder aufzubauen. Dabei würde ihnen ihre eigene Kultur hinderlich sein."',
#    'Albanerinnen',
#    'eine Angehörige der ethnischen Gruppe, die Albanisch spricht',
#    'Staatsbürgerin der Albaner Republik'],
#   ['Verschlussdeckel',
#    '"Decken Sie anschließend die Gläser ab, ohne den Verschlussdeckel fest zuzudrehen."',
#    'Verschlussdeckel',
#    'Deckel, der dazu dient, etwas (ein Behältnis) zu verschließen',
#    'Deckel, der zum Verschließen von etwas oder jemandem dient'],
#   ['Flitter',
#    '"Von Guste, die er für seine Taufpatin hielt, erbte Janosch die Vorliebe für Gold und Flitter."',
#    'Flitter',
#    'übertragen: etwas Schmückendes, das glänzt, aber nutz- und wertlos ist',
#    'etwas, das mit einem Flint gefüllt ist'],
#   ['Ischewsk',
#    'Ischewsk ist seit 1921 Hauptstadt der Republik Udmurtien',
#    'Ischewsk',
#    'die Hauptstadt der Teilrepublik Udmurtien in Russland',
#    'Hauptstadt der Republik Udmurtien'],
#   ['deklarativ',
#    '"Das Besondere dieser Klasse illokutionärer Akte ist, daß der erfolgreiche Vollzug eines deklarativen illokutionären Aktes die Übereinstimmung zwischen propositionalem Gehalt und Realität herstellt."',
#    'deklarativen',
#    'Linguistik, speziell Sprechakttheorie: Eigenschaft sprachlicher Äußerungen, bei denen der Sprecher kundgibt, dass in Zukunft etwas Bestimmtes gelten soll; Eigenschaft von Sprechakten (= deklarativen Akten/Deklarationen), die - unter geeigneten Bedingungen verwendet - eine neue Wirklichkeit herstellen',
#    'Linguistik, speziell Sprechakttheorie: in der Art und Weise eines Sprechakts'],
#   ['Jagdszene',
#    'Im Salon hing eine Jagdszene',
#    'Jagdszene',
#    'Bildende Kunst: bildliche Darstellung einer Jagd',
#    'Bereich, in dem sich die Jagd befindet'],
#   ['monarchisch',
#    '"Man kann annehmen, daß die Mehrheit des gesetzgebenben Körpers damals entschieden monarchisch gesinnt war; es läßt sich also auch annehmen, daß dreiviertel aller Staatsbeamten damals monarchisch gesinnt waren."',
#    'monarchisch',
#    'in Bezug auf eine Monarchie; von einem Monarchen (ausgehend)',
#    'historisch: die monarchische Ordnung betreffend, zu ihr gehörend, von ihr stammend'],
#   ['mehrmonatig',
#    'Die mehrmonatige Forschungsreise brachte keine neuen Erkenntnisse',
#    'mehrmonatige',
#    'mehrere Monate dauernd',
#    'mehrere Monate dauernd'],
# ...
#   ['erwirtschaften',
#    'Das Unternehmen konnte schon im ersten Jahr Gewinn erwirtschaften',
#    'erwirtschaften',
#    'durch Handeln am Markt (Wirtschaften) ein bestimmtes Ergebnis erlangen, erreichen',
#    'Wirtschaft: einen Gewinn erzielen'],
#   ['Berufsverkehr',
#    '"Nun aber, bei der Aktion am 6. Dezember, standen so viele Autos im morgendlichen Berufsverkehr, dass die Polizei einfach eingreifen musste. Sie lösten uns von der Straße und es folgte Präventivgewahrsam."',
#    'Berufsverkehr',
#    'Verkehr: hohes Verkehrsaufkommen zu bestimmten Zeiten aufgrund von Pendlern, die von oder zur Arbeitsstätte fahren',
#    'Verkehrsgeschehen, bei dem berufliche Tätigkeiten durchgeführt werden'],
#   ['europäisch',
#    'Die europäischen Aktienmärkte spielten heute wieder verrückt',
#    'europäischen',
#    'zu Europa gehörig, Europa betreffend',
#    'die Europäische Republik betreffend, zu ihr gehörend'],
#   ['Gier',
#    'Herr Gier wollte uns kein Interview geben',
#    'Gier',
#    'Familienname, Nachname',
#    'deutschsprachiger Familienname, Nachname'],
#   ['benachteiligt',
#    '"Für benachteiligte Kinder, egal ob aus Flüchtlings- oder aus deutschen Familien, sieht die Bildungssituation nicht gut aus."',
#    'benachteiligte',
#    'durch bestimmte Umstände im Nachteil seiend',
#    'so, dass jemand oder etwas von einer anderen Person (beispielsweise einer Familie, einem sozialen Netzwerk, einem sozialen Netzwerk, einem sozialen Netzwerk, einem sozialen Netzwerk, einem sozial'],
#   ['Fischerei',
#    'Um Kunden für das Unternehmen zu bekommen, wird die Fischerei potenzieller Käufer durch die Werbung gefördert',
#    'Fischerei',
#    'Personen oder Gegenstände für einen bestimmten Zweck sammeln',
#    'Wirtschaftszweig, der Fischerei betreibt'],
#   ['dementsprechend',
#    'Wir haben uns dementsprechend entschlossen, nicht zu verreisen',
#    'dementsprechend',
#    'gemäß dem, was bereits bekannt ist',
#    'in der Art und Weise, wie es einem anderen entspricht'],
#   ['auflöten',
#    'Auf die aus einer Pressung basierenden Ringschiene sind im Schulterbereich zwei blattförmige Ornamente aufgelötet, die den Ringkopf halten',
#    'aufgelötet',
#    'etwas auf etwas löten',
#    'etwas auf etwas legen, auf etwas legen'],
#   ['Gewalt',
#    'Er wurde mit Gewalt aus seinem Auto gezerrt und verprügelt',
#    'Gewalt',
#    'ohne Plural: erhebliche oder übermäßige Kraft, dies bei gezieltem Tun gegen Widerstände, oft ohne Legitimation',
#    'ohne Plural: Handlung, mit der jemand oder etwas begangen wird'],
#   ['Aggo',
#    'Aggo wohnt hinterm Deich',
#    'Aggo',
#    'männlicher Vorname',
#    'männlicher Vorname'],
#   ['Notexamen',
#    '"Viele Kriegsfreiwilligen melden sich bei den Meldestellen, Schüler und höhere Klassen können Notexamina ablegen."',
#    'Notexamina',
#    'vorgezogene Abschlussprüfung, um zum Militär einberufenen Schülern/Studenten einen Abschluss ihrer Ausbildung vor/bald nach Dienstantritt zu ermöglichen',
#    'Chemie: chemisches Element mit der Ordnungszahl 80, das zur Gruppe der Atomkerne gehört'],
#   ['Schrottpresse',
#    '"Allerdings gäbe es einen Weg, die für die Schrottpresse vorgesehenen Autos wieder in Umlauf zu bringen: Denn 2014 sollen alle Daten zur Abwrackprämie, die beim Bundesamt für Wirtschaft und Ausfuhrkontrolle (Bafa) liegen, gelöscht werden. Die Vorgeschichte des Autos wäre dann passé."',
#    'Schrottpresse',
#    'Technik: Gerät, mit dem Metallschrott verdichtet wird',
#    'Presse, die beruflich Schrott herstellt'],
#   ['Krisenmanager',
#    '"Wer gefahrenträchtige Ereignisse auf sich zutreiben läßt, wird sich bestenfalls als ein gutwilliger, an der Aufgabe wachsender, wohl kaum aber als ein sehr kompetenter Krisenmanager in der akuten Situation erweisen."',
#    'Krisenmanager',
#    'Person, die sachliche Problemsituationen und menschliche Konflikte zu regulieren versucht',
#    'Person, die in einer Krisensituation tätig ist'],
#   ['Schreiberling',
#    '"Der schwächliche Schreiberling ist ein geschickter Textverstecker. Große Teile seines Tagebuchs quetscht er zwischen die Zeilen des sogenannten "Trinker"-Manuskripts."',
#    'Schreiberling',
#    'abwertend: jemand, der viele und schlechte Texte verfasst, insbesondere ein Schriftsteller oder Journalist',
#    'Person, die sich beruflich mit dem Schreiben beschäftigt'],
#   ['Gesprächsraum',
#    '"Der Gesprächsraum von Pastorin Biermann befindet sich im ersten Stock, direkt über dem Gefängniscafé. "Seelsorgliche Gespräche führen oft in Tiefen und in Sorgen und Nöte hinein", sagt sie."',
#    'Gesprächsraum',
#    'Raum, der der direkten Kommunikation dient; meist ausgestattet mit einem oder mehreren Tischen und Stühlen',
#    'Raum, in dem Gespräche geführt werden'],
#   ['Aggression',
#    '"Das Ziel seiner Aggression waren jetzt nicht mehr die anderen Heimbewohner, sondern ich."',
#    'Aggression',
#    'feindliche Einstellung',
#    'Gewalt gegen jemanden oder etwas'],
#   ['durchstreifen',
#    '"Es würde jetzt bald dunkel sein, und was hatte er nicht schon für schaurige Geschichten über Messerstecher gehört, die in den großen Städten bei Nacht und Nebel die Straßen nach wehrlosen Opfern durchstreiften."',
#    'durchstreiften',
#    'systematisch, zielgerichtet, aufmerksam durch ein Gebiet gehen, um etwas Bestimmtes zu finden, auf etwas Bestimmtes zu achten',
#    'umgangssprachlich,, scherzhaft: durch etwas hindurchstreifen'],
#   ['Coach',
#    '"Dabei wirkte der Coach der Ukraine jedoch nicht wie ein Trainer, dessen Team eben gegen einen der Turnierfavoriten verloren hat, auch wenn der den Beweis dafür dessen sic in diversen Phasen des Spiels schuldig geblieben war."',
#    'Coach',
#    'Sport: jemand, der eine Person oder Mannschaft trainiert und betreut',
#    'Sport: Person, die einen Mannschaftssport ausübt'],
#   ['berauschen',
#    '"Sich am freien Tag auf dem Sofa breitmachen und fernsehkucken... am bloßen Gedanken daran kann man sich berauschen."',
#    'berauschen',
#    'reflexiv: sich nicht satt sehen können und mehr von etwas haben wollen, weil es starke positive Gefühle schafft',
#    'umgangssprachlich: etwas (zum Beispiel einen Text, einen Text, einen Text, einen Text, einen Text) mit Hilfe von Äußerungen oder Ähnlichem versehen'],
#   ['ungelernt',
#    'Wann denkst du, dass du deine 22 ungelernten Gedichte aus der Schulzeit endlich lernst?',
#    'ungelernten',
#    'nicht gelernt',
#    'nicht gelernt, nicht gelernt'],
#   ['davonbrausen',
#    'Der Porsche, mit dem er nach dem Heimsieg davonbrauste, ist ein letztes Relikt aus seiner wilden Zeit',
#    'davonbrauste',
#    'umgangssprachlich: mit großer Geschwindigkeit und großem Getöse davonfahren',
#    'umgangssprachlich,, scherzhaft: etwas oder jemanden von einem Ort an einen anderen Ort entfernen'],
#   ['Anforderung',
#    '"Sie stellt aber auch Anforderungen an die Bürger als Sprachrezipienten, an ihr sprachliches Wissen und Können, etwa bei der Aufnahme von Wortungetümen wie "Wachstumsbeschleunigungsgesetz"."',
#    'Anforderungen',
#    'Eigenschaft oder Fähigkeit, die zur Bewältigung bestimmter Aufgaben vorhanden sein muss',
#    'etwas, das an jemanden oder etwas gerichtet ist'],
#   ['Schnurre',
#    '"So eine richtige "Züri-Schnurre" gilt als arrogant - zu Recht?" Eigentlich ist die Zürcher Mundart eher unauffällig. Starke Assoziationen und Emotionen weckt sie dennoch',
#    'Schnurre',
#    'Schweiz, mundartlich, mit Bezug auf Menschen derb: Mund, Maul',
#    'umgangssprachlich,, abwertend: männliche Person, die in einem bestimmten Bereich außergewöhnliche Eigenschaften aufweist'],
#   ['Etage',
#    '"Ich ging hoch in die obere Etage und klopfte an die Tür."',
#    'Etage',
#    'Erdgeschoss oder Stockwerk eines Bauwerks; "erste Etage" bezeichnet meistens den 1. Stock und manchmal das Erdgeschoss',
#    'Raum in einem Gebäude, in dem sich ein Gebäude befindet'],
#   ['Zehenspitze',
#    '"Auf Zehenspitzen schlich sie in sein Zimmer hinüber."',
#    'Zehenspitzen',
#    'vorderster Bereich einer Zehe',
#    'Spitze einer Zehe'],
#   ['Antichrese',
#    '"Wenn der Antichrese die pfandrechtliche Wirkung abgesprochen wird, so ist damit gesagt, daß der Gläubiger aus derselben nicht den Anspruch herleiten kann, vor anderen Gläubigern des Eigenthümers, namentlich im Fall der Eröffnung des Konkursverfahrens über das Vermögen desselben, aus dem Grundstück oder dessen Nutzungen befriedigt zu werden, beziehungsweise der Befriedigung anderer Gläubiger aus dem Gegenstande der Antichrese entgegenzutreten."',
#    'Antichrese',
#    'Zivilrecht: beim Pfandrecht die in Deutschland mögliche, in Österreich untersagte Berechtigung des Pfandgläubigers, die Nutzungen des Pfandes zu ziehen; z.B. im deutschen Zivilrecht gemäß  und bei gesetzlichem Pfandrecht analog § 1213 I BGB',
#    'Recht: gerichtliche Verfügung über das Vermögen eines Gläubigers'],
#   ['Kretschmer',
#    'Der Kretschmer hat gestern Abend selbst zu tief ins Glas geschaut',
#    'Kretschmer',
#    'Niederschlesien, Spreewald: der Betreiber einer Dorfschenke (eines Kretschams), der Schenkwirt',
#    'umgangssprachlich,, abwertend: jemand, der etwas liebt'],
#   ['Kamerad',
#    '"Von der Odyssee, die die Kameraden der Schönheider Feuerwehr hinter sich haben, können viele Retter ein Lied singen."',
#    'Kameraden',
#    'Person, mit der man auf eine bestimmte Art (Sport, Schule, Beruf, Freundschaft oder Ähnliches) verbunden ist',
#    'Person, mit der jemand gemeinsam etwas gemeinsam tun kann'],
#   ['Kunststoffpreis',
#    'Der Rohstoff Kunststoff wird aus Erdöl hergestellt und zum börsennotierten Kunststoffpreis abgegeben',
#    'Kunststoffpreis',
#    'den beim Erwerb einer Ware oder Dienstleistung aus Kunststoff zu zahlende Geldbetrag',
#    'Preis für Kunststoff'],
#   ['Fußkissen',
#    '"Sie wies mit einem Zeremoniell, das ihr sonst fremd war, auf einen der zur Seite stehenden japanischen Stühle, schob sich ein Fußkissen heran und nahm ihrerseits auf dem Sofa Platz."',
#    'Fußkissen',
#    'Kissen, auf das man die Füße stützen kann',
#    'Kissen, das für die Füße bestimmt ist'],
#   ['arbeitsreich',
#    '"Es ist jedesmal eine schöne erholsame Zeit, in der man Kraft tanken kann für den arbeitsreichen Sommer."',
#    'arbeitsreichen',
#    'voll, gefüllt mit Arbeit',
#    'reich an Arbeit'],
#   ['hinreißend',
#    'Sie hat einen hinreißenden Charme',
#    'hinreißenden',
#    'in Bezug auf persönliche Eigenschaften, wie Aussehen, Charakter, Wesen: begeisternd',
#    'umgangssprachlich,, abwertend: sehr gut'],
#   ['Kirsche',
#    'Hast Du schon die blühende Kirsche in unserem Garten gesehen?',
#    'Kirsche',
#    'Botanik: der in der Natur wachsende Kirschbaum',
#    'Botanik: eine Pflanze aus der Familie der Kirschen'],
#   ['aufschießen',
#    'Der Schlüssel ist jedenfalls weg, wir werden das Schloss aufschießen müssen, wenn wir jetzt ranwollen',
#    'aufschießen',
#    'haben, umgangssprachlich: etwas zugänglich machen/aufmachen, indem der Verschluss mit einem Schuss zerstört und so geöffnet wird',
#    'umgangssprachlich: etwas auf etwas schieben'],
#   ['Nordwest',
#    'Nordwest-Kreuz, Wien Nordwestbahnhof',
#    'Nordwest',
#    'Geografie, als Bestimmungswort in Toponymen, die Zusammensetzungen und Verbindungen sind',
#    'vorangestelltes Wortbildungselement in Fremdwörtern aus dem Griechischen mit der Bedeutung: nördlich, nördlich'],
#   ['Asien',
#    '"Natürlich gehört Indien zu Asien."',
#    'Asien',
#    'der größte Kontinent der Erde; bildet zusammen mit Europa den Großkontinent Eurasien',
#    'Staat in Südostasien'],
#   ['Männerchor',
#    '"Noch gab es nur reinen Wohlklang, die drei Os rollten wie die Bassstimmen eines Männerchors."',
#    'Männerchors',
#    'Chor, in dem ausschließlich männliche, meist erwachsene Personen singen',
#    'Musik: Chor, der von Männern gespielt wird'],
#   ['entschuldigen',
#    'Ich entschuldige mich',
#    'entschuldigen',
#    'reflexiv, der Kürze zuliebe etwas salopp: den eigenen - oft durch Gesten angedeuteten - Abgang ansagen und um Verständnis dafür bitten',
#    'jemandem etwas entschuldigen: jemandem etwas entschuldigen: jemandem etwas entschuldigen, jemandem etwas entschuldigen'],
#   ['Ikosaeder',
#    'Ein Ikosaeder hat zwölf Ecken, in denen jeweils fünf Flächen zusammentreffen',
#    'Ikosaeder',
#    'Geometrie: von zwanzig gleichseitigen Dreiecken begrenzter Körper',
#    'Geometrie: geometrische Figur mit zwölf Ecken'],
#   ['Flutgebiet',
#    '"Flächen im mittleren Flutgebiet werden von den Kleinfluten nicht mehr betroffen und erfahren also auch durch solche keinen Schaden."',
#    'Flutgebiet',
#    'Areal, das von Wasser geflutet wird oder wurde',
#    'Gebiet, in dem ein Flut liegt'],
#   ['Augenschirm',
#    '"Außerdem kaufte er sich einen grünen Augenschirm, mit dem er schon lange geliebäugelt hatte und der ihm half, hinter seinem Redaktionstisch einen gewichtigen Eindruck zu machen."',
#    'Augenschirm',
#    'Schutzschirm für die Augen',
#    'vor allem.: Schirm, der zum Schutz vor Sonneneinstrahlung verwendet wird'],
#   ['Schlögel',
#    'Weiters werden aus dem Schlögel Steaks oder Schnitzel geschnitten, die gebraten, gegrillt oder gebacken werden. Gewürfelt ist der Schlögel ideal für kurz gebratene Ragouts, Spieße und Fondues',
#    'Schlögel',
#    'östereichisch:: Hinterschenkel des Kalbs, Lamms oder Rehs',
#    'Gastronomie: gewürfeltes Fleisch, das vor allem in der Küche verwendet wird'],
#   ['Pi',
#    '"Pi ist eine der grundlegenden Zahlen, die sich durch die ganze Mathematik zieht."',
#    'Pi',
#    'Mathematik, ohne Plural: Konstante, die das Verhältnis des Umfangs zum Durchmesser eines Kreises beschreibt',
#    'Mathematik: Zahlenangabe, die in der ganzen Mathematik verwendet wird'],
#   ['Baack',
#    'Baack kommt und geht',
#    'Baack',
#    'deutschsprachiger Familienname',
#    'deutschsprachiger Familienname, Nachname'],
#   ['EsDur',
#    'Es-Dur hat drei ♭ als Vorzeichen',
#    'EsDur',
#    'meist ohne Artikel: eine Tonart des Tongeschlechts Dur, die auf dem Grundton Es basiert',
#    'Musik: Tonart des Tongeschlechts Dur'],
#   ['überdauern',
#    '"Allerdings werden diese zur Kodierung von Informationen auf einer Oberfläche eingesetzt, die sehr lange Zeiträume überdauern soll."',
#    'überdauern',
#    'eine lange Zeitspanne ohne Schaden zu nehmen erhalten bleiben',
#    'übertragen:: längere Zeit dauern'],
#   ['Echtermeyer',
#    'Der Echtermeyer trägt nie die Pullover, die die Echtermeyer ihm strickt',
#    'Echtermeyer',
#    'deutschsprachiger Nachname, Familienname',
#    'deutschsprachiger Familienname, Nachname'],
#   ['Stromboli',
#    'Der Stromboli ist der aktivste europäische Vulkan mit einer stündlichen Frequenz der Eruptionen',
#    'Stromboli',
#    'ein 924 Meter hoher, aktiver Schichtvulkan der Insel Stromboli',
#    'europäischer Vulkan, der in Südostasien und Asien beheimatet ist'],
#   ['Lehnübersetzung',
#    'Ein Beispiel für eine Lehnübersetzung ist das deutsche Wort "Halbwelt", das eine genaue Übersetzung des französischen "demi-monde" darstellt',
#    'Lehnübersetzung',
#    'Linguistik: ein (auch zusammengesetztes) Wort, das nach einem Fremdwort gebildet wurde, indem ein Ausgangswort (oder dessen Bestandteile, einzeln) übersetzt wurden',
#    'Linguistik: Übersetzung eines Wortes aus einer anderen Sprache'],
#   ['Chorraum',
#    '"Im Chorraum der heutigen, im Jahre 1934 geweihten Kirche befindet sich ein Mosaikbild, das die Kirche prägt und das den gekreuzigten Christus als König und Hohepriester mit Maria und Johannes darstellt. Es besteht aus vier Millionen Steinchen."',
#    'Chorraum',
#    'Architektur: Altarraum in einer Kirche',
#    'Raum in einem Chor'],
#   ['Selm',
#    'Selm liegt im Westen Deutschlands',
#    'Selm',
#    'eine Stadt in Nordrhein-Westfalen, Deutschland',
#    'eine Stadt in Nordrhein-Westfalen, Deutschland'],
#   ['Felsenpinguin',
#    '"Wie die meisten Pinguinarten nistet der Felsenpinguin nicht auf dem antarktischen Festland, sondern bevorzugt etwas wärmeren Regionen fern der Polkappe"',
#    'Felsenpinguin',
#    'Zoologie: eine Art aus der Familie der Pinguine',
#    'Zoologie: Vertreter einer Gattung aus der Familie der Pinguine'],
#   ['speichern',
#    'Dunkle Steine speichern die Sonnenwärme besser als helle',
#    'speichern',
#    'einen Vorrat von etwas anlegen, damit man etwas zur Verfügung hat',
#    'etwas oder jemanden in einem bestimmten Zustand behalten']]}
